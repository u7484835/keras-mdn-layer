# %% [markdown]
# # 2D Mixture Density Network
#
# An extension of Bishops' classic MDN prediction task to 2-dimensions.
#
# The idea in this task is to predict a the value of a two inverse sine functions simultaneously. This function has multiple real-valued solutions at each point, so the ANN model needs to have the capacity to handle this in it's loss function. An MDN is a good way to handle the predictions of these multiple output values.
#
# This implementation owes much to the following:
#
# - [David Ha - Mixture Density Networks with TensorFlow](http://blog.otoro.net/2015/11/24/mixture-density-networks-with-tensorflow/)
# - [Mixture Density Networks in Edward](http://edwardlib.org/tutorials/mixture-density-network)

# %%
import keras
from context import * # imports the MDN layer 
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D 
# %matplotlib widget
# Out:
# 2024-06-13 19:28:56.491112: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-13 19:28:56.493400: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-13 19:28:56.524244: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-13 19:28:56.524280: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-13 19:28:56.526076: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-13 19:28:56.534483: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-13 19:28:56.534935: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-13 19:28:57.189854: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Generate Synthetic Data
#
# Data generation

# %%
## Generating some data:
NSAMPLE = 5000

z_data = np.float32(np.random.uniform(-10.5, 10.5, NSAMPLE))
r_data = np.random.normal(size=NSAMPLE)
s_data = np.random.normal(size=NSAMPLE)
x_data = np.sin(0.75 * z_data) * 7.0 + z_data * 0.5 + r_data * 1.0
y_data = np.cos(0.80 * z_data) * 6.5 + z_data * 0.5 + s_data * 1.0

x_input = z_data.reshape((NSAMPLE, 1))
y_input = np.array([x_data,y_data])
y_input = y_input.T #reshape to (NSAMPLE,2)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_data, y_data, z_data, alpha=0.3, c='r') #c=perf_down_sampled.moving
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Build the MDN Model
#
# Now we will construct the MDN model in Keras. This uses the `Sequential` model interface in Keras.
#
# The `MDN` layer comes after one or more `Dense` layers. You need to define the output dimension and number of mixtures for the MDN like so: `MDN(output_dimension, number_mixtures)`.
#
# For this problem, we only need an output dimension of 1 as we are predicting one value (y). Adding more mixtures adds a more parameters (model is more complex, takes longer to train), but might help make the solutions better. You can see from the training data that there are at maximum 5 different layers to predict in the curve, so setting `N_MIXES = 5` is a good place to start.
#
# For MDNs, we have to use a special loss function that can handle the mixture parameters: the function has to take into account the number of output dimensions and mixtures.

# %%
N_HIDDEN = 15
N_MIXES = 10
OUTPUT_DIMS = 2

model = keras.Sequential()
model.add(keras.layers.Dense(N_HIDDEN, batch_input_shape=(None, 1), activation='relu'))
model.add(keras.layers.Dense(N_HIDDEN, activation='relu'))
model.add(mdn.MDN(OUTPUT_DIMS, N_MIXES))
model.compile(loss=mdn.get_mixture_loss_func(OUTPUT_DIMS,N_MIXES), optimizer=keras.optimizers.Adam())
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 15)                30
#
#  dense_1 (Dense)             (None, 15)                240
#
#  mdn (MDN)                   (None, 50)                800
#
# =================================================================
# Total params: 1070 (4.18 KB)
# Trainable params: 1070 (4.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Training the model
#
# Now we train the model using Keras' normal `fit` command.

# %%
history = model.fit(x=x_input, y=y_input, batch_size=128, epochs=300, validation_split=0.15, callbacks=[keras.callbacks.TerminateOnNaN()])
# Out:
# Epoch 1/300
# 34/34 [==============================] - 4s 29ms/step - loss: 14.7816 - val_loss: 12.0169
# Epoch 2/300
# 34/34 [==============================] - 0s 3ms/step - loss: 10.6659 - val_loss: 9.2323
# Epoch 3/300
# 34/34 [==============================] - 0s 3ms/step - loss: 8.4706 - val_loss: 7.7166
# Epoch 4/300
# 34/34 [==============================] - 0s 3ms/step - loss: 7.3553 - val_loss: 7.0201
# Epoch 5/300
# 34/34 [==============================] - 0s 3ms/step - loss: 6.8529 - val_loss: 6.6852
# Epoch 6/300
# 34/34 [==============================] - 0s 3ms/step - loss: 6.6097 - val_loss: 6.5329
# Epoch 7/300
# 34/34 [==============================] - 0s 3ms/step - loss: 6.4900 - val_loss: 6.4360
# Epoch 8/300
# 34/34 [==============================] - 0s 3ms/step - loss: 6.4051 - val_loss: 6.3641
# Epoch 9/300
# 34/34 [==============================] - 0s 3ms/step - loss: 6.3405 - val_loss: 6.3070
# Epoch 10/300
# 34/34 [==============================] - 0s 3ms/step - loss: 6.2850 - val_loss: 6.2600
# Epoch 11/300
# 34/34 [==============================] - 0s 3ms/step - loss: 6.2378 - val_loss: 6.2221
# Epoch 12/300
# 34/34 [==============================] - 0s 4ms/step - loss: 6.1984 - val_loss: 6.1863
# Epoch 13/300
# 34/34 [==============================] - 0s 4ms/step - loss: 6.1643 - val_loss: 6.1555
# Epoch 14/300
# 34/34 [==============================] - 0s 4ms/step - loss: 6.1328 - val_loss: 6.1259
# Epoch 15/300
# 34/34 [==============================] - 0s 4ms/step - loss: 6.1040 - val_loss: 6.0981
# Epoch 16/300
# 34/34 [==============================] - 0s 4ms/step - loss: 6.0764 - val_loss: 6.0725
# Epoch 17/300
# 34/34 [==============================] - 0s 3ms/step - loss: 6.0506 - val_loss: 6.0468
# Epoch 18/300
# 34/34 [==============================] - 0s 3ms/step - loss: 6.0241 - val_loss: 6.0211
# Epoch 19/300
# 34/34 [==============================] - 0s 3ms/step - loss: 5.9975 - val_loss: 5.9944
# Epoch 20/300
# 34/34 [==============================] - 0s 3ms/step - loss: 5.9714 - val_loss: 5.9724
# Epoch 21/300
# 34/34 [==============================] - 0s 3ms/step - loss: 5.9499 - val_loss: 5.9524
# Epoch 22/300
# 34/34 [==============================] - 0s 3ms/step - loss: 5.9307 - val_loss: 5.9334
# Epoch 23/300
# 34/34 [==============================] - 0s 3ms/step - loss: 5.9114 - val_loss: 5.9149
# Epoch 24/300
# 34/34 [==============================] - 0s 4ms/step - loss: 5.8927 - val_loss: 5.8961
# Epoch 25/300
# 34/34 [==============================] - 0s 3ms/step - loss: 5.8733 - val_loss: 5.8770
# Epoch 26/300
# 34/34 [==============================] - 0s 3ms/step - loss: 5.8538 - val_loss: 5.8567
# Epoch 27/300
# 34/34 [==============================] - 0s 3ms/step - loss: 5.8328 - val_loss: 5.8350
# Epoch 28/300
# 34/34 [==============================] - 0s 3ms/step - loss: 5.8093 - val_loss: 5.8101
# Epoch 29/300
# 34/34 [==============================] - 0s 3ms/step - loss: 5.7812 - val_loss: 5.7780
# Epoch 30/300
# 34/34 [==============================] - 0s 3ms/step - loss: 5.7449 - val_loss: 5.7336
# Epoch 31/300
# 34/34 [==============================] - 0s 4ms/step - loss: 5.7031 - val_loss: 5.6894
# Epoch 32/300
# 34/34 [==============================] - 0s 3ms/step - loss: 5.6602 - val_loss: 5.6359
# Epoch 33/300
# 34/34 [==============================] - 0s 3ms/step - loss: 5.6106 - val_loss: 5.5868
# Epoch 34/300
# 34/34 [==============================] - 0s 3ms/step - loss: 5.5628 - val_loss: 5.5350
# Epoch 35/300
# 34/34 [==============================] - 0s 3ms/step - loss: 5.5112 - val_loss: 5.4816
# Epoch 36/300
# 34/34 [==============================] - 0s 3ms/step - loss: 5.4560 - val_loss: 5.4189
# Epoch 37/300
# 34/34 [==============================] - 0s 3ms/step - loss: 5.3941 - val_loss: 5.3610
# Epoch 38/300
# 34/34 [==============================] - 0s 3ms/step - loss: 5.3348 - val_loss: 5.3099
# Epoch 39/300
# 34/34 [==============================] - 0s 3ms/step - loss: 5.2782 - val_loss: 5.2484
# Epoch 40/300
# 34/34 [==============================] - 0s 3ms/step - loss: 5.2177 - val_loss: 5.1833
# Epoch 41/300
# 34/34 [==============================] - 0s 3ms/step - loss: 5.1510 - val_loss: 5.1137
# Epoch 42/300
# 34/34 [==============================] - 0s 3ms/step - loss: 5.0834 - val_loss: 5.0486
# Epoch 43/300
# 34/34 [==============================] - 0s 3ms/step - loss: 5.0290 - val_loss: 5.0023
# Epoch 44/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.9858 - val_loss: 4.9692
# Epoch 45/300
# 34/34 [==============================] - 0s 3ms/step - loss: 4.9517 - val_loss: 4.9327
# Epoch 46/300
# 34/34 [==============================] - 0s 3ms/step - loss: 4.9216 - val_loss: 4.9056
# Epoch 47/300
# 34/34 [==============================] - 0s 3ms/step - loss: 4.8938 - val_loss: 4.8781
# Epoch 48/300
# 34/34 [==============================] - 0s 3ms/step - loss: 4.8691 - val_loss: 4.8509
# Epoch 49/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.8443 - val_loss: 4.8197
# Epoch 50/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.8034 - val_loss: 4.7768
# Epoch 51/300
# 34/34 [==============================] - 0s 3ms/step - loss: 4.7754 - val_loss: 4.7553
# Epoch 52/300
# 34/34 [==============================] - 0s 3ms/step - loss: 4.7505 - val_loss: 4.7218
# Epoch 53/300
# 34/34 [==============================] - 0s 3ms/step - loss: 4.7193 - val_loss: 4.6870
# Epoch 54/300
# 34/34 [==============================] - 0s 3ms/step - loss: 4.6915 - val_loss: 4.6624
# Epoch 55/300
# 34/34 [==============================] - 0s 3ms/step - loss: 4.6560 - val_loss: 4.6148
# Epoch 56/300
# 34/34 [==============================] - 0s 3ms/step - loss: 4.6096 - val_loss: 4.5654
# Epoch 57/300
# 34/34 [==============================] - 0s 3ms/step - loss: 4.5574 - val_loss: 4.5078
# Epoch 58/300
# 34/34 [==============================] - 0s 3ms/step - loss: 4.5032 - val_loss: 4.4626
# Epoch 59/300
# 34/34 [==============================] - 0s 3ms/step - loss: 4.4577 - val_loss: 4.4306
# Epoch 60/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.4219 - val_loss: 4.3875
# Epoch 61/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.3874 - val_loss: 4.3552
# Epoch 62/300
# 34/34 [==============================] - 0s 3ms/step - loss: 4.3512 - val_loss: 4.3482
# Epoch 63/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.3286 - val_loss: 4.2972
# Epoch 64/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.2948 - val_loss: 4.2669
# Epoch 65/300
# 34/34 [==============================] - 0s 3ms/step - loss: 4.2666 - val_loss: 4.2356
# Epoch 66/300
# 34/34 [==============================] - 0s 3ms/step - loss: 4.2369 - val_loss: 4.2101
# Epoch 67/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.2098 - val_loss: 4.1850
# Epoch 68/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.1895 - val_loss: 4.1658
# Epoch 69/300
# 34/34 [==============================] - 0s 3ms/step - loss: 4.1658 - val_loss: 4.1430
# Epoch 70/300
# 34/34 [==============================] - 0s 3ms/step - loss: 4.1449 - val_loss: 4.1223
# Epoch 71/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.1221 - val_loss: 4.0907
# Epoch 72/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.0995 - val_loss: 4.0718
# Epoch 73/300
# 34/34 [==============================] - 0s 3ms/step - loss: 4.0781 - val_loss: 4.0623
# Epoch 74/300
# 34/34 [==============================] - 0s 3ms/step - loss: 4.0605 - val_loss: 4.0338
# Epoch 75/300
# 34/34 [==============================] - 0s 3ms/step - loss: 4.0415 - val_loss: 4.0086
# Epoch 76/300
# 34/34 [==============================] - 0s 3ms/step - loss: 4.0205 - val_loss: 3.9980
# Epoch 77/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.0061 - val_loss: 3.9840
# Epoch 78/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.9864 - val_loss: 3.9492
# Epoch 79/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.9723 - val_loss: 3.9426
# Epoch 80/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.9557 - val_loss: 3.9217
# Epoch 81/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.9389 - val_loss: 3.9085
# Epoch 82/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.9227 - val_loss: 3.8899
# Epoch 83/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.9101 - val_loss: 3.8730
# Epoch 84/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.8944 - val_loss: 3.8641
# Epoch 85/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.8843 - val_loss: 3.8495
# Epoch 86/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.8673 - val_loss: 3.8318
# Epoch 87/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.8568 - val_loss: 3.8220
# Epoch 88/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.8439 - val_loss: 3.8106
# Epoch 89/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.8347 - val_loss: 3.8069
# Epoch 90/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.8235 - val_loss: 3.7899
# Epoch 91/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.8078 - val_loss: 3.7723
# Epoch 92/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.7976 - val_loss: 3.7755
# Epoch 93/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.7857 - val_loss: 3.7611
# Epoch 94/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.7755 - val_loss: 3.7500
# Epoch 95/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.7701 - val_loss: 3.7371
# Epoch 96/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.7614 - val_loss: 3.7253
# Epoch 97/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.7415 - val_loss: 3.7137
# Epoch 98/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.7323 - val_loss: 3.7081
# Epoch 99/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.7231 - val_loss: 3.6885
# Epoch 100/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.7149 - val_loss: 3.6765
# Epoch 101/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.7013 - val_loss: 3.6856
# Epoch 102/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.6965 - val_loss: 3.6658
# Epoch 103/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.6801 - val_loss: 3.6578
# Epoch 104/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.6795 - val_loss: 3.6421
# Epoch 105/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.6653 - val_loss: 3.6335
# Epoch 106/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.6549 - val_loss: 3.6165
# Epoch 107/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.6427 - val_loss: 3.6086
# Epoch 108/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.6367 - val_loss: 3.6073
# Epoch 109/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.6292 - val_loss: 3.6058
# Epoch 110/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.6136 - val_loss: 3.5801
# Epoch 111/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.6045 - val_loss: 3.6042
# Epoch 112/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.5985 - val_loss: 3.5667
# Epoch 113/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.5917 - val_loss: 3.5587
# Epoch 114/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.5762 - val_loss: 3.5546
# Epoch 115/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.5722 - val_loss: 3.5359
# Epoch 116/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.5612 - val_loss: 3.5311
# Epoch 117/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.5525 - val_loss: 3.5209
# Epoch 118/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.5391 - val_loss: 3.5025
# Epoch 119/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.5249 - val_loss: 3.4936
# Epoch 120/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.5141 - val_loss: 3.4810
# Epoch 121/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.5031 - val_loss: 3.4638
# Epoch 122/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.4912 - val_loss: 3.4569
# Epoch 123/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.4854 - val_loss: 3.4451
# Epoch 124/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.4645 - val_loss: 3.4221
# Epoch 125/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.4483 - val_loss: 3.4128
# Epoch 126/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.4373 - val_loss: 3.4005
# Epoch 127/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.4202 - val_loss: 3.3799
# Epoch 128/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.4062 - val_loss: 3.3651
# Epoch 129/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.3909 - val_loss: 3.3568
# Epoch 130/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.3817 - val_loss: 3.3412
# Epoch 131/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.3655 - val_loss: 3.3179
# Epoch 132/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.3543 - val_loss: 3.3126
# Epoch 133/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.3359 - val_loss: 3.3148
# Epoch 134/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.3246 - val_loss: 3.2836
# Epoch 135/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.3166 - val_loss: 3.2987
# Epoch 136/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.2919 - val_loss: 3.2539
# Epoch 137/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2902 - val_loss: 3.2469
# Epoch 138/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.2790 - val_loss: 3.2258
# Epoch 139/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.2601 - val_loss: 3.2299
# Epoch 140/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.2499 - val_loss: 3.2134
# Epoch 141/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.2414 - val_loss: 3.2114
# Epoch 142/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.2378 - val_loss: 3.1887
# Epoch 143/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.2257 - val_loss: 3.1817
# Epoch 144/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.2223 - val_loss: 3.1962
# Epoch 145/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.2153 - val_loss: 3.1769
# Epoch 146/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2190 - val_loss: 3.1856
# Epoch 147/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.2236 - val_loss: 3.1842
# Epoch 148/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2077 - val_loss: 3.1793
# Epoch 149/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2145 - val_loss: 3.1845
# Epoch 150/300
# 34/34 [==============================] - 0s 6ms/step - loss: 3.1974 - val_loss: 3.1616
# Epoch 151/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1934 - val_loss: 3.1510
# Epoch 152/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1860 - val_loss: 3.1448
# Epoch 153/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1900 - val_loss: 3.1523
# Epoch 154/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1807 - val_loss: 3.1408
# Epoch 155/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1744 - val_loss: 3.1413
# Epoch 156/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1747 - val_loss: 3.1363
# Epoch 157/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1727 - val_loss: 3.1387
# Epoch 158/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1647 - val_loss: 3.1268
# Epoch 159/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1660 - val_loss: 3.1369
# Epoch 160/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1596 - val_loss: 3.1406
# Epoch 161/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1644 - val_loss: 3.1276
# Epoch 162/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1555 - val_loss: 3.1294
# Epoch 163/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1585 - val_loss: 3.1349
# Epoch 164/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.1489 - val_loss: 3.1244
# Epoch 165/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1472 - val_loss: 3.1198
# Epoch 166/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1493 - val_loss: 3.1318
# Epoch 167/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1377 - val_loss: 3.1121
# Epoch 168/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1398 - val_loss: 3.1180
# Epoch 169/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1392 - val_loss: 3.1311
# Epoch 170/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.1402 - val_loss: 3.1319
# Epoch 171/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.1434 - val_loss: 3.1245
# Epoch 172/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1295 - val_loss: 3.1250
# Epoch 173/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.1433 - val_loss: 3.1101
# Epoch 174/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.1357 - val_loss: 3.1239
# Epoch 175/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1402 - val_loss: 3.1088
# Epoch 176/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1246 - val_loss: 3.1051
# Epoch 177/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1286 - val_loss: 3.1015
# Epoch 178/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1184 - val_loss: 3.1043
# Epoch 179/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1228 - val_loss: 3.1104
# Epoch 180/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.1256 - val_loss: 3.1038
# Epoch 181/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.1138 - val_loss: 3.1370
# Epoch 182/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1273 - val_loss: 3.1190
# Epoch 183/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1156 - val_loss: 3.0989
# Epoch 184/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.1092 - val_loss: 3.1113
# Epoch 185/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1088 - val_loss: 3.0962
# Epoch 186/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1149 - val_loss: 3.1007
# Epoch 187/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1127 - val_loss: 3.0975
# Epoch 188/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.1067 - val_loss: 3.0894
# Epoch 189/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.1018 - val_loss: 3.1086
# Epoch 190/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1016 - val_loss: 3.1082
# Epoch 191/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.1204 - val_loss: 3.0914
# Epoch 192/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.1125 - val_loss: 3.0844
# Epoch 193/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.1033 - val_loss: 3.0911
# Epoch 194/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0952 - val_loss: 3.0900
# Epoch 195/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0916 - val_loss: 3.0887
# Epoch 196/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0916 - val_loss: 3.0992
# Epoch 197/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0903 - val_loss: 3.0875
# Epoch 198/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0921 - val_loss: 3.0898
# Epoch 199/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0935 - val_loss: 3.0798
# Epoch 200/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0987 - val_loss: 3.1190
# Epoch 201/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0986 - val_loss: 3.0752
# Epoch 202/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0868 - val_loss: 3.0888
# Epoch 203/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0967 - val_loss: 3.0747
# Epoch 204/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0868 - val_loss: 3.0933
# Epoch 205/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0861 - val_loss: 3.0738
# Epoch 206/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0861 - val_loss: 3.1084
# Epoch 207/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0827 - val_loss: 3.0995
# Epoch 208/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0914 - val_loss: 3.0744
# Epoch 209/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0871 - val_loss: 3.0666
# Epoch 210/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0777 - val_loss: 3.0757
# Epoch 211/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0870 - val_loss: 3.0679
# Epoch 212/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0752 - val_loss: 3.0640
# Epoch 213/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0784 - val_loss: 3.0624
# Epoch 214/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0820 - val_loss: 3.0874
# Epoch 215/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0736 - val_loss: 3.0672
# Epoch 216/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0745 - val_loss: 3.0710
# Epoch 217/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0769 - val_loss: 3.0654
# Epoch 218/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0792 - val_loss: 3.0770
# Epoch 219/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0726 - val_loss: 3.0680
# Epoch 220/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0755 - val_loss: 3.0713
# Epoch 221/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0684 - val_loss: 3.0822
# Epoch 222/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0689 - val_loss: 3.0587
# Epoch 223/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0639 - val_loss: 3.0534
# Epoch 224/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0588 - val_loss: 3.0643
# Epoch 225/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0623 - val_loss: 3.0605
# Epoch 226/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0621 - val_loss: 3.0515
# Epoch 227/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0697 - val_loss: 3.0807
# Epoch 228/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0631 - val_loss: 3.0527
# Epoch 229/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0630 - val_loss: 3.0574
# Epoch 230/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0602 - val_loss: 3.0713
# Epoch 231/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0598 - val_loss: 3.0548
# Epoch 232/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0580 - val_loss: 3.0553
# Epoch 233/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0571 - val_loss: 3.0599
# Epoch 234/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0540 - val_loss: 3.0462
# Epoch 235/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0573 - val_loss: 3.0427
# Epoch 236/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0598 - val_loss: 3.0508
# Epoch 237/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0579 - val_loss: 3.0489
# Epoch 238/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0667 - val_loss: 3.0436
# Epoch 239/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0500 - val_loss: 3.0324
# Epoch 240/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0563 - val_loss: 3.0606
# Epoch 241/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0539 - val_loss: 3.0442
# Epoch 242/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0505 - val_loss: 3.0457
# Epoch 243/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0539 - val_loss: 3.0411
# Epoch 244/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0496 - val_loss: 3.0604
# Epoch 245/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0485 - val_loss: 3.0349
# Epoch 246/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0456 - val_loss: 3.0444
# Epoch 247/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0457 - val_loss: 3.0477
# Epoch 248/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0407 - val_loss: 3.0521
# Epoch 249/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0440 - val_loss: 3.0431
# Epoch 250/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0525 - val_loss: 3.0718
# Epoch 251/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0568 - val_loss: 3.0346
# Epoch 252/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0386 - val_loss: 3.0380
# Epoch 253/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0470 - val_loss: 3.0451
# Epoch 254/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0415 - val_loss: 3.0241
# Epoch 255/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0413 - val_loss: 3.0415
# Epoch 256/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0426 - val_loss: 3.0417
# Epoch 257/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0379 - val_loss: 3.0257
# Epoch 258/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0385 - val_loss: 3.0259
# Epoch 259/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0444 - val_loss: 3.0277
# Epoch 260/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0316 - val_loss: 3.0281
# Epoch 261/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0382 - val_loss: 3.0198
# Epoch 262/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0308 - val_loss: 3.0289
# Epoch 263/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0368 - val_loss: 3.0371
# Epoch 264/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0311 - val_loss: 3.0230
# Epoch 265/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0362 - val_loss: 3.0320
# Epoch 266/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0375 - val_loss: 3.0337
# Epoch 267/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0343 - val_loss: 3.0140
# Epoch 268/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0323 - val_loss: 3.0111
# Epoch 269/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0343 - val_loss: 3.0180
# Epoch 270/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0335 - val_loss: 3.0105
# Epoch 271/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0302 - val_loss: 3.0085
# Epoch 272/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0270 - val_loss: 3.0201
# Epoch 273/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0270 - val_loss: 3.0179
# Epoch 274/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0249 - val_loss: 3.0078
# Epoch 275/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0237 - val_loss: 3.0273
# Epoch 276/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0529 - val_loss: 3.0365
# Epoch 277/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0337 - val_loss: 3.0209
# Epoch 278/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0236 - val_loss: 3.0180
# Epoch 279/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0209 - val_loss: 3.0108
# Epoch 280/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0215 - val_loss: 3.0205
# Epoch 281/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0194 - val_loss: 3.0238
# Epoch 282/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0199 - val_loss: 3.0163
# Epoch 283/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0179 - val_loss: 2.9956
# Epoch 284/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0205 - val_loss: 3.0101
# Epoch 285/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0181 - val_loss: 3.0052
# Epoch 286/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0246 - val_loss: 3.0146
# Epoch 287/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0189 - val_loss: 3.0109
# Epoch 288/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0188 - val_loss: 3.0025
# Epoch 289/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0188 - val_loss: 2.9983
# Epoch 290/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0207 - val_loss: 3.0011
# Epoch 291/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0145 - val_loss: 3.0181
# Epoch 292/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0135 - val_loss: 3.0052
# Epoch 293/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0170 - val_loss: 3.0029
# Epoch 294/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0144 - val_loss: 3.0060
# Epoch 295/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0098 - val_loss: 3.0024
# Epoch 296/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0153 - val_loss: 2.9967
# Epoch 297/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0070 - val_loss: 2.9929
# Epoch 298/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0113 - val_loss: 2.9894
# Epoch 299/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0074 - val_loss: 3.0007
# Epoch 300/300
# 34/34 [==============================] - 0s 3ms/step - loss: 3.0062 - val_loss: 2.9970

# %% [markdown]
# ### Training and Validation Loss
#
# It's interesting to see how the model trained. We can see that after a certain point improvement in training is rather slow.
#
# For this problem a loss value around 3.0 produces quite good results.

# %%
plt.figure(figsize=(10, 5))
plt.ylim([0,9])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Try out the MDN Model
#
# Now we try out the model by making predictions at 3000 evenly spaced points on the x-axis.
#
# Mixture models output lists of parameters, so we're going to sample from these parameters for each point on the x-axis, and also try plotting the parameters themselves so we can have some insight into what the model is learning!

# %%
## Sample on some test data:
x_test = np.float32(np.arange(-15,15,0.1))
NTEST = x_test.size
print("Testing:", NTEST, "samples.")
x_test = x_test.reshape(NTEST,1) # needs to be a matrix, not a vector

# Make predictions from the model
y_test = model.predict(x_test)
# y_test contains parameters for distributions, not actual points on the graph.
# To find points on the graph, we need to sample from each distribution.

# Split up the mixture parameters (for future fun)
mus = np.apply_along_axis((lambda a: a[:N_MIXES*OUTPUT_DIMS]), 1, y_test)
sigs = np.apply_along_axis((lambda a: a[N_MIXES*OUTPUT_DIMS:2*N_MIXES*OUTPUT_DIMS]), 1, y_test)
pis = np.apply_along_axis((lambda a: mdn.softmax(a[-N_MIXES:])), 1, y_test)

# Sample from the predicted distributions
y_samples = np.apply_along_axis(mdn.sample_from_output, 1, y_test, OUTPUT_DIMS, N_MIXES, temp=1.0, sigma_temp=1.0)
# Out:
# Testing: 300 samples.
# 10/10 [==============================] - 0s 2ms/step

# %%
# Plot the predicted samples.
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_data, y_data, z_data, alpha=0.05, c='r') #c=perf_down_sampled.moving
ax.scatter(y_samples.T[0], y_samples.T[1], x_test, alpha=0.2, c='b') #c=perf_down_sampled.moving
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Plot the means - this gives us some insight into how the model learns to produce the mixtures.
# Cool!

# Plot the predicted samples.
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_data, y_data, z_data, alpha=0.1, c='r') #c=perf_down_sampled.moving
ax.scatter(y_samples.T[0], y_samples.T[1], x_test, alpha=0.1, c='b') #c=perf_down_sampled.moving
for m in range(N_MIXES):
    one_pair = mus[m*OUTPUT_DIMS:(m+1)*OUTPUT_DIMS]
    ax.scatter(mus[:,2*m], mus[:,2*m + 1] , x_test, marker='o',alpha=0.3)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Let's plot the variances and weightings of the means as well.

# Plot the predicted samples.
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_data, y_data, z_data, alpha=0.1, c='r') #c=perf_down_sampled.moving
for m in range(N_MIXES):
    one_pair = mus[m*OUTPUT_DIMS:(m+1)*OUTPUT_DIMS]
    ax.scatter(mus[:,2*m], mus[:,2*m + 1] , x_test, s=100*sigs[:,2*m]*pis[:,m], marker='o',alpha=0.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 9
#       7 for m in range(N_MIXES):
#       8     one_pair = mus[m*OUTPUT_DIMS:(m+1)*OUTPUT_DIMS]
# ----> 9     ax.scatter(mus[:,2*m], mus[:,2*m + 1] , x_test, s=100*sigs[:,2*m]*pis[:,m], marker='o',alpha=0.3)
#      10 plt.show()
#
# File ~/.cache/pypoetry/virtualenvs/keras-mdn-layer-Fodlja9D-py3.11/lib/python3.11/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File ~/.cache/pypoetry/virtualenvs/keras-mdn-layer-Fodlja9D-py3.11/lib/python3.11/site-packages/mpl_toolkits/mplot3d/axes3d.py:2664, in Axes3D.scatter(self, xs, ys, zs, zdir, s, c, depthshade, *args, **kwargs)
#    2661 if np.may_share_memory(zs_orig, zs):  # Avoid unnecessary copies.
#    2662     zs = zs.copy()
# -> 2664 patches = super().scatter(xs, ys, s=s, c=c, *args, **kwargs)
#    2665 art3d.patch_collection_2d_to_3d(patches, zs=zs, zdir=zdir,
#    2666                                 depthshade=depthshade)
#    2668 if self._zmargin < 0.05 and xs.size > 0:
#
# File ~/.cache/pypoetry/virtualenvs/keras-mdn-layer-Fodlja9D-py3.11/lib/python3.11/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File ~/.cache/pypoetry/virtualenvs/keras-mdn-layer-Fodlja9D-py3.11/lib/python3.11/site-packages/matplotlib/axes/_axes.py:4796, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4792 s = np.ma.ravel(s)
#    4793 if (len(s) not in (1, x.size) or
#    4794         (not np.issubdtype(s.dtype, np.floating) and
#    4795          not np.issubdtype(s.dtype, np.integer))):
# -> 4796     raise ValueError(
#    4797         "s must be a scalar, "
#    4798         "or float array-like with the same size as x and y")
#    4800 # get the original edgecolor the user passed before we normalize
#    4801 orig_edgecolor = edgecolors
#
# ValueError: s must be a scalar, or float array-like with the same size as x and y
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Converting to TensorFlow Lite
#
# We will now convert the keras model into a tflite model. This primarily uses boilerplate code which invokes the TFLiteConverter class and writes the generated model to file. This conversion currently outputs a significant amount of arithmetic conversion errors. From other posts online, this seems to be a superficial issue with converting from 32 bit ints to 64 bit ints and does not affect the validity of the conversion.

# %%
# Following code converts high level keras model to a .tflite file 
converter = tf.lite.TFLiteConverter.from_keras_model(model)

tflite_model = converter.convert()
# Saves converted file to this folder
tflite_model_name = '2-2dspiral-lite.tflite'
with open(tflite_model_name, 'wb') as f:
    f.write(tflite_model)

# %% [markdown]
# ## Predicting using the TensorFlow Lite Model
#
# To make predictions using the tflite runtime, we use the interpreter class. Primarily, this is boilerplate code provided from the tensorflow tutorials. Importantly as our has a model dynamic input shape (as indicated by us defining the keras model with a first layer with batch_input_shape=(None, 1)) we must define the input tensor manually using resize_tensor_input. Now, we will test the tflite model on our original training data and compare it to the keras model.

# %%
# Load the TFLite model and allocate tensors.
# Note that it assumes we are loading the model just saved to the current folder
# to interpret from a model we have just generated, use model_content=tflite_model as the parameter instead
interpreter = tf.lite.Interpreter(model_path=tflite_model_name) 

# Resize input shape for dynamic shape model and allocate tensor
interpreter.resize_tensor_input(interpreter.get_input_details()[0]['index'], (NTEST,1))
interpreter.allocate_tensors()

# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Test the model on our defined testing set
interpreter.set_tensor(input_details[0]['index'], x_test)

# Uses the interpreter to make the same predictions as our keras model
interpreter.invoke()

# The function `get_tensor()` returns a copy of the tensor data.
y_test_tflite = interpreter.get_tensor(output_details[0]['index'])


# Sample from the TFLite predicted distributions as done previously
y_samples_tflite = np.apply_along_axis(mdn.sample_from_output, 1, y_test_tflite, 1, N_MIXES, temp=1.0)

# %%
# Plot the predicted samples.
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_data, y_data, z_data, alpha=0.05, c='r') #c=perf_down_sampled.moving
ax.scatter(y_samples_tflite.T[0], y_samples_tflite.T[1], x_test, alpha=0.2, c='b') #c=perf_down_sampled.moving
plt.show()
# The model clearly successfully predicts our dataset.

# %%
# Plot the Keras and TFLite model predictions
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(y_samples.T[0], y_samples.T[1], x_test, alpha=0.2, c='b') #c=perf_down_sampled.moving
ax.scatter(y_samples_tflite.T[0], y_samples_tflite.T[1], x_test, alpha=0.2, c='b') #c=perf_down_sampled.moving
plt.show()
# The models clearly behave quite similarly
