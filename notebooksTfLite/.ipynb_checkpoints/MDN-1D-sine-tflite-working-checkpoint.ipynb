# %% [markdown]
# # Mixture Density Network
#
# Reproducing the classic Bishop MDN network tasks in Keras. The idea in this task is to predict a the value of an inverse sine function. This function has multiple real-valued solutions at each point, so the ANN model needs to have the capacity to handle this in it's loss function. An MDN is a good way to handle the predictions of these multiple output values.
#
# There's a couple of other versions of this task, and this implementation owes much to the following:
#
# - [David Ha - Mixture Density Networks with TensorFlow](http://blog.otoro.net/2015/11/24/mixture-density-networks-with-tensorflow/)
# - [Mixture Density Networks in Edward](http://edwardlib.org/tutorials/mixture-density-network)

# %%
# Normal imports for everybody
from context import * # imports the MDN layer 
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib widget

# Tensorflow is used to convert to tflite
import tensorflow as tf
# Out:
# 2024-06-13 17:26:56.619738: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-13 17:26:56.633282: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-13 17:26:56.733926: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-13 17:26:56.734012: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-13 17:26:56.748084: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-13 17:26:56.792948: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-13 17:26:56.794238: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-13 17:26:57.685223: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Generate Synthetic Data
#
# Data generation

# %%
## Generating some data:
NSAMPLE = 3000

y_data = np.float32(np.random.uniform(-10.5, 10.5, NSAMPLE))
r_data = np.random.normal(size=NSAMPLE)
x_data = np.sin(0.75 * y_data) * 7.0 + y_data * 0.5 + r_data * 1
x_data = x_data.reshape((NSAMPLE, 1))
plt.figure(figsize=(8, 8))
plt.plot(x_data,y_data,'ro', alpha=0.3)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Build the MDN Model
#
# Now we will construct the MDN model in Keras. This uses the `Sequential` model interface in Keras.
#
# The `MDN` layer comes after one or more `Dense` layers. You need to define the output dimension and number of mixtures for the MDN like so: `MDN(output_dimension, number_mixtures)`.
#
# For this problem, we only need an output dimension of 1 as we are predicting one value (y). Adding more mixtures adds a more parameters (model is more complex, takes longer to train), but might help make the solutions better. You can see from the training data that there are at maximum 5 different layers to predict in the curve, so setting `N_MIXES = 5` is a good place to start.
#
# For MDNs, we have to use a special loss function that can handle the mixture parameters: the function has to take into account the number of output dimensions and mixtures.

# %%
N_HIDDEN = 15
N_MIXES = 10

model = keras.Sequential()
model.add(keras.layers.Dense(N_HIDDEN, batch_input_shape=(None, 1), activation='relu'))
model.add(keras.layers.Dense(N_HIDDEN, activation='relu'))
model.add(mdn.MDN(1, N_MIXES))
model.compile(loss=mdn.get_mixture_loss_func(1,N_MIXES), optimizer=keras.optimizers.Adam()) #, metrics=[mdn.get_mixture_mse_accuracy(1,N_MIXES)])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 15)                30
#
#  dense_1 (Dense)             (None, 15)                240
#
#  mdn (MDN)                   (None, 30)                480
#
# =================================================================
# Total params: 750 (2.93 KB)
# Trainable params: 750 (2.93 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Training the model
#
# Now we train the model using Keras' normal `fit` command.

# %%
history = model.fit(x=x_data, y=y_data, batch_size=128, epochs=500, validation_split=0.15)
# Out:
# Epoch 1/500
# 20/20 [==============================] - 4s 48ms/step - loss: 7.5138 - val_loss: 6.4597
# Epoch 2/500
# 20/20 [==============================] - 0s 4ms/step - loss: 6.0000 - val_loss: 5.3739
# Epoch 3/500
# 20/20 [==============================] - 0s 4ms/step - loss: 5.0953 - val_loss: 4.7160
# Epoch 4/500
# 20/20 [==============================] - 0s 3ms/step - loss: 4.5511 - val_loss: 4.3239
# Epoch 5/500
# 20/20 [==============================] - 0s 3ms/step - loss: 4.2139 - val_loss: 4.0508
# Epoch 6/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.9689 - val_loss: 3.8381
# Epoch 7/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.7697 - val_loss: 3.6760
# Epoch 8/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.6124 - val_loss: 3.5411
# Epoch 9/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.4792 - val_loss: 3.4473
# Epoch 10/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.3911 - val_loss: 3.3613
# Epoch 11/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.3261 - val_loss: 3.2982
# Epoch 12/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.2720 - val_loss: 3.2463
# Epoch 13/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.2221 - val_loss: 3.1975
# Epoch 14/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.1818 - val_loss: 3.1517
# Epoch 15/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.1434 - val_loss: 3.1180
# Epoch 16/500
# 20/20 [==============================] - 0s 4ms/step - loss: 3.1082 - val_loss: 3.0810
# Epoch 17/500
# 20/20 [==============================] - 0s 4ms/step - loss: 3.0734 - val_loss: 3.0466
# Epoch 18/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.0466 - val_loss: 3.0233
# Epoch 19/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.0215 - val_loss: 2.9868
# Epoch 20/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.9928 - val_loss: 2.9626
# Epoch 21/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.9591 - val_loss: 2.9147
# Epoch 22/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.9187 - val_loss: 2.8750
# Epoch 23/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.8953 - val_loss: 2.8542
# Epoch 24/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.8800 - val_loss: 2.8341
# Epoch 25/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.8538 - val_loss: 2.8100
# Epoch 26/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.8350 - val_loss: 2.7914
# Epoch 27/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.8163 - val_loss: 2.7706
# Epoch 28/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.8050 - val_loss: 2.7772
# Epoch 29/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.7862 - val_loss: 2.7462
# Epoch 30/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.7642 - val_loss: 2.7330
# Epoch 31/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.7513 - val_loss: 2.7120
# Epoch 32/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.7311 - val_loss: 2.6986
# Epoch 33/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.7174 - val_loss: 2.6839
# Epoch 34/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.7036 - val_loss: 2.6726
# Epoch 35/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.6837 - val_loss: 2.6531
# Epoch 36/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.6696 - val_loss: 2.6423
# Epoch 37/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.6520 - val_loss: 2.6275
# Epoch 38/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.6366 - val_loss: 2.6093
# Epoch 39/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.6132 - val_loss: 2.5905
# Epoch 40/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.5966 - val_loss: 2.5664
# Epoch 41/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.5813 - val_loss: 2.5499
# Epoch 42/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.5541 - val_loss: 2.5354
# Epoch 43/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.5320 - val_loss: 2.5199
# Epoch 44/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.5091 - val_loss: 2.4919
# Epoch 45/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.4805 - val_loss: 2.4636
# Epoch 46/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.4517 - val_loss: 2.4486
# Epoch 47/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.4322 - val_loss: 2.4397
# Epoch 48/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.4048 - val_loss: 2.3962
# Epoch 49/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.3786 - val_loss: 2.3578
# Epoch 50/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.3444 - val_loss: 2.3324
# Epoch 51/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.3202 - val_loss: 2.3375
# Epoch 52/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.3201 - val_loss: 2.3294
# Epoch 53/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.2883 - val_loss: 2.2719
# Epoch 54/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2686 - val_loss: 2.2562
# Epoch 55/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2405 - val_loss: 2.2378
# Epoch 56/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.2233 - val_loss: 2.2131
# Epoch 57/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.2037 - val_loss: 2.2166
# Epoch 58/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.2197 - val_loss: 2.2206
# Epoch 59/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1850 - val_loss: 2.1751
# Epoch 60/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.1776 - val_loss: 2.1405
# Epoch 61/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.1626 - val_loss: 2.1522
# Epoch 62/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1355 - val_loss: 2.1226
# Epoch 63/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1035 - val_loss: 2.1037
# Epoch 64/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.0811 - val_loss: 2.1069
# Epoch 65/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.0766 - val_loss: 2.0765
# Epoch 66/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.0521 - val_loss: 2.0673
# Epoch 67/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.0277 - val_loss: 2.0351
# Epoch 68/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.0147 - val_loss: 2.0228
# Epoch 69/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.0095 - val_loss: 2.0070
# Epoch 70/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.9986 - val_loss: 1.9973
# Epoch 71/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0102 - val_loss: 1.9939
# Epoch 72/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.0135 - val_loss: 1.9929
# Epoch 73/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.9625 - val_loss: 1.9535
# Epoch 74/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.9490 - val_loss: 1.9399
# Epoch 75/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.9441 - val_loss: 1.9265
# Epoch 76/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.9245 - val_loss: 1.9251
# Epoch 77/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.9219 - val_loss: 1.9101
# Epoch 78/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.9072 - val_loss: 1.9031
# Epoch 79/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.9009 - val_loss: 1.9139
# Epoch 80/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.9009 - val_loss: 1.8881
# Epoch 81/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.8918 - val_loss: 1.8938
# Epoch 82/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.9024 - val_loss: 1.8846
# Epoch 83/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.8810 - val_loss: 1.8798
# Epoch 84/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.8643 - val_loss: 1.8716
# Epoch 85/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.8643 - val_loss: 1.8591
# Epoch 86/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.8640 - val_loss: 1.8621
# Epoch 87/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.8536 - val_loss: 1.8578
# Epoch 88/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.8593 - val_loss: 1.8495
# Epoch 89/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.8424 - val_loss: 1.8402
# Epoch 90/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.8406 - val_loss: 1.8515
# Epoch 91/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.8332 - val_loss: 1.8316
# Epoch 92/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.8254 - val_loss: 1.8287
# Epoch 93/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.8229 - val_loss: 1.8252
# Epoch 94/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.8269 - val_loss: 1.8500
# Epoch 95/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.8138 - val_loss: 1.8161
# Epoch 96/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.8122 - val_loss: 1.8073
# Epoch 97/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.8011 - val_loss: 1.8038
# Epoch 98/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7960 - val_loss: 1.8076
# Epoch 99/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7891 - val_loss: 1.7948
# Epoch 100/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.7861 - val_loss: 1.7910
# Epoch 101/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7776 - val_loss: 1.7917
# Epoch 102/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.7710 - val_loss: 1.7854
# Epoch 103/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7664 - val_loss: 1.7714
# Epoch 104/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7601 - val_loss: 1.7945
# Epoch 105/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.7609 - val_loss: 1.7693
# Epoch 106/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.7575 - val_loss: 1.7694
# Epoch 107/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.7493 - val_loss: 1.7777
# Epoch 108/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7651 - val_loss: 1.7939
# Epoch 109/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7596 - val_loss: 1.7731
# Epoch 110/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7427 - val_loss: 1.7528
# Epoch 111/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7409 - val_loss: 1.7611
# Epoch 112/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7427 - val_loss: 1.7581
# Epoch 113/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7381 - val_loss: 1.7607
# Epoch 114/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7363 - val_loss: 1.7713
# Epoch 115/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7321 - val_loss: 1.7453
# Epoch 116/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7258 - val_loss: 1.7407
# Epoch 117/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.7248 - val_loss: 1.7457
# Epoch 118/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.7221 - val_loss: 1.7355
# Epoch 119/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.7167 - val_loss: 1.7404
# Epoch 120/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7180 - val_loss: 1.7392
# Epoch 121/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7181 - val_loss: 1.7363
# Epoch 122/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7120 - val_loss: 1.7359
# Epoch 123/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.7122 - val_loss: 1.7314
# Epoch 124/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7101 - val_loss: 1.7464
# Epoch 125/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7174 - val_loss: 1.7281
# Epoch 126/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7066 - val_loss: 1.7261
# Epoch 127/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7087 - val_loss: 1.7185
# Epoch 128/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7079 - val_loss: 1.7198
# Epoch 129/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7083 - val_loss: 1.7193
# Epoch 130/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7098 - val_loss: 1.7269
# Epoch 131/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7017 - val_loss: 1.7158
# Epoch 132/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6961 - val_loss: 1.7186
# Epoch 133/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6963 - val_loss: 1.7086
# Epoch 134/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.6975 - val_loss: 1.7156
# Epoch 135/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6950 - val_loss: 1.7139
# Epoch 136/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.6914 - val_loss: 1.7237
# Epoch 137/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.6988 - val_loss: 1.7086
# Epoch 138/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6885 - val_loss: 1.7083
# Epoch 139/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6864 - val_loss: 1.7076
# Epoch 140/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6857 - val_loss: 1.7021
# Epoch 141/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6899 - val_loss: 1.6979
# Epoch 142/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6877 - val_loss: 1.6940
# Epoch 143/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6854 - val_loss: 1.6979
# Epoch 144/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6880 - val_loss: 1.6905
# Epoch 145/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6822 - val_loss: 1.6876
# Epoch 146/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6842 - val_loss: 1.7014
# Epoch 147/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6820 - val_loss: 1.6886
# Epoch 148/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6769 - val_loss: 1.7138
# Epoch 149/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6780 - val_loss: 1.6833
# Epoch 150/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6734 - val_loss: 1.6882
# Epoch 151/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6786 - val_loss: 1.6857
# Epoch 152/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6886 - val_loss: 1.6846
# Epoch 153/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6742 - val_loss: 1.6833
# Epoch 154/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6774 - val_loss: 1.7021
# Epoch 155/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6748 - val_loss: 1.6881
# Epoch 156/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6928 - val_loss: 1.6984
# Epoch 157/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6778 - val_loss: 1.6833
# Epoch 158/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6657 - val_loss: 1.6831
# Epoch 159/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6682 - val_loss: 1.6865
# Epoch 160/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6656 - val_loss: 1.6898
# Epoch 161/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.6832 - val_loss: 1.6833
# Epoch 162/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.6670 - val_loss: 1.6868
# Epoch 163/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6622 - val_loss: 1.6695
# Epoch 164/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6602 - val_loss: 1.6735
# Epoch 165/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6636 - val_loss: 1.6874
# Epoch 166/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6573 - val_loss: 1.6698
# Epoch 167/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6592 - val_loss: 1.6666
# Epoch 168/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6571 - val_loss: 1.6737
# Epoch 169/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.6628 - val_loss: 1.6684
# Epoch 170/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6592 - val_loss: 1.6686
# Epoch 171/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6520 - val_loss: 1.6731
# Epoch 172/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6604 - val_loss: 1.6707
# Epoch 173/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6526 - val_loss: 1.6613
# Epoch 174/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6460 - val_loss: 1.6661
# Epoch 175/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6405 - val_loss: 1.6594
# Epoch 176/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6383 - val_loss: 1.6641
# Epoch 177/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6380 - val_loss: 1.6558
# Epoch 178/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6361 - val_loss: 1.6479
# Epoch 179/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6363 - val_loss: 1.6559
# Epoch 180/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6297 - val_loss: 1.6560
# Epoch 181/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6280 - val_loss: 1.6446
# Epoch 182/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6363 - val_loss: 1.6585
# Epoch 183/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6226 - val_loss: 1.6515
# Epoch 184/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6217 - val_loss: 1.6355
# Epoch 185/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6146 - val_loss: 1.6324
# Epoch 186/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6156 - val_loss: 1.6373
# Epoch 187/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6130 - val_loss: 1.6220
# Epoch 188/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6119 - val_loss: 1.6225
# Epoch 189/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6091 - val_loss: 1.6136
# Epoch 190/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6062 - val_loss: 1.6167
# Epoch 191/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6025 - val_loss: 1.6259
# Epoch 192/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6025 - val_loss: 1.6217
# Epoch 193/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6114 - val_loss: 1.6117
# Epoch 194/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6008 - val_loss: 1.6209
# Epoch 195/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6024 - val_loss: 1.5946
# Epoch 196/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5916 - val_loss: 1.5934
# Epoch 197/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5978 - val_loss: 1.5924
# Epoch 198/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5948 - val_loss: 1.5849
# Epoch 199/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5851 - val_loss: 1.5730
# Epoch 200/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5779 - val_loss: 1.5675
# Epoch 201/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5746 - val_loss: 1.5633
# Epoch 202/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5733 - val_loss: 1.5485
# Epoch 203/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5655 - val_loss: 1.5526
# Epoch 204/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5631 - val_loss: 1.5445
# Epoch 205/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5557 - val_loss: 1.5431
# Epoch 206/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5616 - val_loss: 1.5412
# Epoch 207/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5517 - val_loss: 1.5410
# Epoch 208/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5482 - val_loss: 1.5163
# Epoch 209/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5375 - val_loss: 1.5183
# Epoch 210/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5389 - val_loss: 1.5250
# Epoch 211/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5388 - val_loss: 1.5430
# Epoch 212/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5369 - val_loss: 1.5075
# Epoch 213/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5317 - val_loss: 1.5194
# Epoch 214/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5244 - val_loss: 1.5094
# Epoch 215/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5226 - val_loss: 1.5002
# Epoch 216/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5174 - val_loss: 1.4963
# Epoch 217/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5262 - val_loss: 1.4940
# Epoch 218/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5202 - val_loss: 1.5176
# Epoch 219/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5165 - val_loss: 1.4974
# Epoch 220/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5127 - val_loss: 1.4904
# Epoch 221/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5286 - val_loss: 1.4949
# Epoch 222/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5100 - val_loss: 1.4801
# Epoch 223/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5022 - val_loss: 1.4848
# Epoch 224/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5085 - val_loss: 1.4761
# Epoch 225/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5000 - val_loss: 1.4885
# Epoch 226/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4971 - val_loss: 1.4712
# Epoch 227/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4965 - val_loss: 1.4744
# Epoch 228/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4991 - val_loss: 1.4785
# Epoch 229/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4947 - val_loss: 1.4700
# Epoch 230/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4938 - val_loss: 1.4624
# Epoch 231/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4869 - val_loss: 1.4529
# Epoch 232/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4829 - val_loss: 1.4701
# Epoch 233/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4910 - val_loss: 1.4477
# Epoch 234/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4822 - val_loss: 1.4678
# Epoch 235/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4817 - val_loss: 1.4447
# Epoch 236/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4819 - val_loss: 1.4425
# Epoch 237/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4834 - val_loss: 1.4458
# Epoch 238/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4786 - val_loss: 1.4482
# Epoch 239/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4707 - val_loss: 1.4422
# Epoch 240/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4653 - val_loss: 1.4296
# Epoch 241/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4640 - val_loss: 1.4368
# Epoch 242/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4600 - val_loss: 1.4335
# Epoch 243/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4602 - val_loss: 1.4311
# Epoch 244/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4654 - val_loss: 1.4334
# Epoch 245/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4676 - val_loss: 1.4295
# Epoch 246/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4571 - val_loss: 1.4347
# Epoch 247/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4619 - val_loss: 1.4252
# Epoch 248/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4512 - val_loss: 1.4177
# Epoch 249/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4555 - val_loss: 1.4190
# Epoch 250/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4464 - val_loss: 1.4214
# Epoch 251/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4629 - val_loss: 1.4552
# Epoch 252/500
# 20/20 [==============================] - 0s 9ms/step - loss: 1.4610 - val_loss: 1.4175
# Epoch 253/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4402 - val_loss: 1.4239
# Epoch 254/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4505 - val_loss: 1.4162
# Epoch 255/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4410 - val_loss: 1.4291
# Epoch 256/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4468 - val_loss: 1.4107
# Epoch 257/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4439 - val_loss: 1.4053
# Epoch 258/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4395 - val_loss: 1.4035
# Epoch 259/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4332 - val_loss: 1.4073
# Epoch 260/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4403 - val_loss: 1.4360
# Epoch 261/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4404 - val_loss: 1.3933
# Epoch 262/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4288 - val_loss: 1.4003
# Epoch 263/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4316 - val_loss: 1.3999
# Epoch 264/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4327 - val_loss: 1.4043
# Epoch 265/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4274 - val_loss: 1.3983
# Epoch 266/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4245 - val_loss: 1.3892
# Epoch 267/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4207 - val_loss: 1.3830
# Epoch 268/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4257 - val_loss: 1.3928
# Epoch 269/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4320 - val_loss: 1.3914
# Epoch 270/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4218 - val_loss: 1.3964
# Epoch 271/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4230 - val_loss: 1.3898
# Epoch 272/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4163 - val_loss: 1.3834
# Epoch 273/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4234 - val_loss: 1.3920
# Epoch 274/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4153 - val_loss: 1.3812
# Epoch 275/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4186 - val_loss: 1.3831
# Epoch 276/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4132 - val_loss: 1.3709
# Epoch 277/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4098 - val_loss: 1.3797
# Epoch 278/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4111 - val_loss: 1.3748
# Epoch 279/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4071 - val_loss: 1.3686
# Epoch 280/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4041 - val_loss: 1.3734
# Epoch 281/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4090 - val_loss: 1.3765
# Epoch 282/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4086 - val_loss: 1.3779
# Epoch 283/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4094 - val_loss: 1.3729
# Epoch 284/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4037 - val_loss: 1.3829
# Epoch 285/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4012 - val_loss: 1.3730
# Epoch 286/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4060 - val_loss: 1.3646
# Epoch 287/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3953 - val_loss: 1.3634
# Epoch 288/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3950 - val_loss: 1.3645
# Epoch 289/500
# 20/20 [==============================] - 0s 9ms/step - loss: 1.4021 - val_loss: 1.3761
# Epoch 290/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.3981 - val_loss: 1.3582
# Epoch 291/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3952 - val_loss: 1.3561
# Epoch 292/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3977 - val_loss: 1.3549
# Epoch 293/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3912 - val_loss: 1.3613
# Epoch 294/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3925 - val_loss: 1.3542
# Epoch 295/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3885 - val_loss: 1.3641
# Epoch 296/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3971 - val_loss: 1.3473
# Epoch 297/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3918 - val_loss: 1.3540
# Epoch 298/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3898 - val_loss: 1.3475
# Epoch 299/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3837 - val_loss: 1.3488
# Epoch 300/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3844 - val_loss: 1.3578
# Epoch 301/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3906 - val_loss: 1.3525
# Epoch 302/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3853 - val_loss: 1.3532
# Epoch 303/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3864 - val_loss: 1.3495
# Epoch 304/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3898 - val_loss: 1.3476
# Epoch 305/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3840 - val_loss: 1.3458
# Epoch 306/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3843 - val_loss: 1.3499
# Epoch 307/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3823 - val_loss: 1.3385
# Epoch 308/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3848 - val_loss: 1.3527
# Epoch 309/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3802 - val_loss: 1.3506
# Epoch 310/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3817 - val_loss: 1.3402
# Epoch 311/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3775 - val_loss: 1.3527
# Epoch 312/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3821 - val_loss: 1.3352
# Epoch 313/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3796 - val_loss: 1.3357
# Epoch 314/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3910 - val_loss: 1.3370
# Epoch 315/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3849 - val_loss: 1.3375
# Epoch 316/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3704 - val_loss: 1.3416
# Epoch 317/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3744 - val_loss: 1.3418
# Epoch 318/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3825 - val_loss: 1.3379
# Epoch 319/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3697 - val_loss: 1.3429
# Epoch 320/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3694 - val_loss: 1.3378
# Epoch 321/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3724 - val_loss: 1.3354
# Epoch 322/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3762 - val_loss: 1.3334
# Epoch 323/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3688 - val_loss: 1.3318
# Epoch 324/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3731 - val_loss: 1.3484
# Epoch 325/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3698 - val_loss: 1.3390
# Epoch 326/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3693 - val_loss: 1.3439
# Epoch 327/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3664 - val_loss: 1.3380
# Epoch 328/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3653 - val_loss: 1.3310
# Epoch 329/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3691 - val_loss: 1.3423
# Epoch 330/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3695 - val_loss: 1.3361
# Epoch 331/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3682 - val_loss: 1.3351
# Epoch 332/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3667 - val_loss: 1.3366
# Epoch 333/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3640 - val_loss: 1.3263
# Epoch 334/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3643 - val_loss: 1.3585
# Epoch 335/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3735 - val_loss: 1.3420
# Epoch 336/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3635 - val_loss: 1.3383
# Epoch 337/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3694 - val_loss: 1.3309
# Epoch 338/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3663 - val_loss: 1.3336
# Epoch 339/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3704 - val_loss: 1.3796
# Epoch 340/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3738 - val_loss: 1.3380
# Epoch 341/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3726 - val_loss: 1.3476
# Epoch 342/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3686 - val_loss: 1.3397
# Epoch 343/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3641 - val_loss: 1.3317
# Epoch 344/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3642 - val_loss: 1.3454
# Epoch 345/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3726 - val_loss: 1.3423
# Epoch 346/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3660 - val_loss: 1.3279
# Epoch 347/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3748 - val_loss: 1.3329
# Epoch 348/500
# 20/20 [==============================] - 0s 9ms/step - loss: 1.3616 - val_loss: 1.3268
# Epoch 349/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3701 - val_loss: 1.3414
# Epoch 350/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3639 - val_loss: 1.3213
# Epoch 351/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3698 - val_loss: 1.3322
# Epoch 352/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3665 - val_loss: 1.3432
# Epoch 353/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3617 - val_loss: 1.3280
# Epoch 354/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3614 - val_loss: 1.3235
# Epoch 355/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3579 - val_loss: 1.3422
# Epoch 356/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3614 - val_loss: 1.3228
# Epoch 357/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3605 - val_loss: 1.3279
# Epoch 358/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3587 - val_loss: 1.3356
# Epoch 359/500
# 20/20 [==============================] - 0s 9ms/step - loss: 1.3645 - val_loss: 1.3271
# Epoch 360/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3582 - val_loss: 1.3274
# Epoch 361/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3596 - val_loss: 1.3366
# Epoch 362/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3637 - val_loss: 1.3399
# Epoch 363/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3628 - val_loss: 1.3217
# Epoch 364/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3594 - val_loss: 1.3242
# Epoch 365/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3621 - val_loss: 1.3262
# Epoch 366/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3604 - val_loss: 1.3250
# Epoch 367/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3557 - val_loss: 1.3267
# Epoch 368/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3546 - val_loss: 1.3195
# Epoch 369/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3542 - val_loss: 1.3264
# Epoch 370/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3547 - val_loss: 1.3278
# Epoch 371/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3575 - val_loss: 1.3283
# Epoch 372/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3533 - val_loss: 1.3326
# Epoch 373/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3636 - val_loss: 1.3219
# Epoch 374/500
# 20/20 [==============================] - 0s 8ms/step - loss: 1.3643 - val_loss: 1.3242
# Epoch 375/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3605 - val_loss: 1.3188
# Epoch 376/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3551 - val_loss: 1.3223
# Epoch 377/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3583 - val_loss: 1.3273
# Epoch 378/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3525 - val_loss: 1.3266
# Epoch 379/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3524 - val_loss: 1.3195
# Epoch 380/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3517 - val_loss: 1.3189
# Epoch 381/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3534 - val_loss: 1.3238
# Epoch 382/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3514 - val_loss: 1.3223
# Epoch 383/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3564 - val_loss: 1.3246
# Epoch 384/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3581 - val_loss: 1.3158
# Epoch 385/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3478 - val_loss: 1.3422
# Epoch 386/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3555 - val_loss: 1.3229
# Epoch 387/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3559 - val_loss: 1.3181
# Epoch 388/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3583 - val_loss: 1.3234
# Epoch 389/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3561 - val_loss: 1.3094
# Epoch 390/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3556 - val_loss: 1.3257
# Epoch 391/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3539 - val_loss: 1.3151
# Epoch 392/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3612 - val_loss: 1.3265
# Epoch 393/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3532 - val_loss: 1.3185
# Epoch 394/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3518 - val_loss: 1.3178
# Epoch 395/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3508 - val_loss: 1.3150
# Epoch 396/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3505 - val_loss: 1.3307
# Epoch 397/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3486 - val_loss: 1.3100
# Epoch 398/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3474 - val_loss: 1.3191
# Epoch 399/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3477 - val_loss: 1.3286
# Epoch 400/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3579 - val_loss: 1.3241
# Epoch 401/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3515 - val_loss: 1.3160
# Epoch 402/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3534 - val_loss: 1.3149
# Epoch 403/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3492 - val_loss: 1.3199
# Epoch 404/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3552 - val_loss: 1.3127
# Epoch 405/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3517 - val_loss: 1.3302
# Epoch 406/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3516 - val_loss: 1.3177
# Epoch 407/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3519 - val_loss: 1.3172
# Epoch 408/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3578 - val_loss: 1.3269
# Epoch 409/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3564 - val_loss: 1.3119
# Epoch 410/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3507 - val_loss: 1.3220
# Epoch 411/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3429 - val_loss: 1.3286
# Epoch 412/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3456 - val_loss: 1.3124
# Epoch 413/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3510 - val_loss: 1.3172
# Epoch 414/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3482 - val_loss: 1.3164
# Epoch 415/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3441 - val_loss: 1.3211
# Epoch 416/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3470 - val_loss: 1.3145
# Epoch 417/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3442 - val_loss: 1.3157
# Epoch 418/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3449 - val_loss: 1.3143
# Epoch 419/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3444 - val_loss: 1.3189
# Epoch 420/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3472 - val_loss: 1.3089
# Epoch 421/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3445 - val_loss: 1.3200
# Epoch 422/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3503 - val_loss: 1.3062
# Epoch 423/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3424 - val_loss: 1.3223
# Epoch 424/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3492 - val_loss: 1.3141
# Epoch 425/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3484 - val_loss: 1.3146
# Epoch 426/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3451 - val_loss: 1.3162
# Epoch 427/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3440 - val_loss: 1.3197
# Epoch 428/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3471 - val_loss: 1.3170
# Epoch 429/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3436 - val_loss: 1.3081
# Epoch 430/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3478 - val_loss: 1.3140
# Epoch 431/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3444 - val_loss: 1.3108
# Epoch 432/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3436 - val_loss: 1.3126
# Epoch 433/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3567 - val_loss: 1.3205
# Epoch 434/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3441 - val_loss: 1.3180
# Epoch 435/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3482 - val_loss: 1.3145
# Epoch 436/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3502 - val_loss: 1.3083
# Epoch 437/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3411 - val_loss: 1.3086
# Epoch 438/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3434 - val_loss: 1.3128
# Epoch 439/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.3462 - val_loss: 1.3124
# Epoch 440/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3450 - val_loss: 1.3135
# Epoch 441/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3462 - val_loss: 1.3202
# Epoch 442/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3468 - val_loss: 1.3178
# Epoch 443/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3422 - val_loss: 1.3050
# Epoch 444/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3407 - val_loss: 1.3194
# Epoch 445/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3435 - val_loss: 1.3125
# Epoch 446/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3505 - val_loss: 1.3095
# Epoch 447/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3388 - val_loss: 1.3237
# Epoch 448/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3464 - val_loss: 1.3120
# Epoch 449/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3389 - val_loss: 1.3123
# Epoch 450/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3419 - val_loss: 1.3320
# Epoch 451/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3481 - val_loss: 1.3133
# Epoch 452/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3420 - val_loss: 1.3102
# Epoch 453/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3418 - val_loss: 1.3155
# Epoch 454/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3389 - val_loss: 1.3084
# Epoch 455/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3425 - val_loss: 1.3129
# Epoch 456/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3485 - val_loss: 1.3375
# Epoch 457/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3441 - val_loss: 1.3046
# Epoch 458/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3405 - val_loss: 1.3091
# Epoch 459/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3406 - val_loss: 1.3108
# Epoch 460/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3395 - val_loss: 1.3150
# Epoch 461/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3523 - val_loss: 1.3104
# Epoch 462/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3383 - val_loss: 1.3288
# Epoch 463/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3486 - val_loss: 1.3090
# Epoch 464/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3433 - val_loss: 1.3128
# Epoch 465/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3387 - val_loss: 1.3061
# Epoch 466/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3448 - val_loss: 1.3353
# Epoch 467/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3515 - val_loss: 1.3281
# Epoch 468/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3425 - val_loss: 1.3125
# Epoch 469/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3457 - val_loss: 1.3086
# Epoch 470/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3422 - val_loss: 1.3109
# Epoch 471/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3506 - val_loss: 1.3157
# Epoch 472/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3432 - val_loss: 1.3247
# Epoch 473/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3464 - val_loss: 1.3105
# Epoch 474/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3375 - val_loss: 1.3100
# Epoch 475/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3395 - val_loss: 1.3103
# Epoch 476/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3413 - val_loss: 1.3132
# Epoch 477/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3409 - val_loss: 1.3220
# Epoch 478/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3389 - val_loss: 1.3137
# Epoch 479/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3391 - val_loss: 1.3063
# Epoch 480/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3316 - val_loss: 1.3087
# Epoch 481/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3418 - val_loss: 1.3423
# Epoch 482/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3685 - val_loss: 1.3192
# Epoch 483/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3393 - val_loss: 1.3074
# Epoch 484/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3383 - val_loss: 1.3113
# Epoch 485/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3475 - val_loss: 1.3238
# Epoch 486/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3442 - val_loss: 1.3172
# Epoch 487/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3452 - val_loss: 1.3153
# Epoch 488/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3388 - val_loss: 1.3086
# Epoch 489/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3378 - val_loss: 1.3110
# Epoch 490/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3371 - val_loss: 1.3083
# Epoch 491/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3332 - val_loss: 1.3081
# Epoch 492/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3340 - val_loss: 1.3043
# Epoch 493/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3361 - val_loss: 1.3073
# Epoch 494/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3350 - val_loss: 1.3135
# Epoch 495/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3389 - val_loss: 1.3321
# Epoch 496/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3459 - val_loss: 1.3349
# Epoch 497/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3415 - val_loss: 1.3120
# Epoch 498/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3374 - val_loss: 1.3122
# Epoch 499/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3372 - val_loss: 1.3175
# Epoch 500/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3340 - val_loss: 1.3121

# %% [markdown]
# ### Training and Validation Loss
#
# It's interesting to see how the model trained. We can see that after a certain point training is rather slow.
#
# For this problem a loss value around 1.5 produces quite good results.

# %%
plt.figure(figsize=(10, 5))
plt.ylim([0,9])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Sampling Functions
#
# The MDN model outputs parameters of a mixture model---a list of means (mu), variances (sigma), and weights (pi).
#
# The `mdn` module provides a function to sample from these parameters as follows. First the parameters are split up into `mu`s, `sigma`s and `pi`s, then the categorical distribution formed by the `pi`s is sampled to choose which mixture component should be sampled, then that component's `mu`s and `sigma`s is used to sample from a multivariate normal model, here's the code:
#
#     def sample_from_output(params, output_dim, num_mixes, temp=1.0):
#         """Sample from an MDN output with temperature adjustment."""
#         mus = params[:num_mixes*output_dim]
#         sigs = params[num_mixes*output_dim:2*num_mixes*output_dim]
#         pis = softmax(params[-num_mixes:], t=temp)
#         m = sample_from_categorical(pis)
#         # Alternative way to sample from categorical:
#         # m = np.random.choice(range(len(pis)), p=pis)
#         mus_vector = mus[m*output_dim:(m+1)*output_dim]
#         sig_vector = sigs[m*output_dim:(m+1)*output_dim] * temp  # adjust for temperature
#         cov_matrix = np.identity(output_dim) * sig_vector
#         sample = np.random.multivariate_normal(mus_vector, cov_matrix, 1)
#         return sample
#
# If you only have one prediction to sample from, you can use the function as is; but if you need to sample from a lot of predictions at once (as in the following sections), you can use `np.apply_along_axis` to apply it to a whole numpy array of predicted parameters.

# %% [markdown]
# ## Try out the MDN Model
#
# Now we try out the model by making predictions at 3000 evenly spaced points on the x-axis.
#
# Mixture models output lists of parameters, so we're going to sample from these parameters for each point on the x-axis, and also try plotting the parameters themselves so we can have some insight into what the model is learning!

# %%
## Sample on some test data:
x_test = np.float32(np.arange(-15,15,0.01))
NTEST = x_test.size
print("Testing:", NTEST, "samples.")
x_test = x_test.reshape(NTEST,1) # needs to be a matrix, not a vector

# Make predictions from the model
y_test = model.predict(x_test)
# y_test contains parameters for distributions, not actual points on the graph.
# To find points on the graph, we need to sample from each distribution.

# Sample from the predicted distributions
y_samples = np.apply_along_axis(mdn.sample_from_output, 1, y_test, 1, N_MIXES,temp=1.0)

# Split up the mixture parameters (for future fun)
mus = np.apply_along_axis((lambda a: a[:N_MIXES]),1, y_test)
sigs = np.apply_along_axis((lambda a: a[N_MIXES:2*N_MIXES]),1, y_test)
pis = np.apply_along_axis((lambda a: mdn.softmax(a[2*N_MIXES:])),1, y_test)
# Out:
# Testing: 3000 samples.
# 94/94 [==============================] - 0s 982us/step

# %%
# Plot the samples
plt.figure(figsize=(8, 8))
plt.plot(x_data,y_data,'ro', x_test, y_samples[:,:,0], 'bo',alpha=0.3)
plt.show()
# These look pretty good!
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Plot the means - this gives us some insight into how the model learns to produce the mixtures.
plt.figure(figsize=(8, 8))
plt.plot(x_data,y_data,'ro', x_test, mus,'bo',alpha=0.3)
plt.show()
# Cool!
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Let's plot the variances and weightings of the means as well.
fig = plt.figure(figsize=(8, 8))
ax1 = fig.add_subplot(111)
# ax1.scatter(data[0], data[1], marker='o', c='b', s=data[2], label='the data')
ax1.scatter(x_data,y_data,marker='o', c='r', alpha=0.3)
for i in range(N_MIXES):
    ax1.scatter(x_test, mus[:,i], marker='o', s=200*sigs[:,i]*pis[:,i],alpha=0.3)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Should be a markdown text box talking about the conversion

# %%
# Following code converts high level keras model to a .tflite file 
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# converter.optimizations = [tf.lite.Optimize.DEFAULT]
"""converter.target_spec.supported_ops = [
tf.lite.OpsSet.TFLITE_BUILTINS, # enable TensorFlow Lite ops.
tf.lite.OpsSet.SELECT_TF_OPS, # enable TensorFlow ops.   
]"""
tflite_model = converter.convert()
# Saves converted file to this folder
tflite_model_name = '1-sineprediction-lite.tflite'
with open(tflite_model_name, 'wb') as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp35wlutdd/assets
# INFO:tensorflow:Assets written to: /tmp/tmp35wlutdd/assets
# 2024-06-13 17:27:41.857211: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2024-06-13 17:27:41.857254: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2024-06-13 17:27:41.857904: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmp35wlutdd
# 2024-06-13 17:27:41.858733: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2024-06-13 17:27:41.858744: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmp35wlutdd
# 2024-06-13 17:27:41.861983: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# 2024-06-13 17:27:41.862676: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2024-06-13 17:27:41.905984: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmp35wlutdd
# 2024-06-13 17:27:41.916737: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 58809 microseconds.
# 2024-06-13 17:27:41.950840: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 11, Total Ops 22, % non-converted = 50.00 %
#  * 11 ARITH ops
#
# - arith.constant:   11 occurrences  (f32: 11)
#
#
#
#   (f32: 1)
#   (f32: 1)
#   (f32: 1)
#   (f32: 5)

# %%
# Load the TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter(model_content=tflite_model)

# Resize input shape for dynamic shape model and allocate tensor
# This is important as our model had a dynamic input shape
interpreter.resize_tensor_input(interpreter.get_input_details()[0]['index'],  (NTEST,1))
interpreter.allocate_tensors()

# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Test the model on our previous dataset
interpreter.set_tensor(input_details[0]['index'], x_test)

# Runs predictions using the interpreter
interpreter.invoke()

# The function `get_tensor()` returns a copy of the tensor data.
y_test_tflite = interpreter.get_tensor(output_details[0]['index'])
print(y_test_tflite)


# Sample from the TFLite predicted distributions
y_samples_tflite = np.apply_along_axis(mdn.sample_from_output, 1, y_test_tflite, 1, N_MIXES, temp=1.0)
# Out:
# [[-10.947128    5.206449   -5.7571483 ...  -2.9328766  -6.724842
#    -9.407207 ]
#  [-10.941992    5.202906   -5.7538824 ...  -2.9317312  -6.7207184
#    -9.399598 ]
#  [-10.936855    5.1993628  -5.750616  ...  -2.9305863  -6.7165947
#    -9.391989 ]
#  ...
#  [ -2.4550629  -7.882145   -9.216926  ...   1.9230683  -8.071507
#    -3.6503816]
#  [ -2.4529493  -7.8859243  -9.220903  ...   1.925169   -8.075388
#    -3.652664 ]
#  [ -2.4508357  -7.8897038  -9.22488   ...   1.9272702  -8.079269
#    -3.6549468]]

# %%
# Plot the Keras and TFLite model predictions
plt.figure(figsize=(8, 8))

plt.plot(x_test, y_samples[:,:,0], 'bo', label='Keras MDN', alpha=0.3)
plt.plot(x_test, y_samples_tflite[:,:,0], 'go', label='TFLite MDN', alpha=0.3)
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
