# %% [markdown]
# # Mixture Density Network
#
# Reproducing the classic Bishop MDN network tasks in Keras. The idea in this task is to predict a the value of an inverse sine function. This function has multiple real-valued solutions at each point, so the ANN model needs to have the capacity to handle this in it's loss function. An MDN is a good way to handle the predictions of these multiple output values.
#
# There's a couple of other versions of this task, and this implementation owes much to the following:
#
# - [David Ha - Mixture Density Networks with TensorFlow](http://blog.otoro.net/2015/11/24/mixture-density-networks-with-tensorflow/)
# - [Mixture Density Networks in Edward](http://edwardlib.org/tutorials/mixture-density-network)

# %%
# Normal imports for everybody
from context import * # imports the MDN layer 
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib widget

# Tensorflow is used to convert to tflite
import tensorflow as tf
# Out:
# 2024-06-13 17:42:20.521760: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-13 17:42:20.525438: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-13 17:42:20.560243: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-13 17:42:20.560276: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-13 17:42:20.562176: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-13 17:42:20.570313: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-13 17:42:20.571664: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-13 17:42:21.192176: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Generate Synthetic Data
#
# Data generation

# %%
## Generating some data:
NSAMPLE = 3000

y_data = np.float32(np.random.uniform(-10.5, 10.5, NSAMPLE))
r_data = np.random.normal(size=NSAMPLE)
x_data = np.sin(0.75 * y_data) * 7.0 + y_data * 0.5 + r_data * 1
x_data = x_data.reshape((NSAMPLE, 1))
plt.figure(figsize=(8, 8))
plt.plot(x_data,y_data,'ro', alpha=0.3)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Build the MDN Model
#
# Now we will construct the MDN model in Keras. This uses the `Sequential` model interface in Keras.
#
# The `MDN` layer comes after one or more `Dense` layers. You need to define the output dimension and number of mixtures for the MDN like so: `MDN(output_dimension, number_mixtures)`.
#
# For this problem, we only need an output dimension of 1 as we are predicting one value (y). Adding more mixtures adds a more parameters (model is more complex, takes longer to train), but might help make the solutions better. You can see from the training data that there are at maximum 5 different layers to predict in the curve, so setting `N_MIXES = 5` is a good place to start.
#
# For MDNs, we have to use a special loss function that can handle the mixture parameters: the function has to take into account the number of output dimensions and mixtures.

# %%
N_HIDDEN = 15
N_MIXES = 10

model = keras.Sequential()
model.add(keras.layers.Dense(N_HIDDEN, batch_input_shape=(None, 1), activation='relu'))
model.add(keras.layers.Dense(N_HIDDEN, activation='relu'))
model.add(mdn.MDN(1, N_MIXES))
model.compile(loss=mdn.get_mixture_loss_func(1,N_MIXES), optimizer=keras.optimizers.Adam()) #, metrics=[mdn.get_mixture_mse_accuracy(1,N_MIXES)])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 15)                30
#
#  dense_1 (Dense)             (None, 15)                240
#
#  mdn (MDN)                   (None, 30)                480
#
# =================================================================
# Total params: 750 (2.93 KB)
# Trainable params: 750 (2.93 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Training the model
#
# Now we train the model using Keras' normal `fit` command.

# %%
history = model.fit(x=x_data, y=y_data, batch_size=128, epochs=500, validation_split=0.15)
# Out:
# Epoch 1/500
# 20/20 [==============================] - 4s 44ms/step - loss: 5.9720 - val_loss: 5.0632
# Epoch 2/500
# 20/20 [==============================] - 0s 3ms/step - loss: 4.9523 - val_loss: 4.3665
# Epoch 3/500
# 20/20 [==============================] - 0s 3ms/step - loss: 4.4034 - val_loss: 4.0043
# Epoch 4/500
# 20/20 [==============================] - 0s 3ms/step - loss: 4.0802 - val_loss: 3.7748
# Epoch 5/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.8591 - val_loss: 3.6110
# Epoch 6/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.6947 - val_loss: 3.4963
# Epoch 7/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.5671 - val_loss: 3.4025
# Epoch 8/500
# 20/20 [==============================] - 0s 4ms/step - loss: 3.4663 - val_loss: 3.3332
# Epoch 9/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.3892 - val_loss: 3.2726
# Epoch 10/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.3220 - val_loss: 3.2227
# Epoch 11/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.2670 - val_loss: 3.1773
# Epoch 12/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.2225 - val_loss: 3.1415
# Epoch 13/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.1802 - val_loss: 3.1023
# Epoch 14/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.1427 - val_loss: 3.0626
# Epoch 15/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.1051 - val_loss: 3.0233
# Epoch 16/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.0667 - val_loss: 2.9931
# Epoch 17/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.0426 - val_loss: 2.9657
# Epoch 18/500
# 20/20 [==============================] - 0s 3ms/step - loss: 3.0138 - val_loss: 2.9474
# Epoch 19/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.9911 - val_loss: 2.9281
# Epoch 20/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.9645 - val_loss: 2.9041
# Epoch 21/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.9398 - val_loss: 2.8811
# Epoch 22/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.9044 - val_loss: 2.8522
# Epoch 23/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.8721 - val_loss: 2.8221
# Epoch 24/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.8416 - val_loss: 2.7994
# Epoch 25/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.8079 - val_loss: 2.7641
# Epoch 26/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.7721 - val_loss: 2.7338
# Epoch 27/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.7315 - val_loss: 2.6930
# Epoch 28/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.6847 - val_loss: 2.6566
# Epoch 29/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.6358 - val_loss: 2.6175
# Epoch 30/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.5829 - val_loss: 2.5814
# Epoch 31/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.5364 - val_loss: 2.5588
# Epoch 32/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.5036 - val_loss: 2.5229
# Epoch 33/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.4670 - val_loss: 2.5120
# Epoch 34/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.4366 - val_loss: 2.4753
# Epoch 35/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.4110 - val_loss: 2.4492
# Epoch 36/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.3787 - val_loss: 2.4175
# Epoch 37/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.3431 - val_loss: 2.3902
# Epoch 38/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.3181 - val_loss: 2.3578
# Epoch 39/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2920 - val_loss: 2.3364
# Epoch 40/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.2571 - val_loss: 2.2985
# Epoch 41/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.2236 - val_loss: 2.2632
# Epoch 42/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1804 - val_loss: 2.2061
# Epoch 43/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1546 - val_loss: 2.1932
# Epoch 44/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1476 - val_loss: 2.2013
# Epoch 45/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1222 - val_loss: 2.1590
# Epoch 46/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1093 - val_loss: 2.1651
# Epoch 47/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1025 - val_loss: 2.1498
# Epoch 48/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.0839 - val_loss: 2.1808
# Epoch 49/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.1015 - val_loss: 2.1431
# Epoch 50/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.0706 - val_loss: 2.1168
# Epoch 51/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.0695 - val_loss: 2.1241
# Epoch 52/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.0575 - val_loss: 2.1548
# Epoch 53/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.0422 - val_loss: 2.1290
# Epoch 54/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.0363 - val_loss: 2.0951
# Epoch 55/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.0224 - val_loss: 2.1099
# Epoch 56/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.0116 - val_loss: 2.0713
# Epoch 57/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.0061 - val_loss: 2.1220
# Epoch 58/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.0058 - val_loss: 2.0636
# Epoch 59/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.9820 - val_loss: 2.0619
# Epoch 60/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.9743 - val_loss: 2.0383
# Epoch 61/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.9863 - val_loss: 2.0788
# Epoch 62/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.9700 - val_loss: 2.0480
# Epoch 63/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.9466 - val_loss: 2.0409
# Epoch 64/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.9383 - val_loss: 1.9836
# Epoch 65/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.9205 - val_loss: 2.0132
# Epoch 66/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.9170 - val_loss: 1.9805
# Epoch 67/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.9021 - val_loss: 1.9510
# Epoch 68/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.9127 - val_loss: 1.9394
# Epoch 69/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.8852 - val_loss: 1.9456
# Epoch 70/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.8631 - val_loss: 1.9057
# Epoch 71/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.8617 - val_loss: 1.8998
# Epoch 72/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.8575 - val_loss: 1.9141
# Epoch 73/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.8365 - val_loss: 1.9023
# Epoch 74/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.8203 - val_loss: 1.9027
# Epoch 75/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.8124 - val_loss: 1.8383
# Epoch 76/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7952 - val_loss: 1.8358
# Epoch 77/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7728 - val_loss: 1.8393
# Epoch 78/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7709 - val_loss: 1.8345
# Epoch 79/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7559 - val_loss: 1.8487
# Epoch 80/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7514 - val_loss: 1.7994
# Epoch 81/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7296 - val_loss: 1.7904
# Epoch 82/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7445 - val_loss: 1.7826
# Epoch 83/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7199 - val_loss: 1.7682
# Epoch 84/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.7055 - val_loss: 1.7733
# Epoch 85/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6933 - val_loss: 1.7450
# Epoch 86/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6868 - val_loss: 1.7275
# Epoch 87/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6786 - val_loss: 1.7046
# Epoch 88/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6822 - val_loss: 1.7290
# Epoch 89/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6717 - val_loss: 1.7152
# Epoch 90/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6488 - val_loss: 1.7092
# Epoch 91/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6489 - val_loss: 1.7394
# Epoch 92/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6719 - val_loss: 1.6574
# Epoch 93/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6318 - val_loss: 1.6703
# Epoch 94/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6253 - val_loss: 1.6922
# Epoch 95/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6308 - val_loss: 1.6201
# Epoch 96/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5983 - val_loss: 1.6448
# Epoch 97/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5903 - val_loss: 1.6190
# Epoch 98/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5904 - val_loss: 1.6404
# Epoch 99/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5915 - val_loss: 1.6154
# Epoch 100/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5853 - val_loss: 1.5818
# Epoch 101/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5665 - val_loss: 1.5709
# Epoch 102/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5628 - val_loss: 1.5857
# Epoch 103/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5467 - val_loss: 1.6264
# Epoch 104/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5349 - val_loss: 1.5691
# Epoch 105/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5383 - val_loss: 1.5543
# Epoch 106/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5315 - val_loss: 1.5891
# Epoch 107/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5188 - val_loss: 1.5627
# Epoch 108/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5019 - val_loss: 1.5181
# Epoch 109/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4940 - val_loss: 1.5446
# Epoch 110/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4836 - val_loss: 1.5550
# Epoch 111/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4885 - val_loss: 1.5093
# Epoch 112/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4724 - val_loss: 1.5286
# Epoch 113/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4790 - val_loss: 1.5016
# Epoch 114/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4732 - val_loss: 1.5013
# Epoch 115/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4712 - val_loss: 1.5023
# Epoch 116/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4617 - val_loss: 1.5166
# Epoch 117/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4704 - val_loss: 1.4890
# Epoch 118/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4531 - val_loss: 1.4720
# Epoch 119/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4459 - val_loss: 1.4873
# Epoch 120/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4456 - val_loss: 1.4732
# Epoch 121/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4335 - val_loss: 1.4677
# Epoch 122/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4416 - val_loss: 1.4834
# Epoch 123/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4345 - val_loss: 1.4661
# Epoch 124/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4359 - val_loss: 1.4812
# Epoch 125/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4307 - val_loss: 1.4621
# Epoch 126/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4244 - val_loss: 1.4491
# Epoch 127/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4371 - val_loss: 1.4555
# Epoch 128/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4387 - val_loss: 1.4788
# Epoch 129/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4210 - val_loss: 1.4498
# Epoch 130/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4220 - val_loss: 1.4448
# Epoch 131/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4158 - val_loss: 1.4428
# Epoch 132/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4106 - val_loss: 1.4553
# Epoch 133/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4147 - val_loss: 1.4353
# Epoch 134/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4132 - val_loss: 1.4416
# Epoch 135/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4092 - val_loss: 1.4608
# Epoch 136/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4123 - val_loss: 1.4416
# Epoch 137/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4108 - val_loss: 1.4400
# Epoch 138/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4089 - val_loss: 1.4434
# Epoch 139/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4095 - val_loss: 1.4476
# Epoch 140/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4156 - val_loss: 1.4538
# Epoch 141/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4034 - val_loss: 1.4333
# Epoch 142/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3985 - val_loss: 1.4302
# Epoch 143/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3973 - val_loss: 1.4235
# Epoch 144/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4107 - val_loss: 1.4488
# Epoch 145/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4033 - val_loss: 1.4668
# Epoch 146/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4020 - val_loss: 1.4330
# Epoch 147/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3952 - val_loss: 1.4303
# Epoch 148/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4018 - val_loss: 1.4315
# Epoch 149/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4008 - val_loss: 1.4364
# Epoch 150/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3940 - val_loss: 1.4292
# Epoch 151/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3947 - val_loss: 1.4253
# Epoch 152/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3966 - val_loss: 1.4587
# Epoch 153/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3957 - val_loss: 1.4264
# Epoch 154/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3951 - val_loss: 1.4287
# Epoch 155/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4028 - val_loss: 1.4291
# Epoch 156/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3934 - val_loss: 1.4414
# Epoch 157/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3898 - val_loss: 1.4270
# Epoch 158/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3852 - val_loss: 1.4402
# Epoch 159/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3855 - val_loss: 1.4617
# Epoch 160/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4014 - val_loss: 1.4182
# Epoch 161/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3889 - val_loss: 1.4394
# Epoch 162/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3895 - val_loss: 1.4324
# Epoch 163/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3815 - val_loss: 1.4760
# Epoch 164/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3886 - val_loss: 1.4258
# Epoch 165/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3981 - val_loss: 1.4373
# Epoch 166/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3907 - val_loss: 1.4401
# Epoch 167/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3894 - val_loss: 1.4232
# Epoch 168/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3860 - val_loss: 1.4358
# Epoch 169/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3926 - val_loss: 1.4363
# Epoch 170/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3968 - val_loss: 1.4212
# Epoch 171/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3940 - val_loss: 1.4147
# Epoch 172/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3810 - val_loss: 1.4100
# Epoch 173/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3884 - val_loss: 1.4615
# Epoch 174/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3868 - val_loss: 1.4124
# Epoch 175/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3811 - val_loss: 1.4105
# Epoch 176/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.3819 - val_loss: 1.4391
# Epoch 177/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3826 - val_loss: 1.4204
# Epoch 178/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3910 - val_loss: 1.4300
# Epoch 179/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3855 - val_loss: 1.4328
# Epoch 180/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3851 - val_loss: 1.4179
# Epoch 181/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3797 - val_loss: 1.4302
# Epoch 182/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3851 - val_loss: 1.4144
# Epoch 183/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3785 - val_loss: 1.4205
# Epoch 184/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3754 - val_loss: 1.4259
# Epoch 185/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3862 - val_loss: 1.4092
# Epoch 186/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.3826 - val_loss: 1.4616
# Epoch 187/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3967 - val_loss: 1.4157
# Epoch 188/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3997 - val_loss: 1.4262
# Epoch 189/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3805 - val_loss: 1.4140
# Epoch 190/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3789 - val_loss: 1.4408
# Epoch 191/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3765 - val_loss: 1.4391
# Epoch 192/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3756 - val_loss: 1.4077
# Epoch 193/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3733 - val_loss: 1.4140
# Epoch 194/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3845 - val_loss: 1.4758
# Epoch 195/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3906 - val_loss: 1.4240
# Epoch 196/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3746 - val_loss: 1.4125
# Epoch 197/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3737 - val_loss: 1.4331
# Epoch 198/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3724 - val_loss: 1.4089
# Epoch 199/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3746 - val_loss: 1.4264
# Epoch 200/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3784 - val_loss: 1.4068
# Epoch 201/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3828 - val_loss: 1.4228
# Epoch 202/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3774 - val_loss: 1.4063
# Epoch 203/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3690 - val_loss: 1.4040
# Epoch 204/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3759 - val_loss: 1.4128
# Epoch 205/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3728 - val_loss: 1.4560
# Epoch 206/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3745 - val_loss: 1.4350
# Epoch 207/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3759 - val_loss: 1.4191
# Epoch 208/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3730 - val_loss: 1.4071
# Epoch 209/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3639 - val_loss: 1.4233
# Epoch 210/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3680 - val_loss: 1.4161
# Epoch 211/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3601 - val_loss: 1.4353
# Epoch 212/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3795 - val_loss: 1.4138
# Epoch 213/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3683 - val_loss: 1.4063
# Epoch 214/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3707 - val_loss: 1.4271
# Epoch 215/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3756 - val_loss: 1.4466
# Epoch 216/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3804 - val_loss: 1.4386
# Epoch 217/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3789 - val_loss: 1.4325
# Epoch 218/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3754 - val_loss: 1.4347
# Epoch 219/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3706 - val_loss: 1.4215
# Epoch 220/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3694 - val_loss: 1.4080
# Epoch 221/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3619 - val_loss: 1.4351
# Epoch 222/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.3678 - val_loss: 1.4295
# Epoch 223/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3784 - val_loss: 1.4238
# Epoch 224/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3708 - val_loss: 1.4294
# Epoch 225/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3675 - val_loss: 1.4095
# Epoch 226/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3689 - val_loss: 1.4337
# Epoch 227/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3604 - val_loss: 1.4288
# Epoch 228/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3661 - val_loss: 1.4191
# Epoch 229/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3648 - val_loss: 1.4083
# Epoch 230/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3563 - val_loss: 1.4489
# Epoch 231/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3619 - val_loss: 1.4109
# Epoch 232/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3672 - val_loss: 1.4061
# Epoch 233/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.3588 - val_loss: 1.4024
# Epoch 234/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3588 - val_loss: 1.4131
# Epoch 235/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3702 - val_loss: 1.4131
# Epoch 236/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3586 - val_loss: 1.4160
# Epoch 237/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3615 - val_loss: 1.4584
# Epoch 238/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3763 - val_loss: 1.4047
# Epoch 239/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3724 - val_loss: 1.4367
# Epoch 240/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3623 - val_loss: 1.4364
# Epoch 241/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3651 - val_loss: 1.4310
# Epoch 242/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3614 - val_loss: 1.4028
# Epoch 243/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3586 - val_loss: 1.4212
# Epoch 244/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3626 - val_loss: 1.4158
# Epoch 245/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.3659 - val_loss: 1.4073
# Epoch 246/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3553 - val_loss: 1.4303
# Epoch 247/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3615 - val_loss: 1.4193
# Epoch 248/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3553 - val_loss: 1.4380
# Epoch 249/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3654 - val_loss: 1.4168
# Epoch 250/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3606 - val_loss: 1.4045
# Epoch 251/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3544 - val_loss: 1.4133
# Epoch 252/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3607 - val_loss: 1.4123
# Epoch 253/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3606 - val_loss: 1.4110
# Epoch 254/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3598 - val_loss: 1.4061
# Epoch 255/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3665 - val_loss: 1.4751
# Epoch 256/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3644 - val_loss: 1.4257
# Epoch 257/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3568 - val_loss: 1.4167
# Epoch 258/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3553 - val_loss: 1.4055
# Epoch 259/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3662 - val_loss: 1.4201
# Epoch 260/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3601 - val_loss: 1.4041
# Epoch 261/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3551 - val_loss: 1.4291
# Epoch 262/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3582 - val_loss: 1.4236
# Epoch 263/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3559 - val_loss: 1.4340
# Epoch 264/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3540 - val_loss: 1.4112
# Epoch 265/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3596 - val_loss: 1.4165
# Epoch 266/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3635 - val_loss: 1.4142
# Epoch 267/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3525 - val_loss: 1.4032
# Epoch 268/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3618 - val_loss: 1.4170
# Epoch 269/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3659 - val_loss: 1.4168
# Epoch 270/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3588 - val_loss: 1.4094
# Epoch 271/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3614 - val_loss: 1.4193
# Epoch 272/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3562 - val_loss: 1.4318
# Epoch 273/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3569 - val_loss: 1.4037
# Epoch 274/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3505 - val_loss: 1.4016
# Epoch 275/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3533 - val_loss: 1.4124
# Epoch 276/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3570 - val_loss: 1.4188
# Epoch 277/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3692 - val_loss: 1.4259
# Epoch 278/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3612 - val_loss: 1.4081
# Epoch 279/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3726 - val_loss: 1.4282
# Epoch 280/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3530 - val_loss: 1.4049
# Epoch 281/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3492 - val_loss: 1.4171
# Epoch 282/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3524 - val_loss: 1.4412
# Epoch 283/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3573 - val_loss: 1.4128
# Epoch 284/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3624 - val_loss: 1.4204
# Epoch 285/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3572 - val_loss: 1.3998
# Epoch 286/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3531 - val_loss: 1.4103
# Epoch 287/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3513 - val_loss: 1.4066
# Epoch 288/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3517 - val_loss: 1.4116
# Epoch 289/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3484 - val_loss: 1.4177
# Epoch 290/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3468 - val_loss: 1.3957
# Epoch 291/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3684 - val_loss: 1.4038
# Epoch 292/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3572 - val_loss: 1.4221
# Epoch 293/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3638 - val_loss: 1.4225
# Epoch 294/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3574 - val_loss: 1.4039
# Epoch 295/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3574 - val_loss: 1.4267
# Epoch 296/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3592 - val_loss: 1.4223
# Epoch 297/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3526 - val_loss: 1.4194
# Epoch 298/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3624 - val_loss: 1.4127
# Epoch 299/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3518 - val_loss: 1.4110
# Epoch 300/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3514 - val_loss: 1.4168
# Epoch 301/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3509 - val_loss: 1.4218
# Epoch 302/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3566 - val_loss: 1.4038
# Epoch 303/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3491 - val_loss: 1.4201
# Epoch 304/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3598 - val_loss: 1.4263
# Epoch 305/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3590 - val_loss: 1.4201
# Epoch 306/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3483 - val_loss: 1.4159
# Epoch 307/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3578 - val_loss: 1.4210
# Epoch 308/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3538 - val_loss: 1.4017
# Epoch 309/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3509 - val_loss: 1.4066
# Epoch 310/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3527 - val_loss: 1.4040
# Epoch 311/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3559 - val_loss: 1.4096
# Epoch 312/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3606 - val_loss: 1.4234
# Epoch 313/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3507 - val_loss: 1.3951
# Epoch 314/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3506 - val_loss: 1.4022
# Epoch 315/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3436 - val_loss: 1.4098
# Epoch 316/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3449 - val_loss: 1.3994
# Epoch 317/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3463 - val_loss: 1.4148
# Epoch 318/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3687 - val_loss: 1.4426
# Epoch 319/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3699 - val_loss: 1.4130
# Epoch 320/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.3573 - val_loss: 1.3989
# Epoch 321/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3489 - val_loss: 1.4147
# Epoch 322/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3495 - val_loss: 1.4300
# Epoch 323/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3482 - val_loss: 1.4137
# Epoch 324/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3509 - val_loss: 1.4025
# Epoch 325/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3524 - val_loss: 1.4263
# Epoch 326/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3490 - val_loss: 1.4134
# Epoch 327/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3488 - val_loss: 1.4218
# Epoch 328/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3483 - val_loss: 1.4165
# Epoch 329/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3512 - val_loss: 1.4015
# Epoch 330/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3482 - val_loss: 1.4194
# Epoch 331/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3530 - val_loss: 1.4128
# Epoch 332/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3471 - val_loss: 1.4036
# Epoch 333/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3496 - val_loss: 1.4110
# Epoch 334/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3470 - val_loss: 1.4070
# Epoch 335/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3452 - val_loss: 1.4058
# Epoch 336/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3410 - val_loss: 1.4162
# Epoch 337/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3619 - val_loss: 1.4167
# Epoch 338/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3630 - val_loss: 1.4327
# Epoch 339/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3592 - val_loss: 1.4250
# Epoch 340/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3566 - val_loss: 1.4060
# Epoch 341/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3461 - val_loss: 1.4210
# Epoch 342/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3506 - val_loss: 1.4183
# Epoch 343/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3450 - val_loss: 1.4021
# Epoch 344/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3495 - val_loss: 1.4120
# Epoch 345/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3542 - val_loss: 1.4397
# Epoch 346/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3624 - val_loss: 1.4278
# Epoch 347/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3419 - val_loss: 1.4265
# Epoch 348/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3533 - val_loss: 1.4097
# Epoch 349/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3511 - val_loss: 1.4183
# Epoch 350/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3487 - val_loss: 1.4065
# Epoch 351/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3447 - val_loss: 1.4147
# Epoch 352/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3447 - val_loss: 1.4186
# Epoch 353/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3408 - val_loss: 1.3928
# Epoch 354/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3498 - val_loss: 1.4455
# Epoch 355/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3579 - val_loss: 1.4100
# Epoch 356/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3487 - val_loss: 1.4068
# Epoch 357/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3426 - val_loss: 1.4046
# Epoch 358/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3426 - val_loss: 1.4097
# Epoch 359/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3426 - val_loss: 1.4142
# Epoch 360/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3427 - val_loss: 1.4052
# Epoch 361/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3464 - val_loss: 1.4319
# Epoch 362/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3412 - val_loss: 1.4357
# Epoch 363/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3514 - val_loss: 1.4144
# Epoch 364/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3588 - val_loss: 1.4333
# Epoch 365/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3638 - val_loss: 1.4440
# Epoch 366/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3723 - val_loss: 1.4080
# Epoch 367/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3663 - val_loss: 1.4251
# Epoch 368/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3487 - val_loss: 1.3998
# Epoch 369/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3413 - val_loss: 1.4207
# Epoch 370/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3421 - val_loss: 1.4146
# Epoch 371/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3377 - val_loss: 1.4007
# Epoch 372/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3432 - val_loss: 1.4307
# Epoch 373/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3446 - val_loss: 1.4119
# Epoch 374/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3429 - val_loss: 1.3998
# Epoch 375/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3431 - val_loss: 1.4126
# Epoch 376/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3396 - val_loss: 1.4151
# Epoch 377/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3379 - val_loss: 1.4260
# Epoch 378/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3554 - val_loss: 1.4159
# Epoch 379/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3475 - val_loss: 1.4072
# Epoch 380/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3423 - val_loss: 1.4075
# Epoch 381/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3395 - val_loss: 1.3983
# Epoch 382/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3449 - val_loss: 1.4227
# Epoch 383/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3495 - val_loss: 1.4200
# Epoch 384/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3426 - val_loss: 1.4604
# Epoch 385/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3496 - val_loss: 1.4104
# Epoch 386/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3397 - val_loss: 1.3998
# Epoch 387/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3362 - val_loss: 1.4046
# Epoch 388/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3425 - val_loss: 1.4218
# Epoch 389/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3475 - val_loss: 1.4111
# Epoch 390/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3408 - val_loss: 1.4031
# Epoch 391/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3480 - val_loss: 1.4219
# Epoch 392/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3413 - val_loss: 1.4143
# Epoch 393/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3430 - val_loss: 1.4102
# Epoch 394/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3370 - val_loss: 1.4057
# Epoch 395/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3339 - val_loss: 1.4081
# Epoch 396/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3360 - val_loss: 1.4175
# Epoch 397/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3465 - val_loss: 1.4250
# Epoch 398/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3436 - val_loss: 1.4287
# Epoch 399/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3439 - val_loss: 1.3985
# Epoch 400/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3374 - val_loss: 1.4312
# Epoch 401/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3387 - val_loss: 1.3996
# Epoch 402/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3428 - val_loss: 1.4000
# Epoch 403/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3349 - val_loss: 1.4723
# Epoch 404/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3418 - val_loss: 1.4045
# Epoch 405/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3371 - val_loss: 1.4137
# Epoch 406/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3430 - val_loss: 1.4156
# Epoch 407/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3390 - val_loss: 1.4011
# Epoch 408/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3371 - val_loss: 1.4148
# Epoch 409/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3431 - val_loss: 1.3940
# Epoch 410/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3421 - val_loss: 1.3953
# Epoch 411/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3450 - val_loss: 1.4020
# Epoch 412/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3509 - val_loss: 1.4257
# Epoch 413/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3416 - val_loss: 1.4056
# Epoch 414/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3388 - val_loss: 1.4055
# Epoch 415/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3420 - val_loss: 1.4176
# Epoch 416/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3426 - val_loss: 1.4426
# Epoch 417/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3476 - val_loss: 1.4018
# Epoch 418/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3351 - val_loss: 1.4369
# Epoch 419/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3456 - val_loss: 1.4132
# Epoch 420/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3486 - val_loss: 1.4166
# Epoch 421/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3439 - val_loss: 1.4057
# Epoch 422/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3394 - val_loss: 1.4108
# Epoch 423/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3396 - val_loss: 1.4152
# Epoch 424/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3362 - val_loss: 1.4140
# Epoch 425/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3520 - val_loss: 1.4321
# Epoch 426/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3486 - val_loss: 1.3954
# Epoch 427/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3423 - val_loss: 1.4395
# Epoch 428/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3399 - val_loss: 1.3957
# Epoch 429/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3414 - val_loss: 1.3997
# Epoch 430/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3308 - val_loss: 1.4184
# Epoch 431/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3443 - val_loss: 1.3950
# Epoch 432/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3286 - val_loss: 1.3999
# Epoch 433/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3299 - val_loss: 1.4427
# Epoch 434/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3409 - val_loss: 1.4058
# Epoch 435/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3388 - val_loss: 1.3985
# Epoch 436/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3333 - val_loss: 1.4129
# Epoch 437/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3348 - val_loss: 1.3984
# Epoch 438/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3322 - val_loss: 1.4010
# Epoch 439/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3329 - val_loss: 1.4101
# Epoch 440/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3383 - val_loss: 1.4227
# Epoch 441/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3436 - val_loss: 1.3965
# Epoch 442/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3359 - val_loss: 1.4250
# Epoch 443/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3389 - val_loss: 1.4159
# Epoch 444/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3348 - val_loss: 1.4127
# Epoch 445/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3313 - val_loss: 1.4028
# Epoch 446/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3307 - val_loss: 1.3985
# Epoch 447/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3327 - val_loss: 1.4279
# Epoch 448/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3368 - val_loss: 1.3988
# Epoch 449/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3360 - val_loss: 1.4119
# Epoch 450/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3288 - val_loss: 1.3970
# Epoch 451/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3323 - val_loss: 1.4322
# Epoch 452/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3507 - val_loss: 1.4016
# Epoch 453/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3503 - val_loss: 1.4242
# Epoch 454/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3399 - val_loss: 1.4073
# Epoch 455/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3355 - val_loss: 1.4103
# Epoch 456/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3429 - val_loss: 1.4161
# Epoch 457/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3432 - val_loss: 1.4397
# Epoch 458/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3412 - val_loss: 1.4232
# Epoch 459/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3354 - val_loss: 1.3951
# Epoch 460/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3450 - val_loss: 1.4143
# Epoch 461/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3445 - val_loss: 1.4606
# Epoch 462/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3372 - val_loss: 1.3930
# Epoch 463/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3307 - val_loss: 1.3966
# Epoch 464/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3406 - val_loss: 1.4328
# Epoch 465/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3433 - val_loss: 1.4456
# Epoch 466/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3404 - val_loss: 1.4222
# Epoch 467/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3386 - val_loss: 1.4231
# Epoch 468/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3363 - val_loss: 1.4075
# Epoch 469/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3378 - val_loss: 1.4237
# Epoch 470/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3443 - val_loss: 1.4163
# Epoch 471/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3363 - val_loss: 1.4201
# Epoch 472/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3354 - val_loss: 1.3975
# Epoch 473/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3320 - val_loss: 1.3991
# Epoch 474/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3287 - val_loss: 1.4044
# Epoch 475/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3307 - val_loss: 1.3975
# Epoch 476/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3380 - val_loss: 1.4171
# Epoch 477/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3328 - val_loss: 1.4099
# Epoch 478/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3290 - val_loss: 1.3999
# Epoch 479/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3341 - val_loss: 1.4121
# Epoch 480/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3324 - val_loss: 1.4429
# Epoch 481/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.3381 - val_loss: 1.4236
# Epoch 482/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3391 - val_loss: 1.4011
# Epoch 483/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3388 - val_loss: 1.4056
# Epoch 484/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3286 - val_loss: 1.3914
# Epoch 485/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3298 - val_loss: 1.4113
# Epoch 486/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3301 - val_loss: 1.4138
# Epoch 487/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3365 - val_loss: 1.4227
# Epoch 488/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3352 - val_loss: 1.3977
# Epoch 489/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3313 - val_loss: 1.4034
# Epoch 490/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3325 - val_loss: 1.4280
# Epoch 491/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3288 - val_loss: 1.4006
# Epoch 492/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3302 - val_loss: 1.4191
# Epoch 493/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3319 - val_loss: 1.4032
# Epoch 494/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3315 - val_loss: 1.4075
# Epoch 495/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3371 - val_loss: 1.4110
# Epoch 496/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3365 - val_loss: 1.4225
# Epoch 497/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3345 - val_loss: 1.4115
# Epoch 498/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3331 - val_loss: 1.4211
# Epoch 499/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3316 - val_loss: 1.3997
# Epoch 500/500
# 20/20 [==============================] - 0s 3ms/step - loss: 1.3299 - val_loss: 1.3988

# %% [markdown]
# ### Training and Validation Loss
#
# It's interesting to see how the model trained. We can see that after a certain point training is rather slow.
#
# For this problem a loss value around 1.5 produces quite good results.

# %%
plt.figure(figsize=(10, 5))
plt.ylim([0,9])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Sampling Functions
#
# The MDN model outputs parameters of a mixture model---a list of means (mu), variances (sigma), and weights (pi).
#
# The `mdn` module provides a function to sample from these parameters as follows. First the parameters are split up into `mu`s, `sigma`s and `pi`s, then the categorical distribution formed by the `pi`s is sampled to choose which mixture component should be sampled, then that component's `mu`s and `sigma`s is used to sample from a multivariate normal model, here's the code:
#
#     def sample_from_output(params, output_dim, num_mixes, temp=1.0):
#         """Sample from an MDN output with temperature adjustment."""
#         mus = params[:num_mixes*output_dim]
#         sigs = params[num_mixes*output_dim:2*num_mixes*output_dim]
#         pis = softmax(params[-num_mixes:], t=temp)
#         m = sample_from_categorical(pis)
#         # Alternative way to sample from categorical:
#         # m = np.random.choice(range(len(pis)), p=pis)
#         mus_vector = mus[m*output_dim:(m+1)*output_dim]
#         sig_vector = sigs[m*output_dim:(m+1)*output_dim] * temp  # adjust for temperature
#         cov_matrix = np.identity(output_dim) * sig_vector
#         sample = np.random.multivariate_normal(mus_vector, cov_matrix, 1)
#         return sample
#
# If you only have one prediction to sample from, you can use the function as is; but if you need to sample from a lot of predictions at once (as in the following sections), you can use `np.apply_along_axis` to apply it to a whole numpy array of predicted parameters.

# %% [markdown]
# ## Try out the MDN Model
#
# Now we try out the model by making predictions at 3000 evenly spaced points on the x-axis.
#
# Mixture models output lists of parameters, so we're going to sample from these parameters for each point on the x-axis, and also try plotting the parameters themselves so we can have some insight into what the model is learning!

# %%
## Sample on some test data:
x_test = np.float32(np.arange(-15,15,0.01))
NTEST = x_test.size
print("Testing:", NTEST, "samples.")
x_test = x_test.reshape(NTEST,1) # needs to be a matrix, not a vector

# Make predictions from the model
y_test = model.predict(x_test)
# y_test contains parameters for distributions, not actual points on the graph.
# To find points on the graph, we need to sample from each distribution.

# Sample from the predicted distributions
y_samples = np.apply_along_axis(mdn.sample_from_output, 1, y_test, 1, N_MIXES,temp=1.0)

# Split up the mixture parameters (for future fun)
mus = np.apply_along_axis((lambda a: a[:N_MIXES]),1, y_test)
sigs = np.apply_along_axis((lambda a: a[N_MIXES:2*N_MIXES]),1, y_test)
pis = np.apply_along_axis((lambda a: mdn.softmax(a[2*N_MIXES:])),1, y_test)
# Out:
# Testing: 3000 samples.
# 94/94 [==============================] - 0s 827us/step

# %%
# Plot the samples
plt.figure(figsize=(8, 8))
plt.plot(x_data,y_data,'ro', x_test, y_samples[:,:,0], 'bo',alpha=0.3)
plt.show()
# These look pretty good!
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Plot the means - this gives us some insight into how the model learns to produce the mixtures.
plt.figure(figsize=(8, 8))
plt.plot(x_data,y_data,'ro', x_test, mus,'bo',alpha=0.3)
plt.show()
# Cool!
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Let's plot the variances and weightings of the means as well.
fig = plt.figure(figsize=(8, 8))
ax1 = fig.add_subplot(111)
# ax1.scatter(data[0], data[1], marker='o', c='b', s=data[2], label='the data')
ax1.scatter(x_data,y_data,marker='o', c='r', alpha=0.3)
for i in range(N_MIXES):
    ax1.scatter(x_test, mus[:,i], marker='o', s=200*sigs[:,i]*pis[:,i],alpha=0.3)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Should be a markdown text box talking about the conversion

# %%
# Following code converts high level keras model to a .tflite file 
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# converter.optimizations = [tf.lite.Optimize.DEFAULT]
"""converter.target_spec.supported_ops = [
tf.lite.OpsSet.TFLITE_BUILTINS, # enable TensorFlow Lite ops.
tf.lite.OpsSet.SELECT_TF_OPS, # enable TensorFlow ops.   
]"""
tflite_model = converter.convert()
# Saves converted file to this folder
tflite_model_name = '1-sineprediction-lite.tflite'
with open(tflite_model_name, 'wb') as f:
    f.write(tflite_model)

# The conversion outputs a significant amount of arithmetic conversion errors. 
# From other posts online, this seems to be a superficial issue with converting from 32 bit 
# ints to 64 bit ints and does not affect the validity of the conversion.
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpbogdo_gb/assets
# INFO:tensorflow:Assets written to: /tmp/tmpbogdo_gb/assets
# 2024-06-13 17:43:03.758009: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2024-06-13 17:43:03.758075: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2024-06-13 17:43:03.758414: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpbogdo_gb
# 2024-06-13 17:43:03.759279: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2024-06-13 17:43:03.759291: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmpbogdo_gb
# 2024-06-13 17:43:03.761502: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# 2024-06-13 17:43:03.762270: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2024-06-13 17:43:03.812923: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmpbogdo_gb
# 2024-06-13 17:43:03.825022: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 66606 microseconds.
# 2024-06-13 17:43:03.854727: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 11, Total Ops 22, % non-converted = 50.00 %
#  * 11 ARITH ops
#
# - arith.constant:   11 occurrences  (f32: 11)
#
#
#
#   (f32: 1)
#   (f32: 1)
#   (f32: 1)
#   (f32: 5)

# %%
# Load the TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter(model_content=tflite_model)

# Resize input shape for dynamic shape model and allocate tensor
interpreter.resize_tensor_input(interpreter.get_input_details()[0]['index'], (NTEST,1))
interpreter.allocate_tensors()

# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Test the model on our defined testing set
interpreter.set_tensor(input_details[0]['index'], x_test)

# Uses the interpreter to make the same predictions as our keras model
interpreter.invoke()

# The function `get_tensor()` returns a copy of the tensor data.
y_test_tflite = interpreter.get_tensor(output_details[0]['index'])


# Sample from the TFLite predicted distributions as done previously
y_samples_tflite = np.apply_along_axis(mdn.sample_from_output, 1, y_test_tflite, 1, N_MIXES, temp=1.0)

# %%
# Plot the samples
plt.figure(figsize=(8, 8))
plt.plot(x_data,y_data,'ro', x_test, y_samples_tflite[:,:,0], 'go',alpha=0.3)
plt.show()
# These look very similar to our keras model!
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Plot the Keras and TFLite model predictions
plt.figure(figsize=(8, 8))
plt.plot(x_test, y_samples[:,:,0], 'bo', label='Keras MDN', alpha=0.3)
plt.plot(x_test, y_samples_tflite[:,:,0], 'go', label='TFLite MDN', alpha=0.3)
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
