# %% [markdown]
# # 2D Mixture Density Network
#
# An extension of Bishops' classic MDN prediction task to 2-dimensions.
#
# The idea in this task is to predict a the value of a two inverse sine functions simultaneously. This function has multiple real-valued solutions at each point, so the ANN model needs to have the capacity to handle this in it's loss function. An MDN is a good way to handle the predictions of these multiple output values.
#
# This implementation owes much to the following:
#
# - [David Ha - Mixture Density Networks with TensorFlow](http://blog.otoro.net/2015/11/24/mixture-density-networks-with-tensorflow/)
# - [Mixture Density Networks in Edward](http://edwardlib.org/tutorials/mixture-density-network)

# %%
import keras
from context import * # imports the MDN layer 
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D 
# %matplotlib widget
# Out:
# 2024-06-09 00:50:03.416705: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-09 00:50:03.420920: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-09 00:50:03.475114: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-09 00:50:03.475162: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-09 00:50:03.477623: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-09 00:50:03.486258: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-09 00:50:03.487057: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-09 00:50:04.299593: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Generate Synthetic Data
#
# Data generation

# %%
## Generating some data:
NSAMPLE = 5000

z_data = np.float32(np.random.uniform(-10.5, 10.5, NSAMPLE))
r_data = np.random.normal(size=NSAMPLE)
s_data = np.random.normal(size=NSAMPLE)
x_data = np.sin(0.75 * z_data) * 7.0 + z_data * 0.5 + r_data * 1.0
y_data = np.cos(0.80 * z_data) * 6.5 + z_data * 0.5 + s_data * 1.0

x_input = z_data.reshape((NSAMPLE, 1))
y_input = np.array([x_data,y_data])
y_input = y_input.T #reshape to (NSAMPLE,2)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_data, y_data, z_data, alpha=0.3, c='r') #c=perf_down_sampled.moving
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Build the MDN Model
#
# Now we will construct the MDN model in Keras. This uses the `Sequential` model interface in Keras.
#
# The `MDN` layer comes after one or more `Dense` layers. You need to define the output dimension and number of mixtures for the MDN like so: `MDN(output_dimension, number_mixtures)`.
#
# For this problem, we only need an output dimension of 1 as we are predicting one value (y). Adding more mixtures adds a more parameters (model is more complex, takes longer to train), but might help make the solutions better. You can see from the training data that there are at maximum 5 different layers to predict in the curve, so setting `N_MIXES = 5` is a good place to start.
#
# For MDNs, we have to use a special loss function that can handle the mixture parameters: the function has to take into account the number of output dimensions and mixtures.

# %%
N_HIDDEN = 15
N_MIXES = 10
OUTPUT_DIMS = 2

model = keras.Sequential()
model.add(keras.layers.Dense(N_HIDDEN, batch_input_shape=(None, 1), activation='relu'))
model.add(keras.layers.Dense(N_HIDDEN, activation='relu'))
model.add(mdn.MDN(OUTPUT_DIMS, N_MIXES))
model.compile(loss=mdn.get_mixture_loss_func(OUTPUT_DIMS,N_MIXES), optimizer=keras.optimizers.Adam())
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 15)                30
#
#  dense_1 (Dense)             (None, 15)                240
#
#  mdn (MDN)                   (None, 50)                800
#
# =================================================================
# Total params: 1070 (4.18 KB)
# Trainable params: 1070 (4.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Training the model
#
# Now we train the model using Keras' normal `fit` command.

# %%
history = model.fit(x=x_input, y=y_input, batch_size=128, epochs=300, validation_split=0.15, callbacks=[keras.callbacks.TerminateOnNaN()])
# Out:
# Epoch 1/300
# 34/34 [==============================] - 6s 41ms/step - loss: 10.8499 - val_loss: 9.1841
# Epoch 2/300
# 34/34 [==============================] - 0s 5ms/step - loss: 8.3535 - val_loss: 7.6316
# Epoch 3/300
# 34/34 [==============================] - 0s 4ms/step - loss: 7.3203 - val_loss: 7.0363
# Epoch 4/300
# 34/34 [==============================] - 0s 4ms/step - loss: 6.8950 - val_loss: 6.7617
# Epoch 5/300
# 34/34 [==============================] - 0s 4ms/step - loss: 6.6626 - val_loss: 6.5606
# Epoch 6/300
# 34/34 [==============================] - 0s 5ms/step - loss: 6.4955 - val_loss: 6.4075
# Epoch 7/300
# 34/34 [==============================] - 0s 5ms/step - loss: 6.3629 - val_loss: 6.2851
# Epoch 8/300
# 34/34 [==============================] - 0s 4ms/step - loss: 6.2528 - val_loss: 6.1809
# Epoch 9/300
# 34/34 [==============================] - 0s 4ms/step - loss: 6.1654 - val_loss: 6.0952
# Epoch 10/300
# 34/34 [==============================] - 0s 4ms/step - loss: 6.0915 - val_loss: 6.0336
# Epoch 11/300
# 34/34 [==============================] - 0s 4ms/step - loss: 6.0309 - val_loss: 5.9606
# Epoch 12/300
# 34/34 [==============================] - 0s 4ms/step - loss: 5.9677 - val_loss: 5.8956
# Epoch 13/300
# 34/34 [==============================] - 0s 4ms/step - loss: 5.9020 - val_loss: 5.8306
# Epoch 14/300
# 34/34 [==============================] - 0s 4ms/step - loss: 5.8351 - val_loss: 5.7532
# Epoch 15/300
# 34/34 [==============================] - 0s 5ms/step - loss: 5.7602 - val_loss: 5.6759
# Epoch 16/300
# 34/34 [==============================] - 0s 5ms/step - loss: 5.6809 - val_loss: 5.5812
# Epoch 17/300
# 34/34 [==============================] - 0s 4ms/step - loss: 5.6044 - val_loss: 5.5159
# Epoch 18/300
# 34/34 [==============================] - 0s 5ms/step - loss: 5.5286 - val_loss: 5.4297
# Epoch 19/300
# 34/34 [==============================] - 0s 4ms/step - loss: 5.4509 - val_loss: 5.3606
# Epoch 20/300
# 34/34 [==============================] - 0s 4ms/step - loss: 5.3783 - val_loss: 5.3052
# Epoch 21/300
# 34/34 [==============================] - 0s 4ms/step - loss: 5.3225 - val_loss: 5.2480
# Epoch 22/300
# 34/34 [==============================] - 0s 4ms/step - loss: 5.2753 - val_loss: 5.2018
# Epoch 23/300
# 34/34 [==============================] - 0s 4ms/step - loss: 5.2283 - val_loss: 5.1673
# Epoch 24/300
# 34/34 [==============================] - 0s 4ms/step - loss: 5.1836 - val_loss: 5.1221
# Epoch 25/300
# 34/34 [==============================] - 0s 5ms/step - loss: 5.1402 - val_loss: 5.0772
# Epoch 26/300
# 34/34 [==============================] - 0s 4ms/step - loss: 5.0852 - val_loss: 5.0211
# Epoch 27/300
# 34/34 [==============================] - 0s 5ms/step - loss: 5.0212 - val_loss: 4.9653
# Epoch 28/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.9602 - val_loss: 4.9072
# Epoch 29/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.8833 - val_loss: 4.8321
# Epoch 30/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.7849 - val_loss: 4.7602
# Epoch 31/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.7038 - val_loss: 4.6861
# Epoch 32/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.6171 - val_loss: 4.5976
# Epoch 33/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.5252 - val_loss: 4.5249
# Epoch 34/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.4520 - val_loss: 4.4478
# Epoch 35/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.3776 - val_loss: 4.3811
# Epoch 36/300
# 34/34 [==============================] - 0s 5ms/step - loss: 4.3057 - val_loss: 4.2845
# Epoch 37/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.2323 - val_loss: 4.2284
# Epoch 38/300
# 34/34 [==============================] - 0s 5ms/step - loss: 4.1855 - val_loss: 4.1761
# Epoch 39/300
# 34/34 [==============================] - 0s 5ms/step - loss: 4.1447 - val_loss: 4.1562
# Epoch 40/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.1135 - val_loss: 4.1176
# Epoch 41/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.0809 - val_loss: 4.0788
# Epoch 42/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.0437 - val_loss: 4.0450
# Epoch 43/300
# 34/34 [==============================] - 0s 5ms/step - loss: 4.0141 - val_loss: 4.0243
# Epoch 44/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.9864 - val_loss: 3.9891
# Epoch 45/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.9578 - val_loss: 3.9684
# Epoch 46/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.9393 - val_loss: 3.9433
# Epoch 47/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.9048 - val_loss: 3.9217
# Epoch 48/300
# 34/34 [==============================] - 0s 6ms/step - loss: 3.8823 - val_loss: 3.8883
# Epoch 49/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.8595 - val_loss: 3.8642
# Epoch 50/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.8319 - val_loss: 3.8332
# Epoch 51/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.8061 - val_loss: 3.8288
# Epoch 52/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.7844 - val_loss: 3.7987
# Epoch 53/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.7618 - val_loss: 3.7842
# Epoch 54/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.7395 - val_loss: 3.7617
# Epoch 55/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.7108 - val_loss: 3.7242
# Epoch 56/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.6970 - val_loss: 3.7230
# Epoch 57/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.6683 - val_loss: 3.6993
# Epoch 58/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.6558 - val_loss: 3.6895
# Epoch 59/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.6372 - val_loss: 3.6757
# Epoch 60/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.6278 - val_loss: 3.6751
# Epoch 61/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.6128 - val_loss: 3.6609
# Epoch 62/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.6023 - val_loss: 3.6394
# Epoch 63/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.5873 - val_loss: 3.6524
# Epoch 64/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.5761 - val_loss: 3.6130
# Epoch 65/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.5689 - val_loss: 3.6169
# Epoch 66/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.5574 - val_loss: 3.6001
# Epoch 67/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.5442 - val_loss: 3.5869
# Epoch 68/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.5346 - val_loss: 3.5800
# Epoch 69/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.5182 - val_loss: 3.5586
# Epoch 70/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.4996 - val_loss: 3.5408
# Epoch 71/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.4866 - val_loss: 3.5259
# Epoch 72/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.4694 - val_loss: 3.5199
# Epoch 73/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.4610 - val_loss: 3.5007
# Epoch 74/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.4455 - val_loss: 3.4818
# Epoch 75/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.4354 - val_loss: 3.4869
# Epoch 76/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.4271 - val_loss: 3.4700
# Epoch 77/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.4162 - val_loss: 3.4706
# Epoch 78/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.4185 - val_loss: 3.4934
# Epoch 79/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.4076 - val_loss: 3.4406
# Epoch 80/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.3860 - val_loss: 3.4182
# Epoch 81/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.3803 - val_loss: 3.4256
# Epoch 82/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.3694 - val_loss: 3.4092
# Epoch 83/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.3673 - val_loss: 3.4088
# Epoch 84/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.3592 - val_loss: 3.4138
# Epoch 85/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.3449 - val_loss: 3.4018
# Epoch 86/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.3438 - val_loss: 3.3904
# Epoch 87/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.3314 - val_loss: 3.3972
# Epoch 88/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.3362 - val_loss: 3.3762
# Epoch 89/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.3193 - val_loss: 3.3604
# Epoch 90/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.3118 - val_loss: 3.3563
# Epoch 91/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.3010 - val_loss: 3.3523
# Epoch 92/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2978 - val_loss: 3.3339
# Epoch 93/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2973 - val_loss: 3.3425
# Epoch 94/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2932 - val_loss: 3.3341
# Epoch 95/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.2867 - val_loss: 3.3255
# Epoch 96/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.2760 - val_loss: 3.3165
# Epoch 97/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2710 - val_loss: 3.3227
# Epoch 98/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2683 - val_loss: 3.3356
# Epoch 99/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2744 - val_loss: 3.3192
# Epoch 100/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.2618 - val_loss: 3.3108
# Epoch 101/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2587 - val_loss: 3.2990
# Epoch 102/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2487 - val_loss: 3.2957
# Epoch 103/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2520 - val_loss: 3.2833
# Epoch 104/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2481 - val_loss: 3.2929
# Epoch 105/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2460 - val_loss: 3.2708
# Epoch 106/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2385 - val_loss: 3.2776
# Epoch 107/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2300 - val_loss: 3.2727
# Epoch 108/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2225 - val_loss: 3.2723
# Epoch 109/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.2207 - val_loss: 3.2648
# Epoch 110/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.2095 - val_loss: 3.2443
# Epoch 111/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2082 - val_loss: 3.2507
# Epoch 112/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.2048 - val_loss: 3.2885
# Epoch 113/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.2091 - val_loss: 3.2579
# Epoch 114/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1966 - val_loss: 3.2352
# Epoch 115/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1913 - val_loss: 3.2338
# Epoch 116/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1978 - val_loss: 3.2288
# Epoch 117/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1834 - val_loss: 3.2235
# Epoch 118/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1760 - val_loss: 3.2153
# Epoch 119/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1740 - val_loss: 3.2041
# Epoch 120/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1609 - val_loss: 3.2072
# Epoch 121/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1551 - val_loss: 3.1885
# Epoch 122/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1548 - val_loss: 3.2199
# Epoch 123/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1536 - val_loss: 3.2016
# Epoch 124/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1394 - val_loss: 3.1759
# Epoch 125/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1290 - val_loss: 3.2006
# Epoch 126/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1283 - val_loss: 3.1623
# Epoch 127/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1287 - val_loss: 3.1534
# Epoch 128/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1146 - val_loss: 3.1756
# Epoch 129/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1046 - val_loss: 3.1277
# Epoch 130/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0958 - val_loss: 3.1320
# Epoch 131/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0963 - val_loss: 3.1384
# Epoch 132/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0839 - val_loss: 3.1165
# Epoch 133/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0781 - val_loss: 3.1019
# Epoch 134/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0754 - val_loss: 3.1309
# Epoch 135/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0749 - val_loss: 3.1132
# Epoch 136/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0795 - val_loss: 3.0858
# Epoch 137/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0726 - val_loss: 3.1046
# Epoch 138/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0626 - val_loss: 3.0966
# Epoch 139/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0611 - val_loss: 3.0873
# Epoch 140/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0558 - val_loss: 3.0865
# Epoch 141/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0573 - val_loss: 3.0888
# Epoch 142/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0625 - val_loss: 3.0908
# Epoch 143/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0647 - val_loss: 3.0834
# Epoch 144/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0528 - val_loss: 3.1000
# Epoch 145/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0648 - val_loss: 3.0738
# Epoch 146/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0539 - val_loss: 3.0827
# Epoch 147/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0567 - val_loss: 3.1056
# Epoch 148/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0627 - val_loss: 3.0812
# Epoch 149/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0450 - val_loss: 3.0752
# Epoch 150/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0494 - val_loss: 3.0724
# Epoch 151/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0430 - val_loss: 3.0611
# Epoch 152/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0450 - val_loss: 3.0574
# Epoch 153/300
# 34/34 [==============================] - 0s 6ms/step - loss: 3.0417 - val_loss: 3.0524
# Epoch 154/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0423 - val_loss: 3.0584
# Epoch 155/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0425 - val_loss: 3.0709
# Epoch 156/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0399 - val_loss: 3.0662
# Epoch 157/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0474 - val_loss: 3.0565
# Epoch 158/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0357 - val_loss: 3.0692
# Epoch 159/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0400 - val_loss: 3.0743
# Epoch 160/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0420 - val_loss: 3.0673
# Epoch 161/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0343 - val_loss: 3.0377
# Epoch 162/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0371 - val_loss: 3.0826
# Epoch 163/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0360 - val_loss: 3.0455
# Epoch 164/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0462 - val_loss: 3.0510
# Epoch 165/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0398 - val_loss: 3.0606
# Epoch 166/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0348 - val_loss: 3.0371
# Epoch 167/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0303 - val_loss: 3.0467
# Epoch 168/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0247 - val_loss: 3.0356
# Epoch 169/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0311 - val_loss: 3.0564
# Epoch 170/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0242 - val_loss: 3.0887
# Epoch 171/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0234 - val_loss: 3.0494
# Epoch 172/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0237 - val_loss: 3.0308
# Epoch 173/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0250 - val_loss: 3.0426
# Epoch 174/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0225 - val_loss: 3.0315
# Epoch 175/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0246 - val_loss: 3.0385
# Epoch 176/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0223 - val_loss: 3.0380
# Epoch 177/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0221 - val_loss: 3.0474
# Epoch 178/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0234 - val_loss: 3.0313
# Epoch 179/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0227 - val_loss: 3.0436
# Epoch 180/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0157 - val_loss: 3.0344
# Epoch 181/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0161 - val_loss: 3.0436
# Epoch 182/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0245 - val_loss: 3.0430
# Epoch 183/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0204 - val_loss: 3.0374
# Epoch 184/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0160 - val_loss: 3.0392
# Epoch 185/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0068 - val_loss: 3.0228
# Epoch 186/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0152 - val_loss: 3.0350
# Epoch 187/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0202 - val_loss: 3.0326
# Epoch 188/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0104 - val_loss: 3.0431
# Epoch 189/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0098 - val_loss: 3.0317
# Epoch 190/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0121 - val_loss: 3.0451
# Epoch 191/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0234 - val_loss: 3.0102
# Epoch 192/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0128 - val_loss: 3.0179
# Epoch 193/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0106 - val_loss: 3.0343
# Epoch 194/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0089 - val_loss: 3.0286
# Epoch 195/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0092 - val_loss: 3.0167
# Epoch 196/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0052 - val_loss: 3.0144
# Epoch 197/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0013 - val_loss: 3.0284
# Epoch 198/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0113 - val_loss: 3.0148
# Epoch 199/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0065 - val_loss: 3.0133
# Epoch 200/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0092 - val_loss: 3.0252
# Epoch 201/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0079 - val_loss: 3.0360
# Epoch 202/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0120 - val_loss: 3.0142
# Epoch 203/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0000 - val_loss: 3.0072
# Epoch 204/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9981 - val_loss: 3.0300
# Epoch 205/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9996 - val_loss: 3.0283
# Epoch 206/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9993 - val_loss: 3.0171
# Epoch 207/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9978 - val_loss: 3.0230
# Epoch 208/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0016 - val_loss: 3.0207
# Epoch 209/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9989 - val_loss: 3.0115
# Epoch 210/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9958 - val_loss: 3.0166
# Epoch 211/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9934 - val_loss: 3.0276
# Epoch 212/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9958 - val_loss: 3.0203
# Epoch 213/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0032 - val_loss: 3.0214
# Epoch 214/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9934 - val_loss: 3.0241
# Epoch 215/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9969 - val_loss: 3.0106
# Epoch 216/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9905 - val_loss: 3.0219
# Epoch 217/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9942 - val_loss: 3.0222
# Epoch 218/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9852 - val_loss: 3.0109
# Epoch 219/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9882 - val_loss: 3.0075
# Epoch 220/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9880 - val_loss: 3.0232
# Epoch 221/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9873 - val_loss: 3.0104
# Epoch 222/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9846 - val_loss: 3.0047
# Epoch 223/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9827 - val_loss: 3.0051
# Epoch 224/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9856 - val_loss: 3.0279
# Epoch 225/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9910 - val_loss: 3.0088
# Epoch 226/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9878 - val_loss: 2.9958
# Epoch 227/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9916 - val_loss: 3.0098
# Epoch 228/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9840 - val_loss: 2.9968
# Epoch 229/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9745 - val_loss: 3.0115
# Epoch 230/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9802 - val_loss: 3.0006
# Epoch 231/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9789 - val_loss: 3.0149
# Epoch 232/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9793 - val_loss: 3.0062
# Epoch 233/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9862 - val_loss: 2.9971
# Epoch 234/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9760 - val_loss: 3.0102
# Epoch 235/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9926 - val_loss: 3.0062
# Epoch 236/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9817 - val_loss: 2.9973
# Epoch 237/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9793 - val_loss: 2.9990
# Epoch 238/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9745 - val_loss: 3.0121
# Epoch 239/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9777 - val_loss: 3.0029
# Epoch 240/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9790 - val_loss: 3.0171
# Epoch 241/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9751 - val_loss: 2.9935
# Epoch 242/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9719 - val_loss: 3.0054
# Epoch 243/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9792 - val_loss: 2.9924
# Epoch 244/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9724 - val_loss: 3.0040
# Epoch 245/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9670 - val_loss: 3.0040
# Epoch 246/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9824 - val_loss: 2.9967
# Epoch 247/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9738 - val_loss: 2.9989
# Epoch 248/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9760 - val_loss: 2.9868
# Epoch 249/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9667 - val_loss: 2.9979
# Epoch 250/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9652 - val_loss: 2.9865
# Epoch 251/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9748 - val_loss: 3.0160
# Epoch 252/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9783 - val_loss: 3.0023
# Epoch 253/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9699 - val_loss: 2.9992
# Epoch 254/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9639 - val_loss: 2.9955
# Epoch 255/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9740 - val_loss: 2.9882
# Epoch 256/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9630 - val_loss: 2.9867
# Epoch 257/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9628 - val_loss: 2.9889
# Epoch 258/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9677 - val_loss: 3.0011
# Epoch 259/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9652 - val_loss: 2.9901
# Epoch 260/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9592 - val_loss: 3.0004
# Epoch 261/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9658 - val_loss: 3.0057
# Epoch 262/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9758 - val_loss: 2.9829
# Epoch 263/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9563 - val_loss: 2.9796
# Epoch 264/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9586 - val_loss: 2.9919
# Epoch 265/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9655 - val_loss: 2.9860
# Epoch 266/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9666 - val_loss: 2.9788
# Epoch 267/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9582 - val_loss: 2.9882
# Epoch 268/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9569 - val_loss: 2.9913
# Epoch 269/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9558 - val_loss: 3.0092
# Epoch 270/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9666 - val_loss: 3.0025
# Epoch 271/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9612 - val_loss: 3.0059
# Epoch 272/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9573 - val_loss: 2.9878
# Epoch 273/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9707 - val_loss: 2.9965
# Epoch 274/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9699 - val_loss: 2.9835
# Epoch 275/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9599 - val_loss: 2.9880
# Epoch 276/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9546 - val_loss: 3.0054
# Epoch 277/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9915 - val_loss: 2.9770
# Epoch 278/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9610 - val_loss: 2.9815
# Epoch 279/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9616 - val_loss: 2.9899
# Epoch 280/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9627 - val_loss: 2.9860
# Epoch 281/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9541 - val_loss: 2.9717
# Epoch 282/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9561 - val_loss: 3.0000
# Epoch 283/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9644 - val_loss: 2.9832
# Epoch 284/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9617 - val_loss: 2.9799
# Epoch 285/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9532 - val_loss: 2.9785
# Epoch 286/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9491 - val_loss: 2.9761
# Epoch 287/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9475 - val_loss: 2.9790
# Epoch 288/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9507 - val_loss: 2.9841
# Epoch 289/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9518 - val_loss: 2.9937
# Epoch 290/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9593 - val_loss: 2.9860
# Epoch 291/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9525 - val_loss: 2.9702
# Epoch 292/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9501 - val_loss: 2.9824
# Epoch 293/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9482 - val_loss: 2.9770
# Epoch 294/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9508 - val_loss: 3.0116
# Epoch 295/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9569 - val_loss: 2.9772
# Epoch 296/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9475 - val_loss: 2.9892
# Epoch 297/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9444 - val_loss: 2.9710
# Epoch 298/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9422 - val_loss: 2.9848
# Epoch 299/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9411 - val_loss: 2.9809
# Epoch 300/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9431 - val_loss: 2.9711

# %% [markdown]
# ### Training and Validation Loss
#
# It's interesting to see how the model trained. We can see that after a certain point improvement in training is rather slow.
#
# For this problem a loss value around 3.0 produces quite good results.

# %%
plt.figure(figsize=(10, 5))
plt.ylim([0,9])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Try out the MDN Model
#
# Now we try out the model by making predictions at 3000 evenly spaced points on the x-axis.
#
# Mixture models output lists of parameters, so we're going to sample from these parameters for each point on the x-axis, and also try plotting the parameters themselves so we can have some insight into what the model is learning!

# %%
## Sample on some test data:
x_test = np.float32(np.arange(-15,15,0.1))
NTEST = x_test.size
print("Testing:", NTEST, "samples.")
x_test = x_test.reshape(NTEST,1) # needs to be a matrix, not a vector

# Make predictions from the model
y_test = model.predict(x_test)
# y_test contains parameters for distributions, not actual points on the graph.
# To find points on the graph, we need to sample from each distribution.

# Split up the mixture parameters (for future fun)
mus = np.apply_along_axis((lambda a: a[:N_MIXES*OUTPUT_DIMS]), 1, y_test)
sigs = np.apply_along_axis((lambda a: a[N_MIXES*OUTPUT_DIMS:2*N_MIXES*OUTPUT_DIMS]), 1, y_test)
pis = np.apply_along_axis((lambda a: mdn.softmax(a[-N_MIXES:])), 1, y_test)

# Sample from the predicted distributions
y_samples = np.apply_along_axis(mdn.sample_from_output, 1, y_test, OUTPUT_DIMS, N_MIXES, temp=1.0, sigma_temp=1.0)
# Out:
# Testing: 300 samples.
# 10/10 [==============================] - 0s 2ms/step

# %%
# Plot the predicted samples.
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_data, y_data, z_data, alpha=0.05, c='r') #c=perf_down_sampled.moving
ax.scatter(y_samples.T[0], y_samples.T[1], x_test, alpha=0.2, c='b') #c=perf_down_sampled.moving
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Plot the means - this gives us some insight into how the model learns to produce the mixtures.
# Cool!

# Plot the predicted samples.
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_data, y_data, z_data, alpha=0.1, c='r') #c=perf_down_sampled.moving
ax.scatter(y_samples.T[0], y_samples.T[1], x_test, alpha=0.1, c='b') #c=perf_down_sampled.moving
for m in range(N_MIXES):
    one_pair = mus[m*OUTPUT_DIMS:(m+1)*OUTPUT_DIMS]
    ax.scatter(mus[:,2*m], mus[:,2*m + 1] , x_test, marker='o',alpha=0.3)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Let's plot the variances and weightings of the means as well.

# Plot the predicted samples.
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_data, y_data, z_data, alpha=0.1, c='r') #c=perf_down_sampled.moving
for m in range(N_MIXES):
    one_pair = mus[m*OUTPUT_DIMS:(m+1)*OUTPUT_DIMS]
    ax.scatter(mus[:,2*m], mus[:,2*m + 1] , x_test, s=100*sigs[:,2*m]*pis[:,m], marker='o',alpha=0.3)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Converting to TensorFlow Lite
#
# We will now convert the keras model into a tflite model. This primarily uses boilerplate code which invokes the TFLiteConverter class and writes the generated model to file. This conversion currently outputs a significant amount of arithmetic conversion errors. From other posts online, this seems to be a superficial issue with converting from 32 bit ints to 64 bit ints and does not affect the validity of the conversion.

# %%
# Following code converts high level keras model to a .tflite file 
converter = tf.lite.TFLiteConverter.from_keras_model(model)

tflite_model = converter.convert()
# Saves converted file to this folder
tflite_model_name = '2-2dspiral-lite.tflite'
with open(tflite_model_name, 'wb') as f:
    f.write(tflite_model)

# %% [markdown]
# ## Predicting using the TensorFlow Lite Model
#
# To make predictions using the tflite runtime, we use the interpreter class. Primarily, this is boilerplate code provided from the tensorflow tutorials. Importantly as our has a model dynamic input shape (as indicated by us defining the keras model with a first layer with batch_input_shape=(None, 1)) we must define the input tensor manually using resize_tensor_input. Now, we will test the tflite model on our original training data and compare it to the keras model.

# %%
# Load the TFLite model and allocate tensors.
# Note that it assumes we are loading the model just saved to the current folder
# to interpret from a model we have just generated, use model_content=tflite_model as the parameter instead
interpreter = tf.lite.Interpreter(model_path=tflite_model_name) 

# Resize input shape for dynamic shape model and allocate tensor
interpreter.resize_tensor_input(interpreter.get_input_details()[0]['index'], (NTEST,1))
interpreter.allocate_tensors()

# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Test the model on our defined testing set
interpreter.set_tensor(input_details[0]['index'], x_test)

# Uses the interpreter to make the same predictions as our keras model
interpreter.invoke()

# The function `get_tensor()` returns a copy of the tensor data.
y_test_tflite = interpreter.get_tensor(output_details[0]['index'])


# Sample from the TFLite predicted distributions as done previously
y_samples_tflite = np.apply_along_axis(mdn.sample_from_output, 1, y_test_tflite, 1, N_MIXES, temp=1.0)
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
# Plot the predicted samples.
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_data, y_data, z_data, alpha=0.05, c='r') #c=perf_down_sampled.moving
ax.scatter(y_samples_tflite.T[0], y_samples_tflite.T[1], x_test, alpha=0.2, c='b') #c=perf_down_sampled.moving
plt.show()
# The model clearly successfully predicts our dataset.
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Plot the Keras and TFLite model predictions
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(y_samples.T[0], y_samples.T[1], x_test, alpha=0.2, c='b') #c=perf_down_sampled.moving
ax.scatter(y_samples_tflite.T[0], y_samples_tflite.T[1], x_test, alpha=0.2, c='b') #c=perf_down_sampled.moving
plt.show()
# The models clearly behave quite similarly
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
