# %% [markdown]
# # Mixture Density Network
#
# Reproducing the classic Bishop MDN network tasks in Keras. The idea in this task is to predict a the value of an inverse sine function. This function has multiple real-valued solutions at each point, so the ANN model needs to have the capacity to handle this in it's loss function. An MDN is a good way to handle the predictions of these multiple output values.
#
# There's a couple of other versions of this task, and this implementation owes much to the following:
#
# - [David Ha - Mixture Density Networks with TensorFlow](http://blog.otoro.net/2015/11/24/mixture-density-networks-with-tensorflow/)
# - [Mixture Density Networks in Edward](http://edwardlib.org/tutorials/mixture-density-network)

# %%
# Normal imports for everybody
from context import * # imports the MDN layer 
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib widget

# Tensorflow is used to convert to tflite
import tensorflow as tf
# Out:
# 2024-06-14 18:02:38.571456: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-14 18:02:38.714377: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-14 18:02:39.361328: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-14 18:02:39.361378: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-14 18:02:39.467356: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-14 18:02:39.779904: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-14 18:02:39.783652: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-14 18:02:41.950600: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Generate Synthetic Data
#
# Data generation

# %%
## Generating some data:
NSAMPLE = 3000

y_data = np.float32(np.random.uniform(-10.5, 10.5, NSAMPLE))
r_data = np.random.normal(size=NSAMPLE)
x_data = np.sin(0.75 * y_data) * 7.0 + y_data * 0.5 + r_data * 1
x_data = x_data.reshape((NSAMPLE, 1))
plt.figure(figsize=(8, 8))
plt.plot(x_data,y_data,'ro', alpha=0.3)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Build the MDN Model
#
# Now we will construct the MDN model in Keras. This uses the `Sequential` model interface in Keras.
#
# The `MDN` layer comes after one or more `Dense` layers. You need to define the output dimension and number of mixtures for the MDN like so: `MDN(output_dimension, number_mixtures)`.
#
# For this problem, we only need an output dimension of 1 as we are predicting one value (y). Adding more mixtures adds a more parameters (model is more complex, takes longer to train), but might help make the solutions better. You can see from the training data that there are at maximum 5 different layers to predict in the curve, so setting `N_MIXES = 5` is a good place to start.
#
# For MDNs, we have to use a special loss function that can handle the mixture parameters: the function has to take into account the number of output dimensions and mixtures.

# %%
N_HIDDEN = 15
N_MIXES = 10

model = keras.Sequential()
model.add(keras.layers.Dense(N_HIDDEN, batch_input_shape=(None, 1), activation='relu'))
model.add(keras.layers.Dense(N_HIDDEN, activation='relu'))
model.add(mdn.MDN(1, N_MIXES))
model.compile(loss=mdn.get_mixture_loss_func(1,N_MIXES), optimizer=keras.optimizers.Adam()) #, metrics=[mdn.get_mixture_mse_accuracy(1,N_MIXES)])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 15)                30
#
#  dense_1 (Dense)             (None, 15)                240
#
#  mdn (MDN)                   (None, 30)                480
#
# =================================================================
# Total params: 750 (2.93 KB)
# Trainable params: 750 (2.93 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Training the model
#
# Now we train the model using Keras' normal `fit` command.

# %%
history = model.fit(x=x_data, y=y_data, batch_size=128, epochs=500, validation_split=0.15)
# Out:
# Epoch 1/500
# 20/20 [==============================] - 6s 63ms/step - loss: 7.7956 - val_loss: 6.3172
# Epoch 2/500
# 20/20 [==============================] - 0s 5ms/step - loss: 6.0177 - val_loss: 5.2633
# Epoch 3/500
# 20/20 [==============================] - 0s 5ms/step - loss: 5.1729 - val_loss: 4.6809
# Epoch 4/500
# 20/20 [==============================] - 0s 6ms/step - loss: 4.6634 - val_loss: 4.2998
# Epoch 5/500
# 20/20 [==============================] - 0s 5ms/step - loss: 4.3141 - val_loss: 4.0272
# Epoch 6/500
# 20/20 [==============================] - 0s 6ms/step - loss: 4.0546 - val_loss: 3.8229
# Epoch 7/500
# 20/20 [==============================] - 0s 5ms/step - loss: 3.8556 - val_loss: 3.6550
# Epoch 8/500
# 20/20 [==============================] - 0s 5ms/step - loss: 3.7024 - val_loss: 3.5215
# Epoch 9/500
# 20/20 [==============================] - 0s 5ms/step - loss: 3.5719 - val_loss: 3.4215
# Epoch 10/500
# 20/20 [==============================] - 0s 5ms/step - loss: 3.4683 - val_loss: 3.3453
# Epoch 11/500
# 20/20 [==============================] - 0s 4ms/step - loss: 3.3886 - val_loss: 3.2744
# Epoch 12/500
# 20/20 [==============================] - 0s 4ms/step - loss: 3.3399 - val_loss: 3.2516
# Epoch 13/500
# 20/20 [==============================] - 0s 5ms/step - loss: 3.2878 - val_loss: 3.1938
# Epoch 14/500
# 20/20 [==============================] - 0s 5ms/step - loss: 3.2502 - val_loss: 3.1608
# Epoch 15/500
# 20/20 [==============================] - 0s 5ms/step - loss: 3.2190 - val_loss: 3.1396
# Epoch 16/500
# 20/20 [==============================] - 0s 6ms/step - loss: 3.1949 - val_loss: 3.1171
# Epoch 17/500
# 20/20 [==============================] - 0s 6ms/step - loss: 3.1923 - val_loss: 3.1008
# Epoch 18/500
# 20/20 [==============================] - 0s 5ms/step - loss: 3.1592 - val_loss: 3.0928
# Epoch 19/500
# 20/20 [==============================] - 0s 4ms/step - loss: 3.1391 - val_loss: 3.0657
# Epoch 20/500
# 20/20 [==============================] - 0s 4ms/step - loss: 3.1248 - val_loss: 3.0525
# Epoch 21/500
# 20/20 [==============================] - 0s 5ms/step - loss: 3.1105 - val_loss: 3.0327
# Epoch 22/500
# 20/20 [==============================] - 0s 5ms/step - loss: 3.0893 - val_loss: 3.0153
# Epoch 23/500
# 20/20 [==============================] - 0s 5ms/step - loss: 3.0696 - val_loss: 2.9999
# Epoch 24/500
# 20/20 [==============================] - 0s 5ms/step - loss: 3.0537 - val_loss: 2.9807
# Epoch 25/500
# 20/20 [==============================] - 0s 4ms/step - loss: 3.0391 - val_loss: 2.9676
# Epoch 26/500
# 20/20 [==============================] - 0s 5ms/step - loss: 3.0224 - val_loss: 2.9403
# Epoch 27/500
# 20/20 [==============================] - 0s 5ms/step - loss: 3.0052 - val_loss: 2.9324
# Epoch 28/500
# 20/20 [==============================] - 0s 7ms/step - loss: 2.9920 - val_loss: 2.9115
# Epoch 29/500
# 20/20 [==============================] - 0s 11ms/step - loss: 2.9796 - val_loss: 2.9070
# Epoch 30/500
# 20/20 [==============================] - 0s 11ms/step - loss: 2.9637 - val_loss: 2.8888
# Epoch 31/500
# 20/20 [==============================] - 0s 9ms/step - loss: 2.9495 - val_loss: 2.8679
# Epoch 32/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.9270 - val_loss: 2.8498
# Epoch 33/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.9158 - val_loss: 2.8399
# Epoch 34/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.8990 - val_loss: 2.8299
# Epoch 35/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.8837 - val_loss: 2.8141
# Epoch 36/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.8666 - val_loss: 2.8031
# Epoch 37/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.8520 - val_loss: 2.7847
# Epoch 38/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.8347 - val_loss: 2.7745
# Epoch 39/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.8194 - val_loss: 2.7575
# Epoch 40/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.8018 - val_loss: 2.7484
# Epoch 41/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.7819 - val_loss: 2.7266
# Epoch 42/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.7624 - val_loss: 2.7136
# Epoch 43/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.7460 - val_loss: 2.7034
# Epoch 44/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.7268 - val_loss: 2.6835
# Epoch 45/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.7022 - val_loss: 2.6610
# Epoch 46/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.6740 - val_loss: 2.6379
# Epoch 47/500
# 20/20 [==============================] - 0s 7ms/step - loss: 2.6413 - val_loss: 2.6087
# Epoch 48/500
# 20/20 [==============================] - 0s 8ms/step - loss: 2.6119 - val_loss: 2.5826
# Epoch 49/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.5896 - val_loss: 2.5654
# Epoch 50/500
# 20/20 [==============================] - 0s 9ms/step - loss: 2.5729 - val_loss: 2.5503
# Epoch 51/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.5493 - val_loss: 2.5432
# Epoch 52/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.5313 - val_loss: 2.5272
# Epoch 53/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.5066 - val_loss: 2.4897
# Epoch 54/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.4816 - val_loss: 2.4594
# Epoch 55/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.4588 - val_loss: 2.4281
# Epoch 56/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.4334 - val_loss: 2.4136
# Epoch 57/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.4106 - val_loss: 2.3881
# Epoch 58/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.3928 - val_loss: 2.3910
# Epoch 59/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.3752 - val_loss: 2.3823
# Epoch 60/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.3591 - val_loss: 2.3494
# Epoch 61/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.3412 - val_loss: 2.3417
# Epoch 62/500
# 20/20 [==============================] - 0s 7ms/step - loss: 2.3339 - val_loss: 2.3230
# Epoch 63/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.3159 - val_loss: 2.3184
# Epoch 64/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.3022 - val_loss: 2.2923
# Epoch 65/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.2919 - val_loss: 2.3167
# Epoch 66/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.2754 - val_loss: 2.2674
# Epoch 67/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.2665 - val_loss: 2.2669
# Epoch 68/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.2448 - val_loss: 2.2310
# Epoch 69/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.2254 - val_loss: 2.2276
# Epoch 70/500
# 20/20 [==============================] - 0s 7ms/step - loss: 2.2125 - val_loss: 2.2196
# Epoch 71/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.2089 - val_loss: 2.1948
# Epoch 72/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.2035 - val_loss: 2.1945
# Epoch 73/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.1950 - val_loss: 2.2097
# Epoch 74/500
# 20/20 [==============================] - 0s 7ms/step - loss: 2.1897 - val_loss: 2.2020
# Epoch 75/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.2010 - val_loss: 2.2001
# Epoch 76/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.1861 - val_loss: 2.1881
# Epoch 77/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.1732 - val_loss: 2.1918
# Epoch 78/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.1701 - val_loss: 2.1866
# Epoch 79/500
# 20/20 [==============================] - 0s 8ms/step - loss: 2.1690 - val_loss: 2.1903
# Epoch 80/500
# 20/20 [==============================] - 0s 7ms/step - loss: 2.1642 - val_loss: 2.1733
# Epoch 81/500
# 20/20 [==============================] - 0s 7ms/step - loss: 2.1785 - val_loss: 2.1973
# Epoch 82/500
# 20/20 [==============================] - 0s 7ms/step - loss: 2.1549 - val_loss: 2.1714
# Epoch 83/500
# 20/20 [==============================] - 0s 7ms/step - loss: 2.1588 - val_loss: 2.1600
# Epoch 84/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.1476 - val_loss: 2.1586
# Epoch 85/500
# 20/20 [==============================] - 0s 7ms/step - loss: 2.1427 - val_loss: 2.1554
# Epoch 86/500
# 20/20 [==============================] - 0s 8ms/step - loss: 2.1484 - val_loss: 2.1680
# Epoch 87/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.1444 - val_loss: 2.1668
# Epoch 88/500
# 20/20 [==============================] - 0s 7ms/step - loss: 2.1461 - val_loss: 2.1377
# Epoch 89/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.1381 - val_loss: 2.1569
# Epoch 90/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.1439 - val_loss: 2.1418
# Epoch 91/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.1322 - val_loss: 2.1318
# Epoch 92/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.1278 - val_loss: 2.1363
# Epoch 93/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.1274 - val_loss: 2.1530
# Epoch 94/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.1360 - val_loss: 2.1288
# Epoch 95/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.1244 - val_loss: 2.1229
# Epoch 96/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.1269 - val_loss: 2.1247
# Epoch 97/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.1285 - val_loss: 2.1094
# Epoch 98/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.1202 - val_loss: 2.1224
# Epoch 99/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.1118 - val_loss: 2.1619
# Epoch 100/500
# 20/20 [==============================] - 0s 7ms/step - loss: 2.1241 - val_loss: 2.1060
# Epoch 101/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.1079 - val_loss: 2.1288
# Epoch 102/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.1148 - val_loss: 2.1425
# Epoch 103/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.1251 - val_loss: 2.0992
# Epoch 104/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.1025 - val_loss: 2.1062
# Epoch 105/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.1006 - val_loss: 2.0961
# Epoch 106/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.1023 - val_loss: 2.1072
# Epoch 107/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.1017 - val_loss: 2.1193
# Epoch 108/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.1021 - val_loss: 2.0945
# Epoch 109/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.1049 - val_loss: 2.1166
# Epoch 110/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.1045 - val_loss: 2.0986
# Epoch 111/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.0931 - val_loss: 2.0986
# Epoch 112/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.0894 - val_loss: 2.0915
# Epoch 113/500
# 20/20 [==============================] - 0s 7ms/step - loss: 2.0850 - val_loss: 2.0905
# Epoch 114/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.0864 - val_loss: 2.0920
# Epoch 115/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.0865 - val_loss: 2.0874
# Epoch 116/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.0781 - val_loss: 2.0796
# Epoch 117/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0740 - val_loss: 2.0778
# Epoch 118/500
# 20/20 [==============================] - 0s 7ms/step - loss: 2.0802 - val_loss: 2.0686
# Epoch 119/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0866 - val_loss: 2.0796
# Epoch 120/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0607 - val_loss: 2.0723
# Epoch 121/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0653 - val_loss: 2.0557
# Epoch 122/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0618 - val_loss: 2.0569
# Epoch 123/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.0648 - val_loss: 2.1100
# Epoch 124/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0829 - val_loss: 2.0390
# Epoch 125/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0420 - val_loss: 2.0278
# Epoch 126/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0351 - val_loss: 2.0484
# Epoch 127/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0377 - val_loss: 2.0374
# Epoch 128/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.0182 - val_loss: 2.0377
# Epoch 129/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0219 - val_loss: 2.0337
# Epoch 130/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.0050 - val_loss: 2.0242
# Epoch 131/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.9901 - val_loss: 2.0158
# Epoch 132/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.0067 - val_loss: 2.0567
# Epoch 133/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.9921 - val_loss: 2.0108
# Epoch 134/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.9608 - val_loss: 1.9881
# Epoch 135/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.9608 - val_loss: 2.0076
# Epoch 136/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.9628 - val_loss: 1.9638
# Epoch 137/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.9400 - val_loss: 1.9758
# Epoch 138/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.9688 - val_loss: 1.9654
# Epoch 139/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.9575 - val_loss: 1.9415
# Epoch 140/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.9278 - val_loss: 1.9414
# Epoch 141/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.9093 - val_loss: 1.9583
# Epoch 142/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.9250 - val_loss: 1.9491
# Epoch 143/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.9145 - val_loss: 1.9029
# Epoch 144/500
# 20/20 [==============================] - 0s 8ms/step - loss: 1.8984 - val_loss: 1.9274
# Epoch 145/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.8845 - val_loss: 1.9027
# Epoch 146/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.8877 - val_loss: 1.9636
# Epoch 147/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.8865 - val_loss: 1.8919
# Epoch 148/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.8756 - val_loss: 1.8863
# Epoch 149/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.8699 - val_loss: 1.8860
# Epoch 150/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.8779 - val_loss: 1.8705
# Epoch 151/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.8532 - val_loss: 1.8924
# Epoch 152/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.8533 - val_loss: 1.8668
# Epoch 153/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.8456 - val_loss: 1.9041
# Epoch 154/500
# 20/20 [==============================] - 0s 8ms/step - loss: 1.8257 - val_loss: 1.8483
# Epoch 155/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.8343 - val_loss: 1.8444
# Epoch 156/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.8270 - val_loss: 1.8530
# Epoch 157/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.8233 - val_loss: 1.8413
# Epoch 158/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.8168 - val_loss: 1.8491
# Epoch 159/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.7944 - val_loss: 1.8154
# Epoch 160/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.7987 - val_loss: 1.8249
# Epoch 161/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.7888 - val_loss: 1.8612
# Epoch 162/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.
500
# 20/20 [==============================] - 0s 9ms/step - loss: 1.5445 - val_loss: 1.5964
# Epoch 413/500
# 20/20 [==============================] - 0s 10ms/step - loss: 1.5387 - val_loss: 1.6191
# Epoch 414/500
# 20/20 [==============================] - 0s 8ms/step - loss: 1.5602 - val_loss: 1.6017
# Epoch 415/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5911 - val_loss: 1.6302
# Epoch 416/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5838 - val_loss: 1.6310
# Epoch 417/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5596 - val_loss: 1.6068
# Epoch 418/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5676 - val_loss: 1.6153
# Epoch 419/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5535 - val_loss: 1.6042
# Epoch 420/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5494 - val_loss: 1.5933
# Epoch 421/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5442 - val_loss: 1.5964
# Epoch 422/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5448 - val_loss: 1.6000
# Epoch 423/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5557 - val_loss: 1.6075
# Epoch 424/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5387 - val_loss: 1.6109
# Epoch 425/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5456 - val_loss: 1.5964
# Epoch 426/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.5399 - val_loss: 1.6020
# Epoch 427/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.5373 - val_loss: 1.5968
# Epoch 428/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5547 - val_loss: 1.6036
# Epoch 429/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.5464 - val_loss: 1.5903
# Epoch 430/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.5452 - val_loss: 1.6304
# Epoch 431/500
# 20/20 [==============================] - 0s 8ms/step - loss: 1.5446 - val_loss: 1.5934
# Epoch 432/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5390 - val_loss: 1.5885
# Epoch 433/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5354 - val_loss: 1.5926
# Epoch 434/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5365 - val_loss: 1.5841
# Epoch 435/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5329 - val_loss: 1.6563
# Epoch 436/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.6559 - val_loss: 1.6523
# Epoch 437/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5990 - val_loss: 1.6171
# Epoch 438/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5652 - val_loss: 1.6025
# Epoch 439/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5507 - val_loss: 1.5967
# Epoch 440/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5441 - val_loss: 1.5965
# Epoch 441/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5477 - val_loss: 1.6084
# Epoch 442/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5374 - val_loss: 1.5869
# Epoch 443/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5397 - val_loss: 1.5981
# Epoch 444/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5410 - val_loss: 1.6012
# Epoch 445/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5386 - val_loss: 1.6027
# Epoch 446/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5355 - val_loss: 1.5900
# Epoch 447/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5312 - val_loss: 1.5929
# Epoch 448/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5338 - val_loss: 1.5869
# Epoch 449/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5314 - val_loss: 1.6124
# Epoch 450/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5393 - val_loss: 1.5799
# Epoch 451/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5350 - val_loss: 1.5859
# Epoch 452/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5358 - val_loss: 1.5943
# Epoch 453/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5350 - val_loss: 1.5869
# Epoch 454/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5340 - val_loss: 1.5817
# Epoch 455/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5332 - val_loss: 1.6685
# Epoch 456/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5751 - val_loss: 1.5818
# Epoch 457/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5400 - val_loss: 1.5824
# Epoch 458/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5292 - val_loss: 1.5862
# Epoch 459/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.5360 - val_loss: 1.6030
# Epoch 460/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5472 - val_loss: 1.5911
# Epoch 461/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5420 - val_loss: 1.5792
# Epoch 462/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5291 - val_loss: 1.5821
# Epoch 463/500
# 20/20 [==============================] - 0s 8ms/step - loss: 1.5290 - val_loss: 1.5897
# Epoch 464/500
# 20/20 [==============================] - 0s 8ms/step - loss: 1.5322 - val_loss: 1.6790
# Epoch 465/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5716 - val_loss: 1.6023
# Epoch 466/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5534 - val_loss: 1.5917
# Epoch 467/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5501 - val_loss: 1.5744
# Epoch 468/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5296 - val_loss: 1.5846
# Epoch 469/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5284 - val_loss: 1.5729
# Epoch 470/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5242 - val_loss: 1.6200
# Epoch 471/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5464 - val_loss: 1.5982
# Epoch 472/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5360 - val_loss: 1.5749
# Epoch 473/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5365 - val_loss: 1.5961
# Epoch 474/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5304 - val_loss: 1.5747
# Epoch 475/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5271 - val_loss: 1.5914
# Epoch 476/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5322 - val_loss: 1.5679
# Epoch 477/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5235 - val_loss: 1.5771
# Epoch 478/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5278 - val_loss: 1.5780
# Epoch 479/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5287 - val_loss: 1.5804
# Epoch 480/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5244 - val_loss: 1.5857
# Epoch 481/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5272 - val_loss: 1.5776
# Epoch 482/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5252 - val_loss: 1.6138
# Epoch 483/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5315 - val_loss: 1.5690
# Epoch 484/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5265 - val_loss: 1.5673
# Epoch 485/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5302 - val_loss: 1.5715
# Epoch 486/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5382 - val_loss: 1.6073
# Epoch 487/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.5478 - val_loss: 1.5805
# Epoch 488/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.5336 - val_loss: 1.5775
# Epoch 489/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5371 - val_loss: 1.6034
# Epoch 490/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5270 - val_loss: 1.5690
# Epoch 491/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.5255 - val_loss: 1.6051
# Epoch 492/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5290 - val_loss: 1.5897
# Epoch 493/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5277 - val_loss: 1.5698
# Epoch 494/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5157 - val_loss: 1.5760
# Epoch 495/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5174 - val_loss: 1.5618
# Epoch 496/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5194 - val_loss: 1.6882
# Epoch 497/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5895 - val_loss: 1.6037
# Epoch 498/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5429 - val_loss: 1.5627
# Epoch 499/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5167 - val_loss: 1.5716
# Epoch 500/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.5100 - val_loss: 1.5583

# %% [markdown]
# ### Training and Validation Loss
#
# It's interesting to see how the model trained. We can see that after a certain point training is rather slow.
#
# For this problem a loss value around 1.5 produces quite good results.

# %%
plt.figure(figsize=(10, 5))
plt.ylim([0,9])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Sampling Functions
#
# The MDN model outputs parameters of a mixture model---a list of means (mu), variances (sigma), and weights (pi).
#
# The `mdn` module provides a function to sample from these parameters as follows. First the parameters are split up into `mu`s, `sigma`s and `pi`s, then the categorical distribution formed by the `pi`s is sampled to choose which mixture component should be sampled, then that component's `mu`s and `sigma`s is used to sample from a multivariate normal model, here's the code:
#
#     def sample_from_output(params, output_dim, num_mixes, temp=1.0):
#         """Sample from an MDN output with temperature adjustment."""
#         mus = params[:num_mixes*output_dim]
#         sigs = params[num_mixes*output_dim:2*num_mixes*output_dim]
#         pis = softmax(params[-num_mixes:], t=temp)
#         m = sample_from_categorical(pis)
#         # Alternative way to sample from categorical:
#         # m = np.random.choice(range(len(pis)), p=pis)
#         mus_vector = mus[m*output_dim:(m+1)*output_dim]
#         sig_vector = sigs[m*output_dim:(m+1)*output_dim] * temp  # adjust for temperature
#         cov_matrix = np.identity(output_dim) * sig_vector
#         sample = np.random.multivariate_normal(mus_vector, cov_matrix, 1)
#         return sample
#
# If you only have one prediction to sample from, you can use the function as is; but if you need to sample from a lot of predictions at once (as in the following sections), you can use `np.apply_along_axis` to apply it to a whole numpy array of predicted parameters.

# %% [markdown]
# ## Try out the MDN Model
#
# Now we try out the model by making predictions at 3000 evenly spaced points on the x-axis.
#
# Mixture models output lists of parameters, so we're going to sample from these parameters for each point on the x-axis, and also try plotting the parameters themselves so we can have some insight into what the model is learning!

# %%
## Sample on some test data:
x_test = np.float32(np.arange(-15,15,0.01))
NTEST = x_test.size
print("Testing:", NTEST, "samples.")
x_test = x_test.reshape(NTEST,1) # needs to be a matrix, not a vector

# Make predictions from the model
y_test = model.predict(x_test)
# y_test contains parameters for distributions, not actual points on the graph.
# To find points on the graph, we need to sample from each distribution.

# Sample from the predicted distributions
y_samples = np.apply_along_axis(mdn.sample_from_output, 1, y_test, 1, N_MIXES,temp=1.0)

# Split up the mixture parameters (for future fun)
mus = np.apply_along_axis((lambda a: a[:N_MIXES]),1, y_test)
sigs = np.apply_along_axis((lambda a: a[N_MIXES:2*N_MIXES]),1, y_test)
pis = np.apply_along_axis((lambda a: mdn.softmax(a[2*N_MIXES:])),1, y_test)
# Out:
# Testing: 3000 samples.
# 94/94 [==============================] - 0s 1ms/step

# %%
# Plot the samples
plt.figure(figsize=(8, 8))
plt.plot(x_data,y_data,'ro', x_test, y_samples[:,:,0], 'bo',alpha=0.3)
plt.show()
# These look pretty good!
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Plot the means - this gives us some insight into how the model learns to produce the mixtures.
plt.figure(figsize=(8, 8))
plt.plot(x_data,y_data,'ro', x_test, mus,'bo',alpha=0.3)
plt.show()
# Cool!
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Let's plot the variances and weightings of the means as well.
fig = plt.figure(figsize=(8, 8))
ax1 = fig.add_subplot(111)
# ax1.scatter(data[0], data[1], marker='o', c='b', s=data[2], label='the data')
ax1.scatter(x_data,y_data,marker='o', c='r', alpha=0.3)
for i in range(N_MIXES):
    ax1.scatter(x_test, mus[:,i], marker='o', s=200*sigs[:,i]*pis[:,i],alpha=0.3)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Converting to TensorFlow Lite
#
# We will now convert the keras model into a tflite model. This primarily uses boilerplate code which invokes the TFLiteConverter class and writes the generated model to file. This conversion currently outputs a significant amount of arithmetic conversion errors. From other posts online, this seems to be a superficial issue with converting from 32 bit ints to 64 bit ints and does not affect the validity of the conversion.

# %%
# Following code converts high level keras model to a .tflite file 
converter = tf.lite.TFLiteConverter.from_keras_model(model)

tflite_model = converter.convert()
# Saves converted file to this folder
tflite_model_name = '1-sineprediction-lite.tflite'
with open(tflite_model_name, 'wb') as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp3hexea_1/assets
# INFO:tensorflow:Assets written to: /tmp/tmp3hexea_1/assets
# 2024-06-14 18:03:54.381572: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2024-06-14 18:03:54.381668: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2024-06-14 18:03:54.382252: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmp3hexea_1
# 2024-06-14 18:03:54.383559: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2024-06-14 18:03:54.383574: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmp3hexea_1
# 2024-06-14 18:03:54.386742: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# 2024-06-14 18:03:54.387728: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2024-06-14 18:03:54.460593: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmp3hexea_1
# 2024-06-14 18:03:54.499765: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 117514 microseconds.
# 2024-06-14 18:03:54.582440: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 11, Total Ops 22, % non-converted = 50.00 %
#  * 11 ARITH ops
#
# - arith.constant:   11 occurrences  (f32: 11)
#
#
#
#   (f32: 1)
#   (f32: 1)
#   (f32: 1)
#   (f32: 5)

# %% [markdown]
# ## Predicting using the TensorFlow Lite Model
#
# To make predictions using the tflite runtime, we use the interpreter class. Primarily, this is boilerplate code provided from the tensorflow tutorials. Importantly as our has a model dynamic input shape (as indicated by us defining the keras model with a first layer with batch_input_shape=(None, 1)) we must define the input tensor manually using resize_tensor_input. Now, we will test the tflite model on our original training data and compare it to the keras model.

# %%
# Load the TFLite model and allocate tensors.
# Note that it assumes we are loading the model just saved to the current folder
# to interpret from a model we have just generated, use model_content=tflite_model as the parameter instead
interpreter = tf.lite.Interpreter(model_path=tflite_model_name) 

# Resize input shape for dynamic shape model and allocate tensor
interpreter.resize_tensor_input(interpreter.get_input_details()[0]['index'], (NTEST,1))
interpreter.allocate_tensors()

# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Test the model on our defined testing set
interpreter.set_tensor(input_details[0]['index'], x_test)

# Uses the interpreter to make the same predictions as our keras model
interpreter.invoke()

# The function `get_tensor()` returns a copy of the tensor data.
y_test_tflite = interpreter.get_tensor(output_details[0]['index'])


# Sample from the TFLite predicted distributions as done previously
y_samples_tflite = np.apply_along_axis(mdn.sample_from_output, 1, y_test_tflite, 1, N_MIXES, temp=1.0)
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
# Plot the samples
plt.figure(figsize=(8, 8))
plt.plot(x_data,y_data,'ro', x_test, y_samples_tflite[:,:,0], 'go',alpha=0.3)
plt.show()
# The model clearly successfully predicts our dataset.
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Plot the Keras and TFLite model predictions
plt.figure(figsize=(8, 8))
plt.plot(x_test, y_samples[:,:,0], 'bo', label='Keras MDN', alpha=0.3)
plt.plot(x_test, y_samples_tflite[:,:,0], 'go', label='TFLite MDN', alpha=0.25)
plt.legend()
plt.show()
# The models clearly behave quite similarly
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
mse = np.mean((y_samples - y_samples_tflite)**2)
rmse = np.sqrt(mse)
mae = np.mean(np.abs(y_samples - y_samples_tflite))
correlation = np.corrcoef(y_samples.ravel(), y_samples_tflite.ravel())[0, 1]

print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"MAE: {mae}")
print(f"Correlation Coefficient: {correlation}")

# All seem useless
# Out:
# MSE: 33.80827037088134
# RMSE: 5.81448797151403
# MAE: 3.9890445605574913
# Correlation Coefficient: 0.6854442478234296
