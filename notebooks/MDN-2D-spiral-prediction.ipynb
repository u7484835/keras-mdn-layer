# %% [markdown]
# # 2D Mixture Density Network
#
# An extension of Bishops' classic MDN prediction task to 2-dimensions.
#
# The idea in this task is to predict a the value of a two inverse sine functions simultaneously. This function has multiple real-valued solutions at each point, so the ANN model needs to have the capacity to handle this in it's loss function. An MDN is a good way to handle the predictions of these multiple output values.
#
# This implementation owes much to the following:
#
# - [David Ha - Mixture Density Networks with TensorFlow](http://blog.otoro.net/2015/11/24/mixture-density-networks-with-tensorflow/)
# - [Mixture Density Networks in Edward](http://edwardlib.org/tutorials/mixture-density-network)

# %%
import keras
from context import * # imports the MDN layer 
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D 
# %matplotlib widget
# Out:
# 2024-05-04 14:35:55.560842: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-04 14:35:55.563796: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-04 14:35:55.601176: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-04 14:35:55.601206: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-04 14:35:55.602070: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-04 14:35:55.607652: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-04 14:35:55.608461: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-04 14:35:56.435676: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Generate Synthetic Data
#
# Data generation

# %%
## Generating some data:
NSAMPLE = 5000

z_data = np.float32(np.random.uniform(-10.5, 10.5, NSAMPLE))
r_data = np.random.normal(size=NSAMPLE)
s_data = np.random.normal(size=NSAMPLE)
x_data = np.sin(0.75 * z_data) * 7.0 + z_data * 0.5 + r_data * 1.0
y_data = np.cos(0.80 * z_data) * 6.5 + z_data * 0.5 + s_data * 1.0

x_input = z_data.reshape((NSAMPLE, 1))
y_input = np.array([x_data,y_data])
y_input = y_input.T #reshape to (NSAMPLE,2)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_data, y_data, z_data, alpha=0.3, c='r') #c=perf_down_sampled.moving
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Build the MDN Model
#
# Now we will construct the MDN model in Keras. This uses the `Sequential` model interface in Keras.
#
# The `MDN` layer comes after one or more `Dense` layers. You need to define the output dimension and number of mixtures for the MDN like so: `MDN(output_dimension, number_mixtures)`.
#
# For this problem, we only need an output dimension of 1 as we are predicting one value (y). Adding more mixtures adds a more parameters (model is more complex, takes longer to train), but might help make the solutions better. You can see from the training data that there are at maximum 5 different layers to predict in the curve, so setting `N_MIXES = 5` is a good place to start.
#
# For MDNs, we have to use a special loss function that can handle the mixture parameters: the function has to take into account the number of output dimensions and mixtures.

# %%
N_HIDDEN = 15
N_MIXES = 10
OUTPUT_DIMS = 2

model = keras.Sequential()
model.add(keras.layers.Dense(N_HIDDEN, batch_input_shape=(None, 1), activation='relu'))
model.add(keras.layers.Dense(N_HIDDEN, activation='relu'))
model.add(mdn.MDN(OUTPUT_DIMS, N_MIXES))
model.compile(loss=mdn.get_mixture_loss_func(OUTPUT_DIMS,N_MIXES), optimizer=keras.optimizers.Adam())
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 15)                30
#
#  dense_1 (Dense)             (None, 15)                240
#
#  mdn (MDN)                   (None, 50)                800
#
# =================================================================
# Total params: 1070 (4.18 KB)
# Trainable params: 1070 (4.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Training the model
#
# Now we train the model using Keras' normal `fit` command.

# %%
history = model.fit(x=x_input, y=y_input, batch_size=128, epochs=300, validation_split=0.15, callbacks=[keras.callbacks.TerminateOnNaN()])
# Out:
# Epoch 1/300
# 34/34 [==============================] - 6s 40ms/step - loss: 11.1028 - val_loss: 8.9961
# Epoch 2/300
# 34/34 [==============================] - 0s 5ms/step - loss: 8.4414 - val_loss: 7.5085
# Epoch 3/300
# 34/34 [==============================] - 0s 4ms/step - loss: 7.3675 - val_loss: 6.9383
# Epoch 4/300
# 34/34 [==============================] - 0s 5ms/step - loss: 6.8874 - val_loss: 6.6733
# Epoch 5/300
# 34/34 [==============================] - 0s 4ms/step - loss: 6.6369 - val_loss: 6.5143
# Epoch 6/300
# 34/34 [==============================] - 0s 6ms/step - loss: 6.4574 - val_loss: 6.3730
# Epoch 7/300
# 34/34 [==============================] - 0s 5ms/step - loss: 6.3023 - val_loss: 6.2452
# Epoch 8/300
# 34/34 [==============================] - 0s 4ms/step - loss: 6.1802 - val_loss: 6.1546
# Epoch 9/300
# 34/34 [==============================] - 0s 4ms/step - loss: 6.0955 - val_loss: 6.0823
# Epoch 10/300
# 34/34 [==============================] - 0s 5ms/step - loss: 6.0222 - val_loss: 6.0187
# Epoch 11/300
# 34/34 [==============================] - 0s 5ms/step - loss: 5.9593 - val_loss: 5.9532
# Epoch 12/300
# 34/34 [==============================] - 0s 5ms/step - loss: 5.8922 - val_loss: 5.8928
# Epoch 13/300
# 34/34 [==============================] - 0s 5ms/step - loss: 5.8305 - val_loss: 5.8276
# Epoch 14/300
# 34/34 [==============================] - 0s 5ms/step - loss: 5.7647 - val_loss: 5.7610
# Epoch 15/300
# 34/34 [==============================] - 0s 4ms/step - loss: 5.6945 - val_loss: 5.6883
# Epoch 16/300
# 34/34 [==============================] - 0s 4ms/step - loss: 5.6172 - val_loss: 5.6162
# Epoch 17/300
# 34/34 [==============================] - 0s 5ms/step - loss: 5.5401 - val_loss: 5.5506
# Epoch 18/300
# 34/34 [==============================] - 0s 4ms/step - loss: 5.4673 - val_loss: 5.4848
# Epoch 19/300
# 34/34 [==============================] - 0s 5ms/step - loss: 5.4078 - val_loss: 5.4356
# Epoch 20/300
# 34/34 [==============================] - 0s 4ms/step - loss: 5.3571 - val_loss: 5.3905
# Epoch 21/300
# 34/34 [==============================] - 0s 4ms/step - loss: 5.3108 - val_loss: 5.3475
# Epoch 22/300
# 34/34 [==============================] - 0s 4ms/step - loss: 5.2679 - val_loss: 5.3167
# Epoch 23/300
# 34/34 [==============================] - 0s 6ms/step - loss: 5.2298 - val_loss: 5.2844
# Epoch 24/300
# 34/34 [==============================] - 0s 4ms/step - loss: 5.1937 - val_loss: 5.2492
# Epoch 25/300
# 34/34 [==============================] - 0s 4ms/step - loss: 5.1588 - val_loss: 5.2216
# Epoch 26/300
# 34/34 [==============================] - 0s 5ms/step - loss: 5.1286 - val_loss: 5.2015
# Epoch 27/300
# 34/34 [==============================] - 0s 4ms/step - loss: 5.0972 - val_loss: 5.1609
# Epoch 28/300
# 34/34 [==============================] - 0s 5ms/step - loss: 5.0648 - val_loss: 5.1375
# Epoch 29/300
# 34/34 [==============================] - 0s 5ms/step - loss: 5.0356 - val_loss: 5.1112
# Epoch 30/300
# 34/34 [==============================] - 0s 5ms/step - loss: 5.0124 - val_loss: 5.0836
# Epoch 31/300
# 34/34 [==============================] - 0s 5ms/step - loss: 4.9849 - val_loss: 5.0555
# Epoch 32/300
# 34/34 [==============================] - 0s 5ms/step - loss: 4.9557 - val_loss: 5.0335
# Epoch 33/300
# 34/34 [==============================] - 0s 5ms/step - loss: 4.9294 - val_loss: 5.0127
# Epoch 34/300
# 34/34 [==============================] - 0s 5ms/step - loss: 4.9011 - val_loss: 4.9785
# Epoch 35/300
# 34/34 [==============================] - 0s 5ms/step - loss: 4.8747 - val_loss: 4.9519
# Epoch 36/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.8460 - val_loss: 4.9295
# Epoch 37/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.8123 - val_loss: 4.8905
# Epoch 38/300
# 34/34 [==============================] - 0s 5ms/step - loss: 4.7838 - val_loss: 4.8723
# Epoch 39/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.7563 - val_loss: 4.8407
# Epoch 40/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.7245 - val_loss: 4.8178
# Epoch 41/300
# 34/34 [==============================] - 0s 5ms/step - loss: 4.6946 - val_loss: 4.7805
# Epoch 42/300
# 34/34 [==============================] - 0s 5ms/step - loss: 4.6594 - val_loss: 4.7528
# Epoch 43/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.6206 - val_loss: 4.6999
# Epoch 44/300
# 34/34 [==============================] - 0s 5ms/step - loss: 4.5763 - val_loss: 4.6497
# Epoch 45/300
# 34/34 [==============================] - 0s 5ms/step - loss: 4.5344 - val_loss: 4.6094
# Epoch 46/300
# 34/34 [==============================] - 0s 5ms/step - loss: 4.4863 - val_loss: 4.5565
# Epoch 47/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.4373 - val_loss: 4.5008
# Epoch 48/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.3917 - val_loss: 4.4466
# Epoch 49/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.3328 - val_loss: 4.3908
# Epoch 50/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.2774 - val_loss: 4.3492
# Epoch 51/300
# 34/34 [==============================] - 0s 5ms/step - loss: 4.2301 - val_loss: 4.3073
# Epoch 52/300
# 34/34 [==============================] - 0s 5ms/step - loss: 4.1851 - val_loss: 4.2667
# Epoch 53/300
# 34/34 [==============================] - 0s 5ms/step - loss: 4.1394 - val_loss: 4.2102
# Epoch 54/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.1028 - val_loss: 4.1738
# Epoch 55/300
# 34/34 [==============================] - 0s 5ms/step - loss: 4.0711 - val_loss: 4.1422
# Epoch 56/300
# 34/34 [==============================] - 0s 5ms/step - loss: 4.0384 - val_loss: 4.1117
# Epoch 57/300
# 34/34 [==============================] - 0s 4ms/step - loss: 4.0047 - val_loss: 4.0589
# Epoch 58/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.9666 - val_loss: 4.0339
# Epoch 59/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.9451 - val_loss: 4.0085
# Epoch 60/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.9008 - val_loss: 3.9536
# Epoch 61/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.8773 - val_loss: 3.9291
# Epoch 62/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.8461 - val_loss: 3.8877
# Epoch 63/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.8190 - val_loss: 3.8694
# Epoch 64/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.7910 - val_loss: 3.8236
# Epoch 65/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.7716 - val_loss: 3.8045
# Epoch 66/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.7566 - val_loss: 3.7980
# Epoch 67/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.7349 - val_loss: 3.7936
# Epoch 68/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.7161 - val_loss: 3.7675
# Epoch 69/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.7026 - val_loss: 3.7464
# Epoch 70/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.6899 - val_loss: 3.7249
# Epoch 71/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.6655 - val_loss: 3.6977
# Epoch 72/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.6516 - val_loss: 3.6925
# Epoch 73/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.6362 - val_loss: 3.6776
# Epoch 74/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.6257 - val_loss: 3.6731
# Epoch 75/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.6191 - val_loss: 3.6591
# Epoch 76/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.6015 - val_loss: 3.6427
# Epoch 77/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.5850 - val_loss: 3.6260
# Epoch 78/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.5730 - val_loss: 3.6195
# Epoch 79/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.5658 - val_loss: 3.6139
# Epoch 80/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.5550 - val_loss: 3.5911
# Epoch 81/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.5466 - val_loss: 3.5689
# Epoch 82/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.5256 - val_loss: 3.5609
# Epoch 83/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.5166 - val_loss: 3.5556
# Epoch 84/300
# 34/34 [==============================] - 0s 6ms/step - loss: 3.5002 - val_loss: 3.5393
# Epoch 85/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.4944 - val_loss: 3.5263
# Epoch 86/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.4786 - val_loss: 3.5091
# Epoch 87/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.4676 - val_loss: 3.5193
# Epoch 88/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.4579 - val_loss: 3.5158
# Epoch 89/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.4499 - val_loss: 3.5034
# Epoch 90/300
# 34/34 [==============================] - 0s 6ms/step - loss: 3.4387 - val_loss: 3.4714
# Epoch 91/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.4226 - val_loss: 3.4674
# Epoch 92/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.4137 - val_loss: 3.4715
# Epoch 93/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.4049 - val_loss: 3.4434
# Epoch 94/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.3883 - val_loss: 3.4289
# Epoch 95/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.3774 - val_loss: 3.4198
# Epoch 96/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.3723 - val_loss: 3.4095
# Epoch 97/300
# 34/34 [==============================] - 0s 6ms/step - loss: 3.3709 - val_loss: 3.3923
# Epoch 98/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.3579 - val_loss: 3.3861
# Epoch 99/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.3469 - val_loss: 3.3846
# Epoch 100/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.3425 - val_loss: 3.3695
# Epoch 101/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.3381 - val_loss: 3.3758
# Epoch 102/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.3270 - val_loss: 3.3911
# Epoch 103/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.3283 - val_loss: 3.3454
# Epoch 104/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.3130 - val_loss: 3.3486
# Epoch 105/300
# 34/34 [==============================] - 0s 6ms/step - loss: 3.3120 - val_loss: 3.3328
# Epoch 106/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.3048 - val_loss: 3.3395
# Epoch 107/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.2990 - val_loss: 3.3155
# Epoch 108/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2911 - val_loss: 3.3143
# Epoch 109/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2828 - val_loss: 3.3142
# Epoch 110/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2798 - val_loss: 3.3073
# Epoch 111/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2770 - val_loss: 3.2904
# Epoch 112/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2707 - val_loss: 3.2916
# Epoch 113/300
# 34/34 [==============================] - 0s 6ms/step - loss: 3.2592 - val_loss: 3.2831
# Epoch 114/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2593 - val_loss: 3.3007
# Epoch 115/300
# 34/34 [==============================] - 0s 6ms/step - loss: 3.2529 - val_loss: 3.2709
# Epoch 116/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.2495 - val_loss: 3.2700
# Epoch 117/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.2418 - val_loss: 3.2650
# Epoch 118/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2367 - val_loss: 3.2713
# Epoch 119/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2342 - val_loss: 3.2466
# Epoch 120/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2312 - val_loss: 3.2522
# Epoch 121/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.2240 - val_loss: 3.2414
# Epoch 122/300
# 34/34 [==============================] - 0s 6ms/step - loss: 3.2187 - val_loss: 3.2994
# Epoch 123/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2264 - val_loss: 3.2508
# Epoch 124/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2170 - val_loss: 3.2292
# Epoch 125/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2060 - val_loss: 3.2233
# Epoch 126/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1929 - val_loss: 3.2271
# Epoch 127/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.2007 - val_loss: 3.2178
# Epoch 128/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1906 - val_loss: 3.2113
# Epoch 129/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1894 - val_loss: 3.2057
# Epoch 130/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1833 - val_loss: 3.1954
# Epoch 131/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1794 - val_loss: 3.1953
# Epoch 132/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1770 - val_loss: 3.1918
# Epoch 133/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1779 - val_loss: 3.2195
# Epoch 134/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1755 - val_loss: 3.1895
# Epoch 135/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1671 - val_loss: 3.1791
# Epoch 136/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1637 - val_loss: 3.1593
# Epoch 137/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1542 - val_loss: 3.1602
# Epoch 138/300
# 34/34 [==============================] - 0s 6ms/step - loss: 3.1503 - val_loss: 3.1566
# Epoch 139/300
# 34/34 [==============================] - 0s 6ms/step - loss: 3.1505 - val_loss: 3.1870
# Epoch 140/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1551 - val_loss: 3.1735
# Epoch 141/300
# 34/34 [==============================] - 0s 6ms/step - loss: 3.1414 - val_loss: 3.1587
# Epoch 142/300
# 34/34 [==============================] - 0s 6ms/step - loss: 3.1484 - val_loss: 3.1443
# Epoch 143/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1436 - val_loss: 3.1368
# Epoch 144/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1377 - val_loss: 3.1560
# Epoch 145/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1356 - val_loss: 3.1594
# Epoch 146/300
# 34/34 [==============================] - 0s 6ms/step - loss: 3.1408 - val_loss: 3.1323
# Epoch 147/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1249 - val_loss: 3.1301
# Epoch 148/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1337 - val_loss: 3.1326
# Epoch 149/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1317 - val_loss: 3.1260
# Epoch 150/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1299 - val_loss: 3.1326
# Epoch 151/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1189 - val_loss: 3.1553
# Epoch 152/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1282 - val_loss: 3.1125
# Epoch 153/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1296 - val_loss: 3.1216
# Epoch 154/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1112 - val_loss: 3.1152
# Epoch 155/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1174 - val_loss: 3.1219
# Epoch 156/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1148 - val_loss: 3.1213
# Epoch 157/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1096 - val_loss: 3.1198
# Epoch 158/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1096 - val_loss: 3.1115
# Epoch 159/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1058 - val_loss: 3.1130
# Epoch 160/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1096 - val_loss: 3.1157
# Epoch 161/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1203 - val_loss: 3.1081
# Epoch 162/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1031 - val_loss: 3.1129
# Epoch 163/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1017 - val_loss: 3.0970
# Epoch 164/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0978 - val_loss: 3.1232
# Epoch 165/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.1005 - val_loss: 3.0955
# Epoch 166/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0980 - val_loss: 3.1189
# Epoch 167/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.1021 - val_loss: 3.1206
# Epoch 168/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0966 - val_loss: 3.0948
# Epoch 169/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0939 - val_loss: 3.0922
# Epoch 170/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0891 - val_loss: 3.0934
# Epoch 171/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0887 - val_loss: 3.0903
# Epoch 172/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0857 - val_loss: 3.0900
# Epoch 173/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0962 - val_loss: 3.0984
# Epoch 174/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0967 - val_loss: 3.1077
# Epoch 175/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0840 - val_loss: 3.1074
# Epoch 176/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0859 - val_loss: 3.0856
# Epoch 177/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0883 - val_loss: 3.0805
# Epoch 178/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0867 - val_loss: 3.0740
# Epoch 179/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0808 - val_loss: 3.0893
# Epoch 180/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0856 - val_loss: 3.0767
# Epoch 181/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0792 - val_loss: 3.0772
# Epoch 182/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0769 - val_loss: 3.0697
# Epoch 183/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0808 - val_loss: 3.0766
# Epoch 184/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0800 - val_loss: 3.0890
# Epoch 185/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0752 - val_loss: 3.0791
# Epoch 186/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0726 - val_loss: 3.0734
# Epoch 187/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0740 - val_loss: 3.0768
# Epoch 188/300
# 34/34 [==============================] - 0s 6ms/step - loss: 3.0716 - val_loss: 3.0940
# Epoch 189/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0710 - val_loss: 3.0860
# Epoch 190/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0772 - val_loss: 3.0862
# Epoch 191/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0704 - val_loss: 3.0729
# Epoch 192/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0670 - val_loss: 3.0677
# Epoch 193/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0659 - val_loss: 3.0542
# Epoch 194/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0654 - val_loss: 3.0627
# Epoch 195/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0612 - val_loss: 3.0526
# Epoch 196/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0681 - val_loss: 3.0809
# Epoch 197/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0677 - val_loss: 3.0661
# Epoch 198/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0592 - val_loss: 3.0598
# Epoch 199/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0636 - val_loss: 3.0524
# Epoch 200/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0593 - val_loss: 3.0530
# Epoch 201/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0563 - val_loss: 3.0712
# Epoch 202/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0593 - val_loss: 3.0513
# Epoch 203/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0590 - val_loss: 3.0625
# Epoch 204/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0590 - val_loss: 3.0563
# Epoch 205/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0555 - val_loss: 3.0752
# Epoch 206/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0563 - val_loss: 3.0609
# Epoch 207/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0557 - val_loss: 3.0519
# Epoch 208/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0516 - val_loss: 3.0676
# Epoch 209/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0537 - val_loss: 3.0429
# Epoch 210/300
# 34/34 [==============================] - 0s 6ms/step - loss: 3.0524 - val_loss: 3.0370
# Epoch 211/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0464 - val_loss: 3.0635
# Epoch 212/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0594 - val_loss: 3.0563
# Epoch 213/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0523 - val_loss: 3.0463
# Epoch 214/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0442 - val_loss: 3.0612
# Epoch 215/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0495 - val_loss: 3.0609
# Epoch 216/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0549 - val_loss: 3.0392
# Epoch 217/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0479 - val_loss: 3.0440
# Epoch 218/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0485 - val_loss: 3.0421
# Epoch 219/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0473 - val_loss: 3.0401
# Epoch 220/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0461 - val_loss: 3.0455
# Epoch 221/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0473 - val_loss: 3.0484
# Epoch 222/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0509 - val_loss: 3.0500
# Epoch 223/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0401 - val_loss: 3.0455
# Epoch 224/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0464 - val_loss: 3.0560
# Epoch 225/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0394 - val_loss: 3.0265
# Epoch 226/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0491 - val_loss: 3.0439
# Epoch 227/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0491 - val_loss: 3.0531
# Epoch 228/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0473 - val_loss: 3.0500
# Epoch 229/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0337 - val_loss: 3.0339
# Epoch 230/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0360 - val_loss: 3.0353
# Epoch 231/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0383 - val_loss: 3.0370
# Epoch 232/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0350 - val_loss: 3.0345
# Epoch 233/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0345 - val_loss: 3.0355
# Epoch 234/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0348 - val_loss: 3.0331
# Epoch 235/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0418 - val_loss: 3.0242
# Epoch 236/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0333 - val_loss: 3.0323
# Epoch 237/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0322 - val_loss: 3.0575
# Epoch 238/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0341 - val_loss: 3.0350
# Epoch 239/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0375 - val_loss: 3.0459
# Epoch 240/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0344 - val_loss: 3.0268
# Epoch 241/300
# 34/34 [==============================] - 0s 6ms/step - loss: 3.0323 - val_loss: 3.0173
# Epoch 242/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0331 - val_loss: 3.0298
# Epoch 243/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0310 - val_loss: 3.0236
# Epoch 244/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0284 - val_loss: 3.0199
# Epoch 245/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0289 - val_loss: 3.0300
# Epoch 246/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0360 - val_loss: 3.0448
# Epoch 247/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0328 - val_loss: 3.0332
# Epoch 248/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0224 - val_loss: 3.0274
# Epoch 249/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0278 - val_loss: 3.0338
# Epoch 250/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0229 - val_loss: 3.0220
# Epoch 251/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0210 - val_loss: 3.0198
# Epoch 252/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0273 - val_loss: 3.0376
# Epoch 253/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0204 - val_loss: 3.0245
# Epoch 254/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0263 - val_loss: 3.0262
# Epoch 255/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0240 - val_loss: 3.0150
# Epoch 256/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0199 - val_loss: 3.0345
# Epoch 257/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0256 - val_loss: 3.0213
# Epoch 258/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0213 - val_loss: 3.0258
# Epoch 259/300
# 34/34 [==============================] - 0s 6ms/step - loss: 3.0268 - val_loss: 3.0379
# Epoch 260/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0244 - val_loss: 3.0039
# Epoch 261/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0200 - val_loss: 3.0240
# Epoch 262/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0226 - val_loss: 3.0186
# Epoch 263/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0203 - val_loss: 3.0514
# Epoch 264/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0187 - val_loss: 3.0150
# Epoch 265/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0210 - val_loss: 3.0104
# Epoch 266/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0096 - val_loss: 3.0022
# Epoch 267/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0200 - val_loss: 3.0259
# Epoch 268/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0187 - val_loss: 3.0305
# Epoch 269/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0213 - val_loss: 3.0244
# Epoch 270/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0155 - val_loss: 3.0170
# Epoch 271/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0133 - val_loss: 3.0099
# Epoch 272/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0118 - val_loss: 3.0430
# Epoch 273/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0146 - val_loss: 2.9989
# Epoch 274/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0100 - val_loss: 3.0114
# Epoch 275/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0147 - val_loss: 3.0493
# Epoch 276/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0164 - val_loss: 3.0093
# Epoch 277/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0140 - val_loss: 3.0062
# Epoch 278/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0102 - val_loss: 3.0134
# Epoch 279/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0093 - val_loss: 3.0134
# Epoch 280/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0174 - val_loss: 3.0076
# Epoch 281/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0085 - val_loss: 3.0226
# Epoch 282/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0059 - val_loss: 3.0238
# Epoch 283/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0185 - val_loss: 3.0292
# Epoch 284/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0090 - val_loss: 3.0080
# Epoch 285/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0252 - val_loss: 3.0032
# Epoch 286/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0066 - val_loss: 3.0121
# Epoch 287/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0047 - val_loss: 3.0018
# Epoch 288/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0059 - val_loss: 3.0244
# Epoch 289/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0045 - val_loss: 3.0108
# Epoch 290/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0019 - val_loss: 3.0198
# Epoch 291/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9995 - val_loss: 3.0018
# Epoch 292/300
# 34/34 [==============================] - 0s 5ms/step - loss: 3.0059 - val_loss: 3.0184
# Epoch 293/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0103 - val_loss: 3.0108
# Epoch 294/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9995 - val_loss: 3.0105
# Epoch 295/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0012 - val_loss: 3.0143
# Epoch 296/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0005 - val_loss: 3.0057
# Epoch 297/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0059 - val_loss: 3.0097
# Epoch 298/300
# 34/34 [==============================] - 0s 4ms/step - loss: 3.0004 - val_loss: 2.9995
# Epoch 299/300
# 34/34 [==============================] - 0s 5ms/step - loss: 2.9963 - val_loss: 2.9948
# Epoch 300/300
# 34/34 [==============================] - 0s 4ms/step - loss: 2.9961 - val_loss: 2.9942

# %% [markdown]
# ### Training and Validation Loss
#
# It's interesting to see how the model trained. We can see that after a certain point improvement in training is rather slow.
#
# For this problem a loss value around 3.0 produces quite good results.

# %%
plt.figure(figsize=(10, 5))
plt.ylim([0,9])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Try out the MDN Model
#
# Now we try out the model by making predictions at 3000 evenly spaced points on the x-axis.
#
# Mixture models output lists of parameters, so we're going to sample from these parameters for each point on the x-axis, and also try plotting the parameters themselves so we can have some insight into what the model is learning!

# %%
## Sample on some test data:
x_test = np.float32(np.arange(-15,15,0.1))
NTEST = x_test.size
print("Testing:", NTEST, "samples.")
x_test = x_test.reshape(NTEST,1) # needs to be a matrix, not a vector

# Make predictions from the model
y_test = model.predict(x_test)
# y_test contains parameters for distributions, not actual points on the graph.
# To find points on the graph, we need to sample from each distribution.

# Split up the mixture parameters (for future fun)
mus = np.apply_along_axis((lambda a: a[:N_MIXES*OUTPUT_DIMS]), 1, y_test)
sigs = np.apply_along_axis((lambda a: a[N_MIXES*OUTPUT_DIMS:2*N_MIXES*OUTPUT_DIMS]), 1, y_test)
pis = np.apply_along_axis((lambda a: mdn.softmax(a[-N_MIXES:])), 1, y_test)

# Sample from the predicted distributions
y_samples = np.apply_along_axis(mdn.sample_from_output, 1, y_test, OUTPUT_DIMS, N_MIXES, temp=1.0, sigma_temp=1.0)
# Out:
# Testing: 300 samples.
# 10/10 [==============================] - 0s 1ms/step

# %%
# Plot the predicted samples.
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_data, y_data, z_data, alpha=0.05, c='r') #c=perf_down_sampled.moving
ax.scatter(y_samples.T[0], y_samples.T[1], x_test, alpha=0.2, c='b') #c=perf_down_sampled.moving
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Plot the means - this gives us some insight into how the model learns to produce the mixtures.
# Cool!

# Plot the predicted samples.
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_data, y_data, z_data, alpha=0.1, c='r') #c=perf_down_sampled.moving
ax.scatter(y_samples.T[0], y_samples.T[1], x_test, alpha=0.1, c='b') #c=perf_down_sampled.moving
for m in range(N_MIXES):
    one_pair = mus[m*OUTPUT_DIMS:(m+1)*OUTPUT_DIMS]
    ax.scatter(mus[:,2*m], mus[:,2*m + 1] , x_test, marker='o',alpha=0.3)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Let's plot the variances and weightings of the means as well.

# Plot the predicted samples.
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_data, y_data, z_data, alpha=0.1, c='r') #c=perf_down_sampled.moving
for m in range(N_MIXES):
    one_pair = mus[m*OUTPUT_DIMS:(m+1)*OUTPUT_DIMS]
    ax.scatter(mus[:,2*m], mus[:,2*m + 1] , x_test, s=100*sigs[:,2*m]*pis[:,m], marker='o',alpha=0.3)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
