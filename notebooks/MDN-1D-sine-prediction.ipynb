# %% [markdown]
# # Mixture Density Network
#
# Reproducing the classic Bishop MDN network tasks in Keras. The idea in this task is to predict a the value of an inverse sine function. This function has multiple real-valued solutions at each point, so the ANN model needs to have the capacity to handle this in it's loss function. An MDN is a good way to handle the predictions of these multiple output values.
#
# There's a couple of other versions of this task, and this implementation owes much to the following:
#
# - [David Ha - Mixture Density Networks with TensorFlow](http://blog.otoro.net/2015/11/24/mixture-density-networks-with-tensorflow/)
# - [Mixture Density Networks in Edward](http://edwardlib.org/tutorials/mixture-density-network)

# %%
# Normal imports for everybody
from context import * # imports the MDN layer 
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib widget
# Out:
# 2024-05-02 22:40:29.479102: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-02 22:40:29.485526: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-02 22:40:29.538401: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-02 22:40:29.538442: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-02 22:40:29.540711: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-02 22:40:29.548986: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-02 22:40:29.549703: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-02 22:40:30.491873: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Generate Synthetic Data
#
# Data generation

# %%
## Generating some data:
NSAMPLE = 3000

y_data = np.float32(np.random.uniform(-10.5, 10.5, NSAMPLE))
r_data = np.random.normal(size=NSAMPLE)
x_data = np.sin(0.75 * y_data) * 7.0 + y_data * 0.5 + r_data * 1.0
x_data = x_data.reshape((NSAMPLE, 1))

plt.figure(figsize=(8, 8))
plt.plot(x_data,y_data,'ro', alpha=0.3)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Build the MDN Model
#
# Now we will construct the MDN model in Keras. This uses the `Sequential` model interface in Keras.
#
# The `MDN` layer comes after one or more `Dense` layers. You need to define the output dimension and number of mixtures for the MDN like so: `MDN(output_dimension, number_mixtures)`.
#
# For this problem, we only need an output dimension of 1 as we are predicting one value (y). Adding more mixtures adds a more parameters (model is more complex, takes longer to train), but might help make the solutions better. You can see from the training data that there are at maximum 5 different layers to predict in the curve, so setting `N_MIXES = 5` is a good place to start.
#
# For MDNs, we have to use a special loss function that can handle the mixture parameters: the function has to take into account the number of output dimensions and mixtures.

# %%
N_HIDDEN = 15
N_MIXES = 10

model = keras.Sequential()
model.add(keras.layers.Dense(N_HIDDEN, batch_input_shape=(None, 1), activation='relu'))
model.add(keras.layers.Dense(N_HIDDEN, activation='relu'))
model.add(mdn.MDN(1, N_MIXES))
model.compile(loss=mdn.get_mixture_loss_func(1,N_MIXES), optimizer=keras.optimizers.Adam()) #, metrics=[mdn.get_mixture_mse_accuracy(1,N_MIXES)])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 15)                30
#
#  dense_1 (Dense)             (None, 15)                240
#
#  mdn (MDN)                   (None, 30)                480
#
# =================================================================
# Total params: 750 (2.93 KB)
# Trainable params: 750 (2.93 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Training the model
#
# Now we train the model using Keras' normal `fit` command.

# %%
history = model.fit(x=x_data, y=y_data, batch_size=128, epochs=500, validation_split=0.15)
# Out:
# Epoch 1/500
# 20/20 [==============================] - 5s 61ms/step - loss: 8.7674 - val_loss: 7.3936
# Epoch 2/500
# 20/20 [==============================] - 0s 4ms/step - loss: 7.0875 - val_loss: 6.0861
# Epoch 3/500
# 20/20 [==============================] - 0s 5ms/step - loss: 5.7918 - val_loss: 5.0163
# Epoch 4/500
# 20/20 [==============================] - 0s 5ms/step - loss: 4.9708 - val_loss: 4.4623
# Epoch 5/500
# 20/20 [==============================] - 0s 5ms/step - loss: 4.4799 - val_loss: 4.0900
# Epoch 6/500
# 20/20 [==============================] - 0s 6ms/step - loss: 4.1149 - val_loss: 3.7700
# Epoch 7/500
# 20/20 [==============================] - 0s 5ms/step - loss: 3.8232 - val_loss: 3.5872
# Epoch 8/500
# 20/20 [==============================] - 0s 6ms/step - loss: 3.6277 - val_loss: 3.4390
# Epoch 9/500
# 20/20 [==============================] - 0s 5ms/step - loss: 3.4905 - val_loss: 3.3436
# Epoch 10/500
# 20/20 [==============================] - 0s 5ms/step - loss: 3.3872 - val_loss: 3.2560
# Epoch 11/500
# 20/20 [==============================] - 0s 7ms/step - loss: 3.3069 - val_loss: 3.1969
# Epoch 12/500
# 20/20 [==============================] - 0s 7ms/step - loss: 3.2453 - val_loss: 3.1445
# Epoch 13/500
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1873 - val_loss: 3.0846
# Epoch 14/500
# 20/20 [==============================] - 0s 7ms/step - loss: 3.1336 - val_loss: 3.0213
# Epoch 15/500
# 20/20 [==============================] - 0s 7ms/step - loss: 3.0885 - val_loss: 2.9925
# Epoch 16/500
# 20/20 [==============================] - 0s 6ms/step - loss: 3.0441 - val_loss: 2.9431
# Epoch 17/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.9979 - val_loss: 2.9003
# Epoch 18/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.9605 - val_loss: 2.8760
# Epoch 19/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.9270 - val_loss: 2.8411
# Epoch 20/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.8914 - val_loss: 2.8122
# Epoch 21/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.8588 - val_loss: 2.7897
# Epoch 22/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.8292 - val_loss: 2.7608
# Epoch 23/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.7982 - val_loss: 2.7332
# Epoch 24/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.7655 - val_loss: 2.7065
# Epoch 25/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.7363 - val_loss: 2.6914
# Epoch 26/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.7080 - val_loss: 2.6613
# Epoch 27/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.6767 - val_loss: 2.6348
# Epoch 28/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.6462 - val_loss: 2.6104
# Epoch 29/500
# 20/20 [==============================] - 0s 8ms/step - loss: 2.6120 - val_loss: 2.5721
# Epoch 30/500
# 20/20 [==============================] - 0s 7ms/step - loss: 2
500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.1103 - val_loss: 2.1679
# Epoch 92/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.1161 - val_loss: 2.1772
# Epoch 93/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.1079 - val_loss: 2.1605
# Epoch 94/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.1103 - val_loss: 2.1637
# Epoch 95/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.1128 - val_loss: 2.1681
# Epoch 96/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.1068 - val_loss: 2.1764
# Epoch 97/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.1072 - val_loss: 2.1649
# Epoch 98/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.1004 - val_loss: 2.1565
# Epoch 99/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.1024 - val_loss: 2.1602
# Epoch 100/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.1031 - val_loss: 2.1581
# Epoch 101/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0963 - val_loss: 2.1464
# Epoch 102/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0960 - val_loss: 2.1582
# Epoch 103/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.1026 - val_loss: 2.1476
# Epoch 104/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.1072 - val_loss: 2.1562
# Epoch 105/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.0947 - val_loss: 2.1395
# Epoch 106/500
# 20/20 [==============================] - 0s 8ms/step - loss: 2.0989 - val_loss: 2.1501
# Epoch 107/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.0871 - val_loss: 2.1425
# Epoch 108/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0888 - val_loss: 2.1441
# Epoch 109/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0850 - val_loss: 2.1440
# Epoch 110/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.0847 - val_loss: 2.1382
# Epoch 111/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0824 - val_loss: 2.1294
# Epoch 112/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0821 - val_loss: 2.1271
# Epoch 113/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0819 - val_loss: 2.1468
# Epoch 114/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0889 - val_loss: 2.1423
# Epoch 115/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.0869 - val_loss: 2.1280
# Epoch 116/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0796 - val_loss: 2.1241
# Epoch 117/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0804 - val_loss: 2.1216
# Epoch 118/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0732 - val_loss: 2.1159
# Epoch 119/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.0709 - val_loss: 2.1212
# Epoch 120/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0662 - val_loss: 2.1153
# Epoch 121/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.0719 - val_loss: 2.1119
# Epoch 122/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.0639 - val_loss: 2.1045
# Epoch 123/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.0701 - val_loss: 2.1140
# Epoch 124/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.0695 - val_loss: 2.1053
# Epoch 125/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.0578 - val_loss: 2.1033
# Epoch 126/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0627 - val_loss: 2.1075
# Epoch 127/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0631 - val_loss: 2.1013
# Epoch 128/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0566 - val_loss: 2.1013
# Epoch 129/500
# 20/20 [==============================] - 0s 4ms/step - loss: 2.0526 - val_loss: 2.0925
# Epoch 130/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0498 - val_loss: 2.0991
# Epoch 131/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.0478 - val_loss: 2.0850
# Epoch 132/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0474 - val_loss: 2.0832
# Epoch 133/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.0400 - val_loss: 2.0851
# Epoch 134/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0432 - val_loss: 2.0859
# Epoch 135/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.0432 - val_loss: 2.0746
# Epoch 136/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0330 - val_loss: 2.0762
# Epoch 137/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.0373 - val_loss: 2.0781
# Epoch 138/500
# 20/20 [==============================] - 0s 8ms/step - loss: 2.0481 - val_loss: 2.0807
# Epoch 139/500
# 20/20 [==============================] - 0s 7ms/step - loss: 2.0372 - val_loss: 2.0841
# Epoch 140/500
# 20/20 [==============================] - 0s 7ms/step - loss: 2.0256 - val_loss: 2.0605
# Epoch 141/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.0292 - val_loss: 2.0654
# Epoch 142/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0291 - val_loss: 2.0681
# Epoch 143/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0242 - val_loss: 2.0532
# Epoch 144/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0178 - val_loss: 2.0574
# Epoch 145/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0181 - val_loss: 2.0488
# Epoch 146/500
# 20/20 [==============================] - 0s 7ms/step - loss: 2.0291 - val_loss: 2.0641
# Epoch 147/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.0192 - val_loss: 2.0698
# Epoch 148/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.0340 - val_loss: 2.0566
# Epoch 149/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0155 - val_loss: 2.0428
# Epoch 150/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.0066 - val_loss: 2.0404
# Epoch 151/500
# 20/20 [==============================] - 0s 7ms/step - loss: 2.0112 - val_loss: 2.0492
# Epoch 152/500
# 20/20 [==============================] - 0s 6ms/step - loss: 2.0027 - val_loss: 2.0261
# Epoch 153/500
# 20/20 [==============================] - 0s 8ms/step - loss: 2.0027 - val_loss: 2.0407
# Epoch 154/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.9969 - val_loss: 2.0308
# Epoch 155/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.9950 - val_loss: 2.0266
# Epoch 156/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.9951 - val_loss: 2.0233
# Epoch 157/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.9921 - val_loss: 2.0295
# Epoch 158/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.9927 - val_loss: 2.0205
# Epoch 159/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.9874 - val_loss: 2.0294
# Epoch 160/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.9844 - val_loss: 2.0189
# Epoch 161/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.9786 - val_loss: 2.0099
# Epoch 162/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.9750 - val_loss: 2.0089
# Epoch 163/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.9706 - val_loss: 2.0065
# Epoch 164/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.9723 - val_loss: 2.0379
# Epoch 165/500
# 20/20 [==============================] - 0s 5ms/step - loss: 2.0034 - val_loss: 2.0359
# Epoch 166/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.9720 - val_loss: 1.9998
# Epoch 167/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.9576 - val_loss: 1.9964
# Epoch 168/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.9529 - val_loss: 1.9889
# Epoch 169/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.9434 - val_loss: 1.9829
# Epoch 170/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.9409 - val_loss: 2.0029
# Epoch 171/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.9531 - val_loss: 1.9830
# Epoch 172/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.9390 - val_loss: 1.9719
# Epoch 173/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.9310 - val_loss: 1.9665
# Epoch 174/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.9252 - val_loss: 1.9636
# Epoch 175/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.9187 - val_loss: 1.9525
# Epoch 176/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.9178 - val_loss: 1.9522
# Epoch 177/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.9157 - val_loss: 1.9511
# Epoch 178/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.9102 - val_loss: 1.9764
# Epoch 179/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.9103 - val_loss: 1.9366
# Epoch 180/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.8946 - val_loss: 1.9318
# Epoch 181/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.8900 - val_loss: 1.9245
# Epoch 182/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.9006 - val_loss: 1.9485
# Epoch 183/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.8956 - val_loss: 1.9663
# Epoch 184/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.9073 - val_loss: 1.9607
# Epoch 185/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.8923 - val_loss: 1.9198
# Epoch 186/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.8815 - val_loss: 1.9080
# Epoch 187/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.8684 - val_loss: 1.9140
# Epoch 188/500
# 20/20 [==============================] - 0s 8ms/step - loss: 1.8650 - val_loss: 1.9020
# Epoch 189/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.8728 - val_loss: 1.9276
# Epoch 190/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.8626 - val_loss: 1.9014
# Epoch 191/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.8528 - val_loss: 1.8896
# Epoch 192/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.8557 - val_loss: 1.8892
# Epoch 193/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.8523 - val_loss: 1.8996
# Epoch 194/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.8433 - val_loss: 1.8598
# Epoch 195/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.8379 - val_loss: 1.8593
# Epoch 196/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.8347 - val_loss: 1.8570
# Epoch 197/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.8226 - val_loss: 1.8686
# Epoch 198/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.8203 - val_loss: 1.8457
# Epoch 199/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.8161 - val_loss: 1.8622
# Epoch 200/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.8134 - val_loss: 1.8559
# Epoch 201/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.8099 - val_loss: 1.8382
# Epoch 202/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.8284 - val_loss: 1.8471
# Epoch 203/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.8117 - val_loss: 1.8651
# Epoch 204/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.8004 - val_loss: 1.8189
# Epoch 205/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.7940 - val_loss: 1.8264
# Epoch 206/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.7929 - val_loss: 1.8378
# Epoch 207/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.7851 - val_loss: 1.8169
# Epoch 208/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.7898 - val_loss: 1.8231
# Epoch 209/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.
500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4855 - val_loss: 1.4718
# Epoch 398/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4924 - val_loss: 1.4643
# Epoch 399/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.4877 - val_loss: 1.4647
# Epoch 400/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4829 - val_loss: 1.4604
# Epoch 401/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4829 - val_loss: 1.4479
# Epoch 402/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4782 - val_loss: 1.4616
# Epoch 403/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4806 - val_loss: 1.4677
# Epoch 404/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4782 - val_loss: 1.4592
# Epoch 405/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4828 - val_loss: 1.4558
# Epoch 406/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4809 - val_loss: 1.4520
# Epoch 407/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4850 - val_loss: 1.4560
# Epoch 408/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4759 - val_loss: 1.4798
# Epoch 409/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4777 - val_loss: 1.4570
# Epoch 410/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4783 - val_loss: 1.4649
# Epoch 411/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4807 - val_loss: 1.4718
# Epoch 412/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4778 - val_loss: 1.4520
# Epoch 413/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4792 - val_loss: 1.4560
# Epoch 414/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4827 - val_loss: 1.4661
# Epoch 415/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4711 - val_loss: 1.4543
# Epoch 416/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4714 - val_loss: 1.4521
# Epoch 417/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4704 - val_loss: 1.4511
# Epoch 418/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4729 - val_loss: 1.4533
# Epoch 419/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.4683 - val_loss: 1.4532
# Epoch 420/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4695 - val_loss: 1.4463
# Epoch 421/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4699 - val_loss: 1.4515
# Epoch 422/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4756 - val_loss: 1.4568
# Epoch 423/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4790 - val_loss: 1.4544
# Epoch 424/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4740 - val_loss: 1.4553
# Epoch 425/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4689 - val_loss: 1.4501
# Epoch 426/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4679 - val_loss: 1.4555
# Epoch 427/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4673 - val_loss: 1.4428
# Epoch 428/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4707 - val_loss: 1.4791
# Epoch 429/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4729 - val_loss: 1.4491
# Epoch 430/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4675 - val_loss: 1.4512
# Epoch 431/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4738 - val_loss: 1.4575
# Epoch 432/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4677 - val_loss: 1.4531
# Epoch 433/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4745 - val_loss: 1.4785
# Epoch 434/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4842 - val_loss: 1.4631
# Epoch 435/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4738 - val_loss: 1.4593
# Epoch 436/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4689 - val_loss: 1.4413
# Epoch 437/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4646 - val_loss: 1.4458
# Epoch 438/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4625 - val_loss: 1.4617
# Epoch 439/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4790 - val_loss: 1.4600
# Epoch 440/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4681 - val_loss: 1.4504
# Epoch 441/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4663 - val_loss: 1.4450
# Epoch 442/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4632 - val_loss: 1.4471
# Epoch 443/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4673 - val_loss: 1.4545
# Epoch 444/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4640 - val_loss: 1.4723
# Epoch 445/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4726 - val_loss: 1.4715
# Epoch 446/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4634 - val_loss: 1.4453
# Epoch 447/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4650 - val_loss: 1.4764
# Epoch 448/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4689 - val_loss: 1.4525
# Epoch 449/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.4603 - val_loss: 1.4396
# Epoch 450/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4568 - val_loss: 1.4502
# Epoch 451/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4585 - val_loss: 1.4407
# Epoch 452/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4585 - val_loss: 1.4391
# Epoch 453/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4590 - val_loss: 1.4439
# Epoch 454/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.4588 - val_loss: 1.4584
# Epoch 455/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4595 - val_loss: 1.4637
# Epoch 456/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4587 - val_loss: 1.4420
# Epoch 457/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4554 - val_loss: 1.4445
# Epoch 458/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4680 - val_loss: 1.4436
# Epoch 459/500
# 20/20 [==============================] - 0s 7ms/step - loss: 1.4601 - val_loss: 1.4469
# Epoch 460/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4564 - val_loss: 1.4667
# Epoch 461/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4666 - val_loss: 1.4539
# Epoch 462/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4587 - val_loss: 1.4413
# Epoch 463/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4561 - val_loss: 1.4511
# Epoch 464/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4573 - val_loss: 1.4552
# Epoch 465/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4498 - val_loss: 1.4518
# Epoch 466/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4497 - val_loss: 1.4414
# Epoch 467/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4579 - val_loss: 1.4507
# Epoch 468/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4530 - val_loss: 1.4382
# Epoch 469/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4534 - val_loss: 1.4397
# Epoch 470/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4510 - val_loss: 1.4488
# Epoch 471/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4529 - val_loss: 1.4611
# Epoch 472/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4529 - val_loss: 1.4396
# Epoch 473/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4525 - val_loss: 1.4410
# Epoch 474/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4501 - val_loss: 1.4548
# Epoch 475/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4521 - val_loss: 1.4347
# Epoch 476/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4512 - val_loss: 1.4368
# Epoch 477/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4521 - val_loss: 1.4734
# Epoch 478/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4570 - val_loss: 1.4313
# Epoch 479/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4470 - val_loss: 1.4390
# Epoch 480/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4427 - val_loss: 1.4384
# Epoch 481/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4573 - val_loss: 1.4659
# Epoch 482/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4523 - val_loss: 1.4439
# Epoch 483/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4503 - val_loss: 1.4344
# Epoch 484/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4491 - val_loss: 1.4342
# Epoch 485/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4493 - val_loss: 1.4377
# Epoch 486/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4413 - val_loss: 1.4251
# Epoch 487/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4412 - val_loss: 1.4337
# Epoch 488/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4465 - val_loss: 1.4424
# Epoch 489/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4512 - val_loss: 1.4513
# Epoch 490/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4447 - val_loss: 1.4561
# Epoch 491/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4410 - val_loss: 1.4268
# Epoch 492/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4459 - val_loss: 1.4292
# Epoch 493/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4559 - val_loss: 1.4389
# Epoch 494/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4475 - val_loss: 1.4299
# Epoch 495/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4412 - val_loss: 1.4348
# Epoch 496/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4482 - val_loss: 1.4324
# Epoch 497/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4535 - val_loss: 1.4391
# Epoch 498/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4505 - val_loss: 1.4264
# Epoch 499/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4396 - val_loss: 1.4418
# Epoch 500/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4429 - val_loss: 1.4593

# %%
# Check all functions are importing properly 

num = 5

print(mdn.plusOne(num))
# Out:
# /home/ninjatimtam/.cache/pypoetry/virtualenvs/keras-mdn-layer-Fodlja9D-py3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Save model if you want to.
model.save("MDN-1D-sine-prediction-model.h5")

# %%
# Load the model if you want to.
# To load models from file, you need to supply the layer and loss function as custom_objects:
modelH = keras.models.load_model('MDN-1D-sine-prediction-model.h5', custom_objects={'MDN': mdn.MDN, 'loss_func': mdn.get_mixture_loss_func(1, N_MIXES)})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Load the model if you want to.
#       2 # To load models from file, you need to supply the layer and loss function as custom_objects:
# ----> 3 modelH = keras.models.load_model('MDN-1D-sine-prediction-model.h5', custom_objects={'MDN': mdn.MDN, 'loss_func': mdn.get_mixture_loss_func(1, N_MIXES)})
#
# File ~/.cache/pypoetry/virtualenvs/keras-mdn-layer-Fodlja9D-py3.11/lib/python3.11/site-packages/keras/src/saving/saving_api.py:262, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     254     return saving_lib.load_model(
#     255         filepath,
#     256         custom_objects=custom_objects,
#     257         compile=compile,
#     258         safe_mode=safe_mode,
#     259     )
#     261 # Legacy case.
# --> 262 return legacy_sm_saving_lib.load_model(
#     263     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     264 )
#
# File ~/.cache/pypoetry/virtualenvs/keras-mdn-layer-Fodlja9D-py3.11/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/.cache/pypoetry/virtualenvs/keras-mdn-layer-Fodlja9D-py3.11/lib/python3.11/site-packages/keras/src/saving/legacy/serialization.py:537, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     535     obj = module_objects.get(object_name)
#     536     if obj is None:
# --> 537         raise ValueError(
#     538             f"Unknown {printable_module_name}: '{object_name}'. "
#     539             "Please ensure you are using a "
#     540             "`keras.utils.custom_object_scope` "
#     541             "and that this object is included in the scope. See "
#     542             "https://www.tensorflow.org/guide/keras/save_and_serialize"
#     543             "#registering_the_custom_object for details."
#     544         )
#     546 # Classes passed by name are instantiated with no args, functions are
#     547 # returned as-is.
#     548 if tf_inspect.isclass(obj):
#
# ValueError: Unknown loss function: 'mdn_loss_func'. Please ensure you are using a `keras.utils.custom_object_scope` and that this object is included in the scope. See https://www.tensorflow.org/guide/keras/save_and_serialize#registering_the_custom_object for details.

# %% [markdown]
# ### Training and Validation Loss
#
# It's interesting to see how the model trained. We can see that after a certain point training is rather slow.
#
# For this problem a loss value around 1.5 produces quite good results.

# %%
plt.figure(figsize=(10, 5))
plt.ylim([0,9])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()

# %% [markdown]
# ## Sampling Functions
#
# The MDN model outputs parameters of a mixture model---a list of means (mu), variances (sigma), and weights (pi).
#
# The `mdn` module provides a function to sample from these parameters as follows. First the parameters are split up into `mu`s, `sigma`s and `pi`s, then the categorical distribution formed by the `pi`s is sampled to choose which mixture component should be sampled, then that component's `mu`s and `sigma`s is used to sample from a multivariate normal model, here's the code:
#
#     def sample_from_output(params, output_dim, num_mixes, temp=1.0):
#         """Sample from an MDN output with temperature adjustment."""
#         mus = params[:num_mixes*output_dim]
#         sigs = params[num_mixes*output_dim:2*num_mixes*output_dim]
#         pis = softmax(params[-num_mixes:], t=temp)
#         m = sample_from_categorical(pis)
#         # Alternative way to sample from categorical:
#         # m = np.random.choice(range(len(pis)), p=pis)
#         mus_vector = mus[m*output_dim:(m+1)*output_dim]
#         sig_vector = sigs[m*output_dim:(m+1)*output_dim] * temp  # adjust for temperature
#         cov_matrix = np.identity(output_dim) * sig_vector
#         sample = np.random.multivariate_normal(mus_vector, cov_matrix, 1)
#         return sample
#
# If you only have one prediction to sample from, you can use the function as is; but if you need to sample from a lot of predictions at once (as in the following sections), you can use `np.apply_along_axis` to apply it to a whole numpy array of predicted parameters.

# %% [markdown]
# ## Try out the MDN Model
#
# Now we try out the model by making predictions at 3000 evenly spaced points on the x-axis.
#
# Mixture models output lists of parameters, so we're going to sample from these parameters for each point on the x-axis, and also try plotting the parameters themselves so we can have some insight into what the model is learning!

# %%
## Sample on some test data:
x_test = np.float32(np.arange(-15,15,0.01))
NTEST = x_test.size
print("Testing:", NTEST, "samples.")
x_test = x_test.reshape(NTEST,1) # needs to be a matrix, not a vector

# Make predictions from the model
y_test = modelH.predict(x_test)
# y_test contains parameters for distributions, not actual points on the graph.
# To find points on the graph, we need to sample from each distribution.

# Sample from the predicted distributions
y_samples = np.apply_along_axis(mdn.sample_from_output, 1, y_test, 1, N_MIXES,temp=1.0)

# Split up the mixture parameters (for future fun)
mus = np.apply_along_axis((lambda a: a[:N_MIXES]),1, y_test)
sigs = np.apply_along_axis((lambda a: a[N_MIXES:2*N_MIXES]),1, y_test)
pis = np.apply_along_axis((lambda a: mdn.softmax(a[2*N_MIXES:])),1, y_test)

# %%
# Plot the samples
plt.figure(figsize=(8, 8))
plt.plot(x_data,y_data,'ro', x_test, y_samples[:,:,0], 'bo',alpha=0.3)
plt.show()
# These look pretty good!

# %%
# Plot the means - this gives us some insight into how the model learns to produce the mixtures.
plt.figure(figsize=(8, 8))
plt.plot(x_data,y_data,'ro', x_test, mus,'bo',alpha=0.3)
plt.show()
# Cool!

# %%
# Let's plot the variances and weightings of the means as well.
fig = plt.figure(figsize=(8, 8))
ax1 = fig.add_subplot(111)
# ax1.scatter(data[0], data[1], marker='o', c='b', s=data[2], label='the data')
ax1.scatter(x_data,y_data,marker='o', c='r', alpha=0.3)
for i in range(N_MIXES):
    ax1.scatter(x_test, mus[:,i], marker='o', s=200*sigs[:,i]*pis[:,i],alpha=0.3)
plt.show()
